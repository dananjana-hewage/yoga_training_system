# %%
import math
from pickle import FALSE

import cv2
import numpy as np
from time import time
import mediapipe as mp
import matplotlib.pyplot as plt
from numpy.ma.core import left_shift

# %%
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

pose = mp_pose.Pose(
    static_image_mode=True,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5,
    model_complexity = 1
)
###################

# %%
def detectPose(image, pose, display=True):
    '''
    Perform pose detection on an image.
    Args:
        image: Input image with a prominent person for pose detection.
        pose: Mediapipe pose function for detection.
        display: If True, display the images and landmarks.
    Returns:
        output_image: Image with detected pose landmarks drawn.
        landmarks: List of detected landmarks in original scale.
    '''
    # Create a copy of the input image.
    output_image = image.copy()

    # Convert BGR to RGB format.
    imageRGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Perform Pose Detection.
    results = pose.process(imageRGB)

    # Retrieve the image dimensions.
    height, width, _ = image.shape

    # Initialize list for landmarks.
    landmarks = []

    # If landmarks are detected.
    if results.pose_landmarks:
        # Draw Pose landmarks on the image.
        mp_drawing.draw_landmarks(
            image=output_image,
            landmark_list=results.pose_landmarks,
            connections=mp_pose.POSE_CONNECTIONS
        )

        # Save the landmarks.
        for landmark in results.pose_landmarks.landmark:
            landmarks.append((int(landmark.x * width), int(landmark.y * height), landmark.z * width))

    # Display results if requested.
    if display:
        plt.figure(figsize=[22, 22])
        plt.subplot(121);
        plt.imshow(image[:, :, ::-1]);
        plt.title("Original Image");
        plt.axis('off');
        plt.subplot(122);
        plt.imshow(output_image[:, :, ::-1]);
        plt.title("Output Image");
        plt.axis('off');
        mp_drawing.plot_landmarks(results.pose_world_landmarks, mp_pose.POSE_CONNECTIONS)
    else:
        return output_image, landmarks

# %%
# Initialize Pose function for video.
pose_video = mp_pose.Pose(
    static_image_mode=False,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5,
    model_complexity=1
)

# Open the webcam (change index to 1 if another camera is used).
video = cv2.VideoCapture(0)

# Create named window for resizing.
cv2.namedWindow('Pose Detection', cv2.WINDOW_NORMAL)

# Set video resolution.
video.set(3, 1280)  # Width
video.set(4, 960)  # Height

# Initialize time for FPS calculation.
time1 = 0

# Video capture loop.
while video.isOpened():
    # Read a frame.
    ok, frame = video.read()

    # If frame is not read properly, break the loop.
    if not ok:
        print("Error: Unable to read frame.")
        break

    # Flip the frame horizontally for natural view.
    frame = cv2.flip(frame, 1)

    # Resize the frame.
    frame_height, frame_width, _ = frame.shape
    frame = cv2.resize(frame, (int(frame_width * (640 / frame_height)), 640))

    # Perform pose detection.
    try:
        # Convert the frame to RGB for processing.
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Perform pose detection.
        results = pose_video.process(rgb_frame)

        # If landmarks are detected, process them.
        if results.pose_landmarks:
            landmarks = results.pose_landmarks.landmark

            # Print and optionally process landmarks.
            for i, landmark in enumerate(landmarks):
                print(
                    f"Landmark {i}: x={landmark.x:.3f}, y={landmark.y:.3f}, z={landmark.z:.3f}, visibility={landmark.visibility:.2f}"
                )

                # Optionally, convert normalized coordinates to pixels.
                pixel_x = int(landmark.x * frame_width)
                pixel_y = int(landmark.y * frame_height)
                print(f"Landmark {i} in pixels: x={pixel_x}, y={pixel_y}")

            # Draw pose landmarks on the frame.
            mp_drawing.draw_landmarks(
                frame,
                results.pose_landmarks,
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
            )

    except Exception as e:
        print("Error during pose detection:", e)
        continue

    # Calculate and display FPS.
    time2 = time()
    if (time2 - time1) > 0:
        fps = 1.0 / (time2 - time1)
        cv2.putText(frame, f'FPS: {int(fps)}', (10, 30), cv2.FONT_HERSHEY_PLAIN, 2, (0, 255, 0), 3)
    time1 = time2

    # Display the frame.
    cv2.imshow('Pose Detection', frame)

    # Break on 'ESC' key press.
    if cv2.waitKey(1) & 0xFF == 27:
        break

# Release the video capture object and close windows.
video.release()
cv2.destroyAllWindows()
# Out:
# Landmark 0: x=0.362, y=0.605, z=-1.360, visibility=1.00
# Landmark 0 in pixels: x=463, y=435
# Landmark 1: x=0.388, y=0.500, z=-1.293, visibility=1.00
# Landmark 1 in pixels: x=496, y=360
# Landmark 2: x=0.407, y=0.498, z=-1.293, visibility=1.00
# Landmark 2 in pixels: x=520, y=358
# Landmark 3: x=0.425, y=0.497, z=-1.293, visibility=1.00
# Landmark 3 in pixels: x=544, y=357
# Landmark 4: x=0.329, y=0.498, z=-1.311, visibility=1.00
# Landmark 4 in pixels: x=421, y=358
# Landmark 5: x=0.306, y=0.496, z=-1.311, visibility=1.00
# Landmark 5 in pixels: x=392, y=357
# Landmark 6: x=0.287, y=0.496, z=-1.312, visibility=1.00
# Landmark 6 in pixels: x=366, y=357
# Landmark 7: x=0.447, y=0.518, z=-0.764, visibility=1.00
# Landmark 7 in pixels: x=571, y=373
# Landmark 8: x=0.250, y=0.529, z=-0.844, visibility=1.00
# Landmark 8 in pixels: x=320, y=381
# Landmark 9: x=0.389, y=0.695, z=-1.146, visibility=1.00
# Landmark 9 in pixels: x=497, y=500
# Landmark 10: x=0.329, y=0.705, z=-1.171, visibility=1.00
# Landmark 10 in pixels: x=421, y=507
# Landmark 11: x=0.588, y=0.965, z=-0.436, visibility=0.97
# Landmark 11 in pixels: x=752, y=694
# Landmark 12: x=0.119, y=0.929, z=-0.476, visibility=0.96
# Landmark 12 in pixels: x=151, y=669
# Landmark 13: x=0.697, y=1.376, z=-0.744, visibility=0.16
# Landmark 13 in pixels: x=892, y=990
# Landmark 14: x=-0.104, y=1.283, z=-0.966, visibility=0.38
# Landmark 14 in pixels: x=-132, y=923
# Landmark 15: x=0.646, y=1.474, z=-1.362, visibility=0.08
# Landmark 15 in pixels: x=827, y=1061
# Landmark 16: x=-0.037, y=1.051, z=-1.847, visibility=0.22
# Landmark 16 in pixels: x=-47, y=757
# Landmark 17: x=0.646, y=1.545, z=-1.467, visibility=0.11
# Landmark 17 in pixels: x=826, y=1112
# Landmark 18: x=-0.027, y=1.001, z=-2.015, visibility=0.20
# Landmark 18 in pixels: x=-34, y=720
# Landmark 19: x=0.617, y=1.471, z=-1.477, visibility=0.15
# Landmark 19 in pixels: x=789, y=1059
# Landmark 20: x=-0.002, y=0.953, z=-1.952, visibility=0.26
# Landmark 20 in pixels: x=-2, y=686
# Landmark 21: x=0.610, y=1.448, z=-1.385, visibility=0.12
# Landmark 21 in pixels: x=780, y=1042
# Landmark 22: x=0.005, y=0.979, z=-1.851, visibility=0.22
# Landmark 22 in pixels: x=6, y=705
# Landmark 23: x=0.503, y=2.041, z=-0.050, visibility=0.00
# Landmark 23 in pixels: x=644, y=1469
# Landmark 24: x=0.201, y=2.030, z=0.054, visibility=0.00
# Landmark 24 in pixels: x=256, y=1461
# Landmark 25: x=0.503, y=2.819, z=-0.123, visibility=0.04
# Landmark 25 in pixels: x=643, y=2029
# Landmark 26: x=0.239, y=2.768, z=-0.262, visibility=0.02
# Landmark 26 in pixels: x=305, y=1992
# Landmark 27: x=0.523, y=3.569, z=0.488, visibility=0.00
# Landmark 27 in pixels: x=669, y=2569
# Landmark 28: x=0.267, y=3.534, z=0.155, visibility=0.00
# Landmark 28 in pixels: x=341, y=2544
# Landmark 29: x=0.528, y=3.692, z=0.513, visibility=0.00
# Landmark 29 in pixels: x=676, y=2658
# Landmark 30: x=0.271, y=3.658, z=0.174, visibility=0.00
# Landmark 30 in pixels: x=346, y=2633
# Landmark 31: x=0.487, y=3.811, z=-0.099, visibility=0.00
# Landmark 31 in pixels: x=622, y=2743
# Landmark 32: x=0.300, y=3.774, z=-0.488, visibility=0.00
# Landmark 32 in pixels: x=383, y=2716
# Landmark 0: x=0.362, y=0.605, z=-1.452, visibility=1.00
# Landmark 0 in pixels: x=463, y=435
# Landmark 1: x=0.388, y=0.501, z=-1.387, visibility=1.00
# Landmark 1 in pixels: x=496, y=360
# Landmark 2: x=0.407, y=0.499, z=-1.387, visibility=1.00
# Landmark 2 in pixels: x=520, y=358
# Landmark 3: x=0.425, y=0.497, z=-1.387, visibility=1.00
# Landmark 3 in pixels: x=543, y=357
# Landmark 4: x=0.329, y=0.499, z=-1.399, visibility=1.00
# Landmark 4 in pixels: x=421, y=359
# Landmark 5: x=0.306, y=0.497, z=-1.398, visibility=1.00
# Landmark 5 in pixels: x=392, y=357
# Landmark 6: x=0.287, y=0.496, z=-1.399, visibility=1.00
# Landmark 6 in pixels: x=366, y=357
# Landmark 7: x=0.447, y=0.519, z=-0.866, visibility=1.00
# Landmark 7 in pixels: x=571, y=373
# Landmark 8: x=0.251, y=0.529, z=-0.901, visibility=1.00
# Landmark 8 in pixels: x=321, y=381
# Landmark 9: x=0.390, y=0.695, z=-1.243, visibility=1.00
# Landmark 9 in pixels: x=499, y=500
# Landmark 10: x=0.328, y=0.704, z=-1.257, visibility=1.00
# Landmark 10 in pixels: x=419, y=507
# Landmark 11: x=0.592, y=0.968, z=-0.501, visibility=0.98
# Landmark 11 in pixels: x=757, y=697
# Landmark 12: x=0.118, y=0.933, z=-0.532, visibility=0.96
# Landmark 12 in pixels: x=150, y=671
# Landmark 13: x=0.696, y=1.506, z=-0.474, visibility=0.15
# Landmark 13 in pixels: x=891, y=1084
# Landmark 14: x=-0.085, y=1.420, z=-0.676, visibility=0.38
# Landmark 14 in pixels: x=-108, y=1022
# Landmark 15: x=0.655, y=1.905, z=-0.842, visibility=0.08
# Landmark 15 in pixels: x=838, y=1371
# Landmark 16: x=-0.015, y=1.674, z=-1.431, visibility=0.21
# Landmark 16 in pixels: x=-19, y=1205
# Landmark 17: x=0.674, y=2.064, z=-0.961, visibility=0.10
# Landmark 17 in pixels: x=862, y=1486
# Landmark 18: x=-0.011, y=1.806, z=-1.603, visibility=0.19
# Landmark 18 in pixels: x=-14, y=1300
# Landmark 19: x=0.631, y=2.036, z=-1.022, visibility=0.14
# Landmark 19 in pixels: x=808, y=1466
# Landmark 20: x=0.033, y=1.743, z=-1.657, visibility=0.24
# Landmark 20 in pixels: x=41, y=1254
# Landmark 21: x=0.616, y=1.974, z=-0.887, visibility=0.11
# Landmark 21 in pixels: x=788, y=1421
# Landmark 22: x=0.037, y=1.698, z=-1.478, visibility=0.21
# Landmark 22 in pixels: x=47, y=1222
# Landmark 23: x=0.506, y=2.048, z=-0.073, visibility=0.00
# Landmark 23 in pixels: x=647, y=1474
# Landmark 24: x=0.194, y=2.045, z=0.078, visibility=0.00
# Landmark 24 in pixels: x=247, y=1472
# Landmark 25: x=0.506, y=2.898, z=-0.083, visibility=0.04
# Landmark 25 in pixels: x=648, y=2086
# Landmark 26: x=0.231, y=2.893, z=0.059, visibility=0.01
# Landmark 26 in pixels: x=295, y=2083
# Landmark 27: x=0.521, y=3.666, z=0.655, visibility=0.00
# Landmark 27 in pixels: x=666, y=2639
# Landmark 28: x=0.250, y=3.667, z=0.623, visibility=0.00
# Landmark 28 in pixels: x=320, y=2640
# Landmark 29: x=0.528, y=3.797, z=0.685, visibility=0.00
# Landmark 29 in pixels: x=676, y=2734
# Landmark 30: x=0.249, y=3.804, z=0.661, visibility=0.00
# Landmark 30 in pixels: x=319, y=2739
# Landmark 31: x=0.464, y=3.940, z=-0.041, visibility=0.00
# Landmark 31 in pixels: x=593, y=2836
# Landmark 32: x=0.295, y=3.931, z=-0.108, visibility=0.00
# Landmark 32 in pixels: x=377, y=2830
# Landmark 0: x=0.362, y=0.606, z=-1.435, visibility=1.00
# Landmark 0 in pixels: x=463, y=436
# Landmark 1: x=0.388, y=0.501, z=-1.370, visibility=1.00
# Landmark 1 in pixels: x=497, y=361
# Landmark 2: x=0.407, y=0.499, z=-1.371, visibility=1.00
# Landmark 2 in pixels: x=520, y=359
# Landmark 3: x=0.424, y=0.498, z=-1.371, visibility=1.00
# Landmark 3 in pixels: x=543, y=358
# Landmark 4: x=0.329, y=0.500, z=-1.383, visibility=1.00
# Landmark 4 in pixels: x=421, y=359
# Landmark 5: x=0.306, y=0.497, z=-1.382, visibility=1.00
# Landmark 5 in pixels: x=392, y=357
# Landmark 6: x=0.287, y=0.497, z=-1.383, visibility=1.00
# Landmark 6 in pixels: x=366, y=357
# Landmark 7: x=0.447, y=0.519, z=-0.854, visibility=1.00
# Landmark 7 in pixels: x=571, y=373
# Landmark 8: x=0.251, y=0.529, z=-0.892, visibility=1.00
# Landmark 8 in pixels: x=321, y=381
# Landmark 9: x=0.390, y=0.695, z=-1.228, visibility=1.00
# Landmark 9 in pixels: x=499, y=500
# Landmark 10: x=0.327, y=0.704, z=-1.242, visibility=1.00
# Landmark 10 in pixels: x=418, y=507
# Landmark 11: x=0.592, y=0.971, z=-0.494, visibility=0.98
# Landmark 11 in pixels: x=758, y=699
# Landmark 12: x=0.117, y=0.934, z=-0.528, visibility=0.96
# Landmark 12 in pixels: x=149, y=672
# Landmark 13: x=0.689, y=1.542, z=-0.423, visibility=0.14
# Landmark 13 in pixels: x=881, y=1109
# Landmark 14: x=-0.078, y=1.438, z=-0.625, visibility=0.37
# Landmark 14 in pixels: x=-99, y=1035
# Landmark 15: x=0.653, y=1.952, z=-0.776, visibility=0.07
# Landmark 15 in pixels: x=836, y=1405
# Landmark 16: x=-0.014, y=1.693, z=-1.355, visibility=0.19
# Landmark 16 in pixels: x=-17, y=1218
# Landmark 17: x=0.671, y=2.113, z=-0.892, visibility=0.09
# Landmark 17 in pixels: x=858, y=1521
# Landmark 18: x=-0.011, y=1.821, z=-1.525, visibility=0.18
# Landmark 18 in pixels: x=-14, y=1311
# Landmark 19: x=0.631, y=2.083, z=-0.957, visibility=0.13
# Landmark 19 in pixels: x=807, y=1499
# Landmark 20: x=0.033, y=1.759, z=-1.583, visibility=0.23
# Landmark 20 in pixels: x=42, y=1266
# Landmark 21: x=0.613, y=2.019, z=-0.823, visibility=0.11
# Landmark 21 in pixels: x=784, y=1453
# Landmark 22: x=0.038, y=1.716, z=-1.403, visibility=0.20
# Landmark 22 in pixels: x=48, y=1235
# Landmark 23: x=0.506, y=2.051, z=-0.074, visibility=0.00
# Landmark 23 in pixels: x=647, y=1476
# Landmark 24: x=0.187, y=2.051, z=0.080, visibility=0.00
# Landmark 24 in pixels: x=239, y=1476
# Landmark 25: x=0.506, y=2.916, z=-0.072, visibility=0.03
# Landmark 25 in pixels: x=648, y=2099
# Landmark 26: x=0.223, y=2.910, z=-0.011, visibility=0.01
# Landmark 26 in pixels: x=285, y=2095
# Landmark 27: x=0.515, y=3.685, z=0.643, visibility=0.00
# Landmark 27 in pixels: x=658, y=2652
# Landmark 28: x=0.238, y=3.690, z=0.499, visibility=0.00
# Landmark 28 in pixels: x=304, y=2657
# Landmark 29: x=0.523, y=3.812, z=0.670, visibility=0.00
# Landmark 29 in pixels: x=669, y=2744
# Landmark 30: x=0.236, y=3.827, z=0.531, visibility=0.00
# Landmark 30 in pixels: x=301, y=2755
# Landmark 31: x=0.450, y=3.962, z=-0.046, visibility=0.00
# Landmark 31 in pixels: x=576, y=2852
# Landmark 32: x=0.287, y=3.949, z=-0.231, visibility=0.00
# Landmark 32 in pixels: x=366, y=2842
# Landmark 0: x=0.362, y=0.604, z=-1.430, visibility=1.00
# Landmark 0 in pixels: x=463, y=434
# Landmark 1: x=0.389, y=0.501, z=-1.366, visibility=1.00
# Landmark 1 in pixels: x=497, y=360
# Landmark 2: x=0.407, y=0.499, z=-1.367, visibility=1.00
# Landmark 2 in pixels: x=520, y=359
# Landmark 3: x=0.424, y=0.498, z=-1.367, visibility=1.00
# Landmark 3 in pixels: x=543, y=358
# Landmark 4: x=0.329, y=0.498, z=-1.383, visibility=1.00
# Landmark 4 in pixels: x=421, y=358
# Landmark 5: x=0.306, y=0.496, z=-1.382, visibility=1.00
# Landmark 5 in pixels: x=392, y=357
# Landmark 6: x=0.287, y=0.496, z=-1.383, visibility=1.00
# Landmark 6 in pixels: x=366, y=356
# Landmark 7: x=0.446, y=0.519, z=-0.863, visibility=1.00
# Landmark 7 in pixels: x=571, y=373
# Landmark 8: x=0.252, y=0.529, z=-0.918, visibility=1.00
# Landmark 8 in pixels: x=322, y=380
# Landmark 9: x=0.391, y=0.693, z=-1.226, visibility=1.00
# Landmark 9 in pixels: x=500, y=499
# Landmark 10: x=0.327, y=0.702, z=-1.245, visibility=1.00
# Landmark 10 in pixels: x=418, y=505
# Landmark 11: x=0.592, y=0.972, z=-0.486, visibility=0.98
# Landmark 11 in pixels: x=757, y=699
# Landmark 12: x=0.116, y=0.936, z=-0.566, visibility=0.97
# Landmark 12 in pixels: x=148, y=674
# Landmark 13: x=0.683, y=1.528, z=-0.375, visibility=0.13
# Landmark 13 in pixels: x=874, y=1100
# Landmark 14: x=-0.056, y=1.490, z=-0.583, visibility=0.36
# Landmark 14 in pixels: x=-72, y=1073
# Landmark 15: x=0.653, y=1.903, z=-0.737, visibility=0.07
# Landmark 15 in pixels: x=835, y=1370
# Landmark 16: x=0.001, y=1.810, z=-1.228, visibility=0.18
# Landmark 16 in pixels: x=0, y=1303
# Landmark 17: x=0.670, y=2.053, z=-0.847, visibility=0.09
# Landmark 17 in pixels: x=858, y=1477
# Landmark 18: x=-0.001, y=1.960, z=-1.399, visibility=0.17
# Landmark 18 in pixels: x=-1, y=1411
# Landmark 19: x=0.631, y=2.025, z=-0.917, visibility=0.12
# Landmark 19 in pixels: x=807, y=1458
# Landmark 20: x=0.047, y=1.906, z=-1.455, visibility=0.22
# Landmark 20 in pixels: x=59, y=1372
# Landmark 21: x=0.613, y=1.966, z=-0.786, visibility=0.10
# Landmark 21 in pixels: x=784, y=1415
# Landmark 22: x=0.055, y=1.850, z=-1.274, visibility=0.19
# Landmark 22 in pixels: x=69, y=1331
# Landmark 23: x=0.508, y=2.046, z=-0.068, visibility=0.00
# Landmark 23 in pixels: x=650, y=1472
# Landmark 24: x=0.186, y=2.051, z=0.074, visibility=0.00
# Landmark 24 in pixels: x=238, y=1476
# Landmark 25: x=0.527, y=2.905, z=-0.067, visibility=0.03
# Landmark 25 in pixels: x=674, y=2091
# Landmark 26: x=0.239, y=2.893, z=-0.103, visibility=0.01
# Landmark 26 in pixels: x=305, y=2082
# Landmark 27: x=0.545, y=3.670, z=0.662, visibility=0.00
# Landmark 27 in pixels: x=697, y=2642
# Landmark 28: x=0.263, y=3.676, z=0.391, visibility=0.00
# Landmark 28 in pixels: x=336, y=2646
# Landmark 29: x=0.552, y=3.796, z=0.691, visibility=0.00
# Landmark 29 in pixels: x=706, y=2732
# Landmark 30: x=0.259, y=3.817, z=0.420, visibility=0.00
# Landmark 30 in pixels: x=331, y=2747
# Landmark 31: x=0.488, y=3.953, z=-0.022, visibility=0.00
# Landmark 31 in pixels: x=624, y=2846
# Landmark 32: x=0.324, y=3.927, z=-0.287, visibility=0.00
# Landmark 32 in pixels: x=414, y=2827
# Landmark 0: x=0.363, y=0.604, z=-1.401, visibility=1.00
# Landmark 0 in pixels: x=464, y=434
# Landmark 1: x=0.389, y=0.501, z=-1.342, visibility=1.00
# Landmark 1 in pixels: x=497, y=360
# Landmark 2: x=0.407, y=0.499, z=-1.342, visibility=1.00
# Landmark 2 in pixels: x=521, y=359
# Landmark 3: x=0.424, y=0.498, z=-1.342, visibility=1.00
# Landmark 3 in pixels: x=543, y=358
# Landmark 4: x=0.329, y=0.499, z=-1.356, visibility=1.00
# Landmark 4 in pixels: x=421, y=359
# Landmark 5: x=0.306, y=0.496, z=-1.355, visibility=1.00
# Landmark 5 in pixels: x=392, y=357
# Landmark 6: x=0.286, y=0.496, z=-1.356, visibility=1.00
# Landmark 6 in pixels: x=366, y=357
# Landmark 7: x=0.446, y=0.519, z=-0.849, visibility=1.00
# Landmark 7 in pixels: x=571, y=373
# Landmark 8: x=0.252, y=0.529, z=-0.915, visibility=1.00
# Landmark 8 in pixels: x=322, y=381
# Landmark 9: x=0.392, y=0.693, z=-1.212, visibility=1.00
# Landmark 9 in pixels: x=501, y=498
# Landmark 10: x=0.327, y=0.702, z=-1.226, visibility=1.00
# Landmark 10 in pixels: x=418, y=505
# Landmark 11: x=0.592, y=0.978, z=-0.483, visibility=0.98
# Landmark 11 in pixels: x=757, y=703
# Landmark 12: x=0.116, y=0.937, z=-0.551, visibility=0.97
# Landmark 12 in pixels: x=148, y=674
# Landmark 13: x=0.682, y=1.518, z=-0.394, visibility=0.12
# Landmark 13 in pixels: x=873, y=1093
# Landmark 14: x=-0.060, y=1.466, z=-0.598, visibility=0.34
# Landmark 14 in pixels: x=-76, y=1055
# Landmark 15: x=0.657, y=1.872, z=-0.758, visibility=0.06
# Landmark 15 in pixels: x=840, y=1348
# Landmark 16: x=-0.003, y=1.726, z=-1.256, visibility=0.16
# Landmark 16 in pixels: x=-3, y=1242
# Landmark 17: x=0.677, y=2.015, z=-0.862, visibility=0.08
# Landmark 17 in pixels: x=867, y=1450
# Landmark 18: x=-0.002, y=1.856, z=-1.412, visibility=0.16
# Landmark 18 in pixels: x=-3, y=1336
# Landmark 19: x=0.640, y=1.983, z=-0.924, visibility=0.12
# Landmark 19 in pixels: x=818, y=1428
# Landmark 20: x=0.042, y=1.799, z=-1.462, visibility=0.20
# Landmark 20 in pixels: x=53, y=1294
# Landmark 21: x=0.621, y=1.927, z=-0.803, visibility=0.10
# Landmark 21 in pixels: x=794, y=1387
# Landmark 22: x=0.049, y=1.752, z=-1.300, visibility=0.18
# Landmark 22 in pixels: x=63, y=1261
# Landmark 23: x=0.508, y=2.052, z=-0.065, visibility=0.00
# Landmark 23 in pixels: x=650, y=1477
# Landmark 24: x=0.186, y=2.060, z=0.072, visibility=0.00
# Landmark 24 in pixels: x=237, y=1482
# Landmark 25: x=0.525, y=2.913, z=-0.073, visibility=0.03
# Landmark 25 in pixels: x=671, y=2097
# Landmark 26: x=0.238, y=2.908, z=-0.120, visibility=0.01
# Landmark 26 in pixels: x=304, y=2093
# Landmark 27: x=0.542, y=3.687, z=0.641, visibility=0.00
# Landmark 27 in pixels: x=693, y=2654
# Landmark 28: x=0.259, y=3.695, z=0.355, visibility=0.00
# Landmark 28 in pixels: x=331, y=2660
# Landmark 29: x=0.549, y=3.812, z=0.659, visibility=0.00
# Landmark 29 in pixels: x=702, y=2744
# Landmark 30: x=0.255, y=3.835, z=0.382, visibility=0.00
# Landmark 30 in pixels: x=326, y=2761
# Landmark 31: x=0.482, y=3.968, z=-0.077, visibility=0.00
# Landmark 31 in pixels: x=616, y=2856
# Landmark 32: x=0.322, y=3.941, z=-0.301, visibility=0.00
# Landmark 32 in pixels: x=412, y=2837
# Landmark 0: x=0.363, y=0.604, z=-1.363, visibility=1.00
# Landmark 0 in pixels: x=464, y=434
# Landmark 1: x=0.389, y=0.501, z=-1.304, visibility=1.00
# Landmark 1 in pixels: x=497, y=360
# Landmark 2: x=0.407, y=0.499, z=-1.304, visibility=1.00
# Landmark 2 in pixels: x=521, y=359
# Landmark 3: x=0.424, y=0.497, z=-1.304, visibility=1.00
# Landmark 3 in pixels: x=543, y=358
# Landmark 4: x=0.329, y=0.499, z=-1.319, visibility=1.00
# Landmark 4 in pixels: x=421, y=359
# Landmark 5: x=0.306, y=0.496, z=-1.318, visibility=1.00
# Landmark 5 in pixels: x=392, y=357
# Landmark 6: x=0.286, y=0.496, z=-1.319, visibility=1.00
# Landmark 6 in pixels: x=366, y=357
# Landmark 7: x=0.446, y=0.519, z=-0.832, visibility=1.00
# Landmark 7 in pixels: x=571, y=373
# Landmark 8: x=0.252, y=0.530, z=-0.888, visibility=1.00
# Landmark 8 in pixels: x=322, y=381
# Landmark 9: x=0.392, y=0.693, z=-1.176, visibility=1.00
# Landmark 9 in pixels: x=502, y=498
# Landmark 10: x=0.327, y=0.702, z=-1.192, visibility=1.00
# Landmark 10 in pixels: x=418, y=505
# Landmark 11: x=0.591, y=0.980, z=-0.460, visibility=0.98
# Landmark 11 in pixels: x=756, y=705
# Landmark 12: x=0.116, y=0.937, z=-0.545, visibility=0.97
# Landmark 12 in pixels: x=148, y=674
# Landmark 13: x=0.681, y=1.510, z=-0.361, visibility=0.11
# Landmark 13 in pixels: x=871, y=1087
# Landmark 14: x=-0.060, y=1.458, z=-0.600, visibility=0.32
# Landmark 14 in pixels: x=-77, y=1049
# Landmark 15: x=0.658, y=1.853, z=-0.714, visibility=0.06
# Landmark 15 in pixels: x=842, y=1334
# Landmark 16: x=-0.005, y=1.710, z=-1.266, visibility=0.15
# Landmark 16 in pixels: x=-5, y=1230
# Landmark 17: x=0.680, y=1.992, z=-0.813, visibility=0.08
# Landmark 17 in pixels: x=870, y=1434
# Landmark 18: x=-0.004, y=1.837, z=-1.423, visibility=0.15
# Landmark 18 in pixels: x=-4, y=1322
# Landmark 19: x=0.645, y=1.959, z=-0.877, visibility=0.11
# Landmark 19 in pixels: x=825, y=1410
# Landmark 20: x=0.039, y=1.778, z=-1.470, visibility=0.19
# Landmark 20 in pixels: x=49, y=1279
# Landmark 21: x=0.626, y=1.904, z=-0.760, visibility=0.09
# Landmark 21 in pixels: x=801, y=1371
# Landmark 22: x=0.046, y=1.732, z=-1.310, visibility=0.17
# Landmark 22 in pixels: x=59, y=1247
# Landmark 23: x=0.508, y=2.055, z=-0.060, visibility=0.00
# Landmark 23 in pixels: x=649, y=1479
# Landmark 24: x=0.185, y=2.063, z=0.067, visibility=0.00
# Landmark 24 in pixels: x=237, y=1485
# Landmark 25: x=0.524, y=2.914, z=-0.075, visibility=0.02
# Landmark 25 in pixels: x=670, y=2098
# Landmark 26: x=0.237, y=2.911, z=-0.127, visibility=0.01
# Landmark 26 in pixels: x=303, y=2096
# Landmark 27: x=0.540, y=3.690, z=0.615, visibility=0.00
# Landmark 27 in pixels: x=690, y=2656
# Landmark 28: x=0.257, y=3.699, z=0.342, visibility=0.00
# Landmark 28 in pixels: x=328, y=2663
# Landmark 29: x=0.546, y=3.816, z=0.628, visibility=0.00
# Landmark 29 in pixels: x=699, y=2747
# Landmark 30: x=0.253, y=3.837, z=0.372, visibility=0.00
# Landmark 30 in pixels: x=324, y=2762
# Landmark 31: x=0.479, y=3.968, z=-0.097, visibility=0.00
# Landmark 31 in pixels: x=612, y=2856
# Landmark 32: x=0.320, y=3.941, z=-0.337, visibility=0.00
# Landmark 32 in pixels: x=410, y=2837
# Landmark 0: x=0.363, y=0.604, z=-1.357, visibility=1.00
# Landmark 0 in pixels: x=464, y=434
# Landmark 1: x=0.389, y=0.501, z=-1.296, visibility=1.00
# Landmark 1 in pixels: x=498, y=360
# Landmark 2: x=0.407, y=0.499, z=-1.296, visibility=1.00
# Landmark 2 in pixels: x=521, y=359
# Landmark 3: x=0.424, y=0.497, z=-1.296, visibility=1.00
# Landmark 3 in pixels: x=543, y=358
# Landmark 4: x=0.329, y=0.499, z=-1.311, visibility=1.00
# Landmark 4 in pixels: x=421, y=359
# Landmark 5: x=0.306, y=0.497, z=-1.311, visibility=1.00
# Landmark 5 in pixels: x=392, y=357
# Landmark 6: x=0.286, y=0.496, z=-1.311, visibility=1.00
# Landmark 6 in pixels: x=366, y=357
# Landmark 7: x=0.446, y=0.519, z=-0.823, visibility=1.00
# Landmark 7 in pixels: x=571, y=373
# Landmark 8: x=0.252, y=0.530, z=-0.878, visibility=1.00
# Landmark 8 in pixels: x=322, y=381
# Landmark 9: x=0.393, y=0.692, z=-1.166, visibility=1.00
# Landmark 9 in pixels: x=502, y=498
# Landmark 10: x=0.327, y=0.702, z=-1.183, visibility=1.00
# Landmark 10 in pixels: x=418, y=505
# Landmark 11: x=0.591, y=0.981, z=-0.446, visibility=0.98
# Landmark 11 in pixels: x=756, y=706
# Landmark 12: x=0.117, y=0.938, z=-0.539, visibility=0.97
# Landmark 12 in pixels: x=149, y=675
# Landmark 13: x=0.679, y=1.506, z=-0.353, visibility=0.11
# Landmark 13 in pixels: x=869, y=1084
# Landmark 14: x=-0.060, y=1.455, z=-0.609, visibility=0.31
# Landmark 14 in pixels: x=-76, y=1047
# Landmark 15: x=0.660, y=1.846, z=-0.714, visibility=0.06
# Landmark 15 in pixels: x=844, y=1329
# Landmark 16: x=-0.005, y=1.705, z=-1.287, visibility=0.14
# Landmark 16 in pixels: x=-6, y=1227
# Landmark 17: x=0.682, y=1.983, z=-0.815, visibility=0.07
# Landmark 17 in pixels: x=873, y=1428
# Landmark 18: x=-0.004, y=1.831, z=-1.446, visibility=0.14
# Landmark 18 in pixels: x=-5, y=1318
# Landmark 19: x=0.648, y=1.950, z=-0.881, visibility=0.10
# Landmark 19 in pixels: x=829, y=1404
# Landmark 20: x=0.037, y=1.771, z=-1.493, visibility=0.18
# Landmark 20 in pixels: x=47, y=1274
# Landmark 21: x=0.629, y=1.896, z=-0.761, visibility=0.09
# Landmark 21 in pixels: x=805, y=1365
# Landmark 22: x=0.044, y=1.726, z=-1.330, visibility=0.16
# Landmark 22 in pixels: x=56, y=1242
# Landmark 23: x=0.508, y=2.056, z=-0.056, visibility=0.00
# Landmark 23 in pixels: x=649, y=1480
# Landmark 24: x=0.185, y=2.066, z=0.062, visibility=0.00
# Landmark 24 in pixels: x=237, y=1487
# Landmark 25: x=0.523, y=2.914, z=-0.077, visibility=0.02
# Landmark 25 in pixels: x=669, y=2098
# Landmark 26: x=0.237, y=2.912, z=-0.132, visibility=0.01
# Landmark 26 in pixels: x=302, y=2096
# Landmark 27: x=0.539, y=3.691, z=0.597, visibility=0.00
# Landmark 27 in pixels: x=690, y=2657
# Landmark 28: x=0.256, y=3.699, z=0.342, visibility=0.00
# Landmark 28 in pixels: x=327, y=2663
# Landmark 29: x=0.546, y=3.817, z=0.608, visibility=0.00
# Landmark 29 in pixels: x=698, y=2748
# Landmark 30: x=0.252, y=3.837, z=0.367, visibility=0.00
# Landmark 30 in pixels: x=323, y=2762
# Landmark 31: x=0.478, y=3.966, z=-0.108, visibility=0.00
# Landmark 31 in pixels: x=611, y=2855
# Landmark 32: x=0.320, y=3.941, z=-0.374, visibility=0.00
# Landmark 32 in pixels: x=408, y=2837
# Landmark 0: x=0.363, y=0.603, z=-1.318, visibility=1.00
# Landmark 0 in pixels: x=464, y=434
# Landmark 1: x=0.389, y=0.499, z=-1.247, visibility=1.00
# Landmark 1 in pixels: x=498, y=359
# Landmark 2: x=0.407, y=0.498, z=-1.248, visibility=1.00
# Landmark 2 in pixels: x=521, y=358
# Landmark 3: x=0.424, y=0.496, z=-1.248, visibility=1.00
# Landmark 3 in pixels: x=543, y=357
# Landmark 4: x=0.329, y=0.498, z=-1.256, visibility=1.00
# Landmark 4 in pixels: x=421, y=358
# Landmark 5: x=0.306, y=0.496, z=-1.255, visibility=1.00
# Landmark 5 in pixels: x=392, y=357
# Landmark 6: x=0.286, y=0.496, z=-1.256, visibility=1.00
# Landmark 6 in pixels: x=366, y=357
# Landmark 7: x=0.446, y=0.519, z=-0.724, visibility=1.00
# Landmark 7 in pixels: x=571, y=373
# Landmark 8: x=0.252, y=0.530, z=-0.748, visibility=1.00
# Landmark 8 in pixels: x=322, y=381
# Landmark 9: x=0.393, y=0.691, z=-1.115, visibility=1.00
# Landmark 9 in pixels: x=503, y=497
# Landmark 10: x=0.327, y=0.700, z=-1.126, visibility=1.00
# Landmark 10 in pixels: x=418, y=504
# Landmark 11: x=0.591, y=0.986, z=-0.417, visibility=0.98
# Landmark 11 in pixels: x=756, y=709
# Landmark 12: x=0.118, y=0.939, z=-0.427, visibility=0.97
# Landmark 12 in pixels: x=150, y=676
# Landmark 13: x=0.679, y=1.545, z=-0.407, visibility=0.10
# Landmark 13 in pixels: x=869, y=1112
# Landmark 14: x=-0.107, y=1.395, z=-0.841, visibility=0.32
# Landmark 14 in pixels: x=-136, y=1004
# Landmark 15: x=0.659, y=1.953, z=-0.827, visibility=0.06
# Landmark 15 in pixels: x=843, y=1406
# Landmark 16: x=-0.052, y=1.310, z=-1.885, visibility=0.17
# Landmark 16 in pixels: x=-67, y=943
# Landmark 17: x=0.681, y=2.116, z=-0.926, visibility=0.08
# Landmark 17 in pixels: x=871, y=1523
# Landmark 18: x=-0.053, y=1.314, z=-2.085, visibility=0.16
# Landmark 18 in pixels: x=-67, y=946
# Landmark 19: x=0.647, y=2.076, z=-0.977, visibility=0.11
# Landmark 19 in pixels: x=828, y=1495
# Landmark 20: x=-0.014, y=1.255, z=-2.081, visibility=0.21
# Landmark 20 in pixels: x=-17, y=903
# Landmark 21: x=0.627, y=2.017, z=-0.867, visibility=0.10
# Landmark 21 in pixels: x=802, y=1452
# Landmark 22: x=-0.003, y=1.270, z=-1.920, visibility=0.19
# Landmark 22 in pixels: x=-3, y=914
# Landmark 23: x=0.508, y=2.070, z=-0.064, visibility=0.00
# Landmark 23 in pixels: x=649, y=1490
# Landmark 24: x=0.182, y=2.074, z=0.070, visibility=0.00
# Landmark 24 in pixels: x=232, y=1493
# Landmark 25: x=0.522, y=2.941, z=-0.061, visibility=0.02
# Landmark 25 in pixels: x=667, y=2117
# Landmark 26: x=0.227, y=2.935, z=0.015, visibility=0.01
# Landmark 26 in pixels: x=291, y=2113
# Landmark 27: x=0.528, y=3.717, z=0.662, visibility=0.00
# Landmark 27 in pixels: x=675, y=2676
# Landmark 28: x=0.242, y=3.717, z=0.566, visibility=0.00
# Landmark 28 in pixels: x=309, y=2676
# Landmark 29: x=0.533, y=3.841, z=0.686, visibility=0.00
# Landmark 29 in pixels: x=682, y=2765
# Landmark 30: x=0.239, y=3.849, z=0.603, visibility=0.00
# Landmark 30 in pixels: x=305, y=2771
# Landmark 31: x=0.472, y=3.982, z=-0.044, visibility=0.00
# Landmark 31 in pixels: x=603, y=2866
# Landmark 32: x=0.293, y=3.960, z=-0.166, visibility=0.00
# Landmark 32 in pixels: x=374, y=2850
# Landmark 0: x=0.363, y=0.602, z=-1.314, visibility=1.00
# Landmark 0 in pixels: x=464, y=433
# Landmark 1: x=0.389, y=0.498, z=-1.244, visibility=1.00
# Landmark 1 in pixels: x=498, y=358
# Landmark 2: x=0.407, y=0.496, z=-1.245, visibility=1.00
# Landmark 2 in pixels: x=521, y=357
# Landmark 3: x=0.424, y=0.495, z=-1.245, visibility=1.00
# Landmark 3 in pixels: x=542, y=356
# Landmark 4: x=0.329, y=0.497, z=-1.253, visibility=1.00
# Landmark 4 in pixels: x=421, y=358
# Landmark 5: x=0.306, y=0.496, z=-1.252, visibility=1.00
# Landmark 5 in pixels: x=392, y=356
# Landmark 6: x=0.286, y=0.496, z=-1.253, visibility=1.00
# Landmark 6 in pixels: x=366, y=356
# Landmark 7: x=0.446, y=0.519, z=-0.722, visibility=1.00
# Landmark 7 in pixels: x=570, y=373
# Landmark 8: x=0.253, y=0.530, z=-0.746, visibility=1.00
# Landmark 8 in pixels: x=323, y=381
# Landmark 9: x=0.393, y=0.689, z=-1.111, visibility=1.00
# Landmark 9 in pixels: x=503, y=495
# Landmark 10: x=0.327, y=0.699, z=-1.121, visibility=1.00
# Landmark 10 in pixels: x=418, y=503
# Landmark 11: x=0.591, y=0.988, z=-0.408, visibility=0.98
# Landmark 11 in pixels: x=756, y=711
# Landmark 12: x=0.119, y=0.941, z=-0.414, visibility=0.97
# Landmark 12 in pixels: x=151, y=677
# Landmark 13: x=0.679, y=1.552, z=-0.424, visibility=0.10
# Landmark 13 in pixels: x=869, y=1117
# Landmark 14: x=-0.110, y=1.389, z=-0.815, visibility=0.32
# Landmark 14 in pixels: x=-140, y=1000
# Landmark 15: x=0.659, y=1.965, z=-0.853, visibility=0.06
# Landmark 15 in pixels: x=843, y=1414
# Landmark 16: x=-0.066, y=1.360, z=-1.762, visibility=0.17
# Landmark 16 in pixels: x=-84, y=979
# Landmark 17: x=0.680, y=2.129, z=-0.964, visibility=0.08
# Landmark 17 in pixels: x=870, y=1532
# Landmark 18: x=-0.068, y=1.396, z=-1.956, visibility=0.16
# Landmark 18 in pixels: x=-87, y=1005
# Landmark 19: x=0.646, y=2.093, z=-1.019, visibility=0.11
# Landmark 19 in pixels: x=827, y=1507
# Landmark 20: x=-0.031, y=1.337, z=-1.980, visibility=0.22
# Landmark 20 in pixels: x=-39, y=962
# Landmark 21: x=0.626, y=2.032, z=-0.897, visibility=0.10
# Landmark 21 in pixels: x=801, y=1463
# Landmark 22: x=-0.021, y=1.336, z=-1.805, visibility=0.20
# Landmark 22 in pixels: x=-27, y=961
# Landmark 23: x=0.508, y=2.073, z=-0.066, visibility=0.00
# Landmark 23 in pixels: x=649, y=1492
# Landmark 24: x=0.182, y=2.076, z=0.072, visibility=0.00
# Landmark 24 in pixels: x=232, y=1494
# Landmark 25: x=0.521, y=2.944, z=-0.056, visibility=0.02
# Landmark 25 in pixels: x=666, y=2119
# Landmark 26: x=0.227, y=2.935, z=0.003, visibility=0.01
# Landmark 26 in pixels: x=290, y=2113
# Landmark 27: x=0.525, y=3.717, z=0.674, visibility=0.00
# Landmark 27 in pixels: x=672, y=2676
# Landmark 28: x=0.240, y=3.716, z=0.535, visibility=0.00
# Landmark 28 in pixels: x=307, y=2675
# Landmark 29: x=0.531, y=3.841, z=0.701, visibility=0.00
# Landmark 29 in pixels: x=680, y=2765
# Landmark 30: x=0.237, y=3.848, z=0.570, visibility=0.00
# Landmark 30 in pixels: x=303, y=2770
# Landmark 31: x=0.470, y=3.980, z=-0.023, visibility=0.00
# Landmark 31 in pixels: x=601, y=2865
# Landmark 32: x=0.289, y=3.959, z=-0.196, visibility=0.00
# Landmark 32 in pixels: x=370, y=2850
# Landmark 0: x=0.363, y=0.601, z=-1.323, visibility=1.00
# Landmark 0 in pixels: x=464, y=432
# Landmark 1: x=0.389, y=0.497, z=-1.255, visibility=1.00
# Landmark 1 in pixels: x=498, y=358
# Landmark 2: x=0.407, y=0.495, z=-1.255, visibility=1.00
# Landmark 2 in pixels: x=521, y=356
# Landmark 3: x=0.424, y=0.494, z=-1.255, visibility=1.00
# Landmark 3 in pixels: x=542, y=355
# Landmark 4: x=0.329, y=0.497, z=-1.265, visibility=1.00
# Landmark 4 in pixels: x=421, y=358
# Landmark 5: x=0.306, y=0.495, z=-1.265, visibility=1.00
# Landmark 5 in pixels: x=391, y=356
# Landmark 6: x=0.286, y=0.496, z=-1.265, visibility=1.00
# Landmark 6 in pixels: x=366, y=356
# Landmark 7: x=0.446, y=0.518, z=-0.736, visibility=1.00
# Landmark 7 in pixels: x=570, y=372
# Landmark 8: x=0.253, y=0.530, z=-0.768, visibility=1.00
# Landmark 8 in pixels: x=323, y=381
# Landmark 9: x=0.393, y=0.687, z=-1.119, visibility=1.00
# Landmark 9 in pixels: x=503, y=494
# Landmark 10: x=0.327, y=0.698, z=-1.132, visibility=1.00
# Landmark 10 in pixels: x=418, y=502
# Landmark 11: x=0.591, y=0.987, z=-0.407, visibility=0.98
# Landmark 11 in pixels: x=756, y=710
# Landmark 12: x=0.120, y=0.942, z=-0.431, visibility=0.97
# Landmark 12 in pixels: x=154, y=677
# Landmark 13: x=0.679, y=1.555, z=-0.392, visibility=0.10
# Landmark 13 in pixels: x=869, y=1119
# Landmark 14: x=-0.107, y=1.389, z=-0.735, visibility=0.32
# Landmark 14 in pixels: x=-136, y=1000
# Landmark 15: x=0.659, y=1.967, z=-0.809, visibility=0.06
# Landmark 15 in pixels: x=843, y=1416
# Landmark 16: x=-0.065, y=1.420, z=-1.716, visibility=0.16
# Landmark 16 in pixels: x=-83, y=1022
# Landmark 17: x=0.681, y=2.130, z=-0.926, visibility=0.07
# Landmark 17 in pixels: x=871, y=1533
# Landmark 18: x=-0.068, y=1.494, z=-1.875, visibility=0.16
# Landmark 18 in pixels: x=-86, y=1075
# Landmark 19: x=0.645, y=2.099, z=-0.993, visibility=0.11
# Landmark 19 in pixels: x=825, y=1511
# Landmark 20: x=-0.029, y=1.431, z=-1.874, visibility=0.21
# Landmark 20 in pixels: x=-36, y=1030
# Landmark 21: x=0.626, y=2.036, z=-0.857, visibility=0.10
# Landmark 21 in pixels: x=801, y=1466
# Landmark 22: x=-0.021, y=1.416, z=-1.726, visibility=0.20
# Landmark 22 in pixels: x=-26, y=1019
# Landmark 23: x=0.508, y=2.074, z=-0.067, visibility=0.00
# Landmark 23 in pixels: x=650, y=1493
# Landmark 24: x=0.182, y=2.076, z=0.073, visibility=0.00
# Landmark 24 in pixels: x=233, y=1494
# Landmark 25: x=0.520, y=2.942, z=-0.033, visibility=0.02
# Landmark 25 in pixels: x=666, y=2118
# Landmark 26: x=0.227, y=2.936, z=0.051, visibility=0.01
# Landmark 26 in pixels: x=290, y=2113
# Landmark 27: x=0.525, y=3.714, z=0.705, visibility=0.00
# Landmark 27 in pixels: x=671, y=2673
# Landmark 28: x=0.241, y=3.714, z=0.600, visibility=0.00
# Landmark 28 in pixels: x=308, y=2674
# Landmark 29: x=0.531, y=3.838, z=0.735, visibility=0.00
# Landmark 29 in pixels: x=680, y=2763
# Landmark 30: x=0.238, y=3.846, z=0.637, visibility=0.00
# Landmark 30 in pixels: x=304, y=2769
# Landmark 31: x=0.469, y=3.978, z=0.021, visibility=0.00
# Landmark 31 in pixels: x=600, y=2864
# Landmark 32: x=0.289, y=3.960, z=-0.122, visibility=0.00
# Landmark 32 in pixels: x=370, y=2851
# Landmark 0: x=0.363, y=0.601, z=-1.458, visibility=1.00
# Landmark 0 in pixels: x=464, y=432
# Landmark 1: x=0.389, y=0.497, z=-1.389, visibility=1.00
# Landmark 1 in pixels: x=498, y=357
# Landmark 2: x=0.407, y=0.494, z=-1.390, visibility=1.00
# Landmark 2 in pixels: x=521, y=355
# Landmark 3: x=0.424, y=0.492, z=-1.390, visibility=1.00
# Landmark 3 in pixels: x=542, y=354
# Landmark 4: x=0.329, y=0.497, z=-1.407, visibility=1.00
# Landmark 4 in pixels: x=421, y=358
# Landmark 5: x=0.307, y=0.496, z=-1.407, visibility=1.00
# Landmark 5 in pixels: x=392, y=356
# Landmark 6: x=0.286, y=0.496, z=-1.407, visibility=1.00
# Landmark 6 in pixels: x=366, y=357
# Landmark 7: x=0.446, y=0.517, z=-0.863, visibility=1.00
# Landmark 7 in pixels: x=570, y=372
# Landmark 8: x=0.253, y=0.530, z=-0.925, visibility=1.00
# Landmark 8 in pixels: x=324, y=381
# Landmark 9: x=0.394, y=0.687, z=-1.247, visibility=1.00
# Landmark 9 in pixels: x=503, y=494
# Landmark 10: x=0.327, y=0.698, z=-1.267, visibility=1.00
# Landmark 10 in pixels: x=418, y=502
# Landmark 11: x=0.591, y=0.987, z=-0.465, visibility=0.98
# Landmark 11 in pixels: x=756, y=710
# Landmark 12: x=0.120, y=0.944, z=-0.543, visibility=0.97
# Landmark 12 in pixels: x=153, y=679
# Landmark 13: x=0.678, y=1.548, z=-0.399, visibility=0.09
# Landmark 13 in pixels: x=868, y=1114
# Landmark 14: x=-0.082, y=1.462, z=-0.617, visibility=0.32
# Landmark 14 in pixels: x=-104, y=1052
# Landmark 15: x=0.659, y=1.934, z=-0.804, visibility=0.05
# Landmark 15 in pixels: x=843, y=1392
# Landmark 16: x=-0.032, y=1.721, z=-1.282, visibility=0.15
# Landmark 16 in pixels: x=-40, y=1239
# Landmark 17: x=0.680, y=2.086, z=-0.923, visibility=0.07
# Landmark 17 in pixels: x=870, y=1501
# Landmark 18: x=-0.031, y=1.858, z=-1.453, visibility=0.15
# Landmark 18 in pixels: x=-39, y=1337
# Landmark 19: x=0.644, y=2.054, z=-0.996, visibility=0.10
# Landmark 19 in pixels: x=824, y=1479
# Landmark 20: x=0.010, y=1.798, z=-1.515, visibility=0.20
# Landmark 20 in pixels: x=13, y=1294
# Landmark 21: x=0.626, y=1.995, z=-0.855, visibility=0.09
# Landmark 21 in pixels: x=800, y=1436
# Landmark 22: x=0.016, y=1.749, z=-1.330, visibility=0.18
# Landmark 22 in pixels: x=20, y=1259
# Landmark 23: x=0.509, y=2.075, z=-0.065, visibility=0.00
# Landmark 23 in pixels: x=651, y=1494
# Landmark 24: x=0.183, y=2.079, z=0.071, visibility=0.00
# Landmark 24 in pixels: x=234, y=1497
# Landmark 25: x=0.523, y=2.942, z=-0.076, visibility=0.01
# Landmark 25 in pixels: x=669, y=2118
# Landmark 26: x=0.233, y=2.930, z=-0.203, visibility=0.01
# Landmark 26 in pixels: x=298, y=2109
# Landmark 27: x=0.531, y=3.712, z=0.702, visibility=0.00
# Landmark 27 in pixels: x=679, y=2672
# Landmark 28: x=0.252, y=3.711, z=0.341, visibility=0.00
# Landmark 28 in pixels: x=322, y=2672
# Landmark 29: x=0.537, y=3.837, z=0.725, visibility=0.00
# Landmark 29 in pixels: x=686, y=2762
# Landmark 30: x=0.250, y=3.847, z=0.374, visibility=0.00
# Landmark 30 in pixels: x=319, y=2770
# Landmark 31: x=0.478, y=3.984, z=-0.029, visibility=0.00
# Landmark 31 in pixels: x=612, y=2868
# Landmark 32: x=0.305, y=3.957, z=-0.424, visibility=0.00
# Landmark 32 in pixels: x=390, y=2848
# Landmark 0: x=0.364, y=0.601, z=-1.507, visibility=1.00
# Landmark 0 in pixels: x=466, y=432
# Landmark 1: x=0.390, y=0.496, z=-1.438, visibility=1.00
# Landmark 1 in pixels: x=499, y=357
# Landmark 2: x=0.408, y=0.494, z=-1.439, visibility=1.00
# Landmark 2 in pixels: x=522, y=355
# Landmark 3: x=0.424, y=0.492, z=-1.439, visibility=1.00
# Landmark 3 in pixels: x=543, y=354
# Landmark 4: x=0.331, y=0.497, z=-1.457, visibility=1.00
# Landmark 4 in pixels: x=423, y=358
# Landmark 5: x=0.308, y=0.496, z=-1.457, visibility=1.00
# Landmark 5 in pixels: x=394, y=356
# Landmark 6: x=0.287, y=0.496, z=-1.457, visibility=1.00
# Landmark 6 in pixels: x=367, y=357
# Landmark 7: x=0.446, y=0.516, z=-0.910, visibility=1.00
# Landmark 7 in pixels: x=570, y=371
# Landmark 8: x=0.253, y=0.530, z=-0.973, visibility=1.00
# Landmark 8 in pixels: x=324, y=381
# Landmark 9: x=0.395, y=0.687, z=-1.294, visibility=1.00
# Landmark 9 in pixels: x=505, y=494
# Landmark 10: x=0.329, y=0.698, z=-1.315, visibility=1.00
# Landmark 10 in pixels: x=420, y=502
# Landmark 11: x=0.593, y=0.987, z=-0.513, visibility=0.98
# Landmark 11 in pixels: x=759, y=710
# Landmark 12: x=0.120, y=0.946, z=-0.589, visibility=0.97
# Landmark 12 in pixels: x=152, y=681
# Landmark 13: x=0.680, y=1.544, z=-0.413, visibility=0.09
# Landmark 13 in pixels: x=870, y=1111
# Landmark 14: x=-0.073, y=1.488, z=-0.626, visibility=0.32
# Landmark 14 in pixels: x=-93, y=1071
# Landmark 15: x=0.661, y=1.930, z=-0.801, visibility=0.05
# Landmark 15 in pixels: x=846, y=1389
# Landmark 16: x=-0.011, y=1.767, z=-1.291, visibility=0.14
# Landmark 16 in pixels: x=-14, y=1271
# Landmark 17: x=0.684, y=2.083, z=-0.920, visibility=0.07
# Landmark 17 in pixels: x=875, y=1499
# Landmark 18: x=-0.009, y=1.904, z=-1.460, visibility=0.14
# Landmark 18 in pixels: x=-10, y=1370
# Landmark 19: x=0.647, y=2.057, z=-0.991, visibility=0.10
# Landmark 19 in pixels: x=827, y=1480
# Landmark 20: x=0.035, y=1.845, z=-1.524, visibility=0.19
# Landmark 20 in pixels: x=45, y=1328
# Landmark 21: x=0.628, y=1.996, z=-0.850, visibility=0.09
# Landmark 21 in pixels: x=803, y=1437
# Landmark 22: x=0.040, y=1.796, z=-1.340, visibility=0.17
# Landmark 22 in pixels: x=50, y=1293
# Landmark 23: x=0.512, y=2.075, z=-0.065, visibility=0.00
# Landmark 23 in pixels: x=655, y=1494
# Landmark 24: x=0.184, y=2.082, z=0.071, visibility=0.00
# Landmark 24 in pixels: x=234, y=1498
# Landmark 25: x=0.529, y=2.943, z=-0.058, visibility=0.01
# Landmark 25 in pixels: x=676, y=2118
# Landmark 26: x=0.238, y=2.930, z=-0.189, visibility=0.01
# Landmark 26 in pixels: x=304, y=2109
# Landmark 27: x=0.539, y=3.713, z=0.742, visibility=0.00
# Landmark 27 in pixels: x=690, y=2673
# Landmark 28: x=0.261, y=3.715, z=0.470, visibility=0.00
# Landmark 28 in pixels: x=334, y=2674
# Landmark 29: x=0.545, y=3.839, z=0.776, visibility=0.00
# Landmark 29 in pixels: x=698, y=2763
# Landmark 30: x=0.260, y=3.854, z=0.511, visibility=0.00
# Landmark 30 in pixels: x=333, y=2775
# Landmark 31: x=0.487, y=3.991, z=0.045, visibility=0.00
# Landmark 31 in pixels: x=623, y=2873
# Landmark 32: x=0.318, y=3.964, z=-0.293, visibility=0.00
# Landmark 32 in pixels: x=407, y=2854
# Landmark 0: x=0.367, y=0.601, z=-1.551, visibility=1.00
# Landmark 0 in pixels: x=469, y=433
# Landmark 1: x=0.392, y=0.496, z=-1.484, visibility=1.00
# Landmark 1 in pixels: x=501, y=357
# Landmark 2: x=0.409, y=0.494, z=-1.485, visibility=1.00
# Landmark 2 in pixels: x=524, y=355
# Landmark 3: x=0.425, y=0.492, z=-1.485, visibility=1.00
# Landmark 3 in pixels: x=544, y=354
# Landmark 4: x=0.333, y=0.498, z=-1.504, visibility=1.00
# Landmark 4 in pixels: x=426, y=358
# Landmark 5: x=0.310, y=0.496, z=-1.503, visibility=1.00
# Landmark 5 in pixels: x=397, y=357
# Landmark 6: x=0.289, y=0.496, z=-1.504, visibility=1.00
# Landmark 6 in pixels: x=369, y=357
# Landmark 7: x=0.446, y=0.516, z=-0.953, visibility=1.00
# Landmark 7 in pixels: x=571, y=371
# Landmark 8: x=0.254, y=0.530, z=-1.019, visibility=1.00
# Landmark 8 in pixels: x=324, y=381
# Landmark 9: x=0.397, y=0.687, z=-1.336, visibility=1.00
# Landmark 9 in pixels: x=507, y=494
# Landmark 10: x=0.331, y=0.699, z=-1.358, visibility=1.00
# Landmark 10 in pixels: x=423, y=503
# Landmark 11: x=0.594, y=0.987, z=-0.547, visibility=0.98
# Landmark 11 in pixels: x=760, y=710
# Landmark 12: x=0.119, y=0.948, z=-0.622, visibility=0.97
# Landmark 12 in pixels: x=152, y=682
# Landmark 13: x=0.685, y=1.542, z=-0.419, visibility=0.09
# Landmark 13 in pixels: x=877, y=1110
# Landmark 14: x=-0.063, y=1.503, z=-0.638, visibility=0.32
# Landmark 14 in pixels: x=-80, y=1082
# Landmark 15: x=0.666, y=1.921, z=-0.821, visibility=0.05
# Landmark 15 in pixels: x=851, y=1383
# Landmark 16: x=0.001, y=1.793, z=-1.304, visibility=0.13
# Landmark 16 in pixels: x=1, y=1290
# Landmark 17: x=0.690, y=2.072, z=-0.939, visibility=0.06
# Landmark 17 in pixels: x=882, y=1491
# Landmark 18: x=0.003, y=1.932, z=-1.473, visibility=0.13
# Landmark 18 in pixels: x=4, y=1390
# Landmark 19: x=0.651, y=2.046, z=-1.004, visibility=0.09
# Landmark 19 in pixels: x=833, y=1473
# Landmark 20: x=0.047, y=1.873, z=-1.539, visibility=0.18
# Landmark 20 in pixels: x=59, y=1348
# Landmark 21: x=0.632, y=1.986, z=-0.869, visibility=0.09
# Landmark 21 in pixels: x=808, y=1430
# Landmark 22: x=0.052, y=1.822, z=-1.353, visibility=0.17
# Landmark 22 in pixels: x=66, y=1312
# Landmark 23: x=0.514, y=2.075, z=-0.066, visibility=0.00
# Landmark 23 in pixels: x=657, y=1493
# Landmark 24: x=0.184, y=2.083, z=0.072, visibility=0.00
# Landmark 24 in pixels: x=236, y=1499
# Landmark 25: x=0.531, y=2.942, z=-0.049, visibility=0.01
# Landmark 25 in pixels: x=679, y=2118
# Landmark 26: x=0.239, y=2.930, z=-0.173, visibility=0.00
# Landmark 26 in pixels: x=306, y=2109
# Landmark 27: x=0.542, y=3.712, z=0.733, visibility=0.00
# Landmark 27 in pixels: x=693, y=2672
# Landmark 28: x=0.265, y=3.716, z=0.478, visibility=0.00
# Landmark 28 in pixels: x=338, y=2675
# Landmark 29: x=0.548, y=3.839, z=0.766, visibility=0.00
# Landmark 29 in pixels: x=701, y=2763
# Landmark 30: x=0.264, y=3.856, z=0.517, visibility=0.00
# Landmark 30 in pixels: x=337, y=2775
# Landmark 31: x=0.490, y=3.992, z=0.035, visibility=0.00
# Landmark 31 in pixels: x=627, y=2874
# Landmark 32: x=0.322, y=3.967, z=-0.284, visibility=0.00
# Landmark 32 in pixels: x=412, y=2856
# Landmark 0: x=0.366, y=0.598, z=-1.503, visibility=1.00
# Landmark 0 in pixels: x=468, y=430
# Landmark 1: x=0.392, y=0.493, z=-1.437, visibility=1.00
# Landmark 1 in pixels: x=501, y=355
# Landmark 2: x=0.409, y=0.491, z=-1.438, visibility=1.00
# Landmark 2 in pixels: x=523, y=353
# Landmark 3: x=0.425, y=0.490, z=-1.438, visibility=1.00
# Landmark 3 in pixels: x=543, y=352
# Landmark 4: x=0.333, y=0.494, z=-1.453, visibility=1.00
# Landmark 4 in pixels: x=425, y=355
# Landmark 5: x=0.310, y=0.493, z=-1.452, visibility=1.00
# Landmark 5 in pixels: x=396, y=354
# Landmark 6: x=0.289, y=0.493, z=-1.453, visibility=1.00
# Landmark 6 in pixels: x=369, y=354
# Landmark 7: x=0.446, y=0.515, z=-0.909, visibility=1.00
# Landmark 7 in pixels: x=570, y=371
# Landmark 8: x=0.254, y=0.528, z=-0.969, visibility=1.00
# Landmark 8 in pixels: x=324, y=380
# Landmark 9: x=0.396, y=0.685, z=-1.290, visibility=1.00
# Landmark 9 in pixels: x=507, y=492
# Landmark 10: x=0.330, y=0.696, z=-1.309, visibility=1.00
# Landmark 10 in pixels: x=422, y=501
# Landmark 11: x=0.593, y=0.985, z=-0.533, visibility=0.98
# Landmark 11 in pixels: x=758, y=709
# Landmark 12: x=0.117, y=0.948, z=-0.595, visibility=0.97
# Landmark 12 in pixels: x=149, y=682
# Landmark 13: x=0.685, y=1.529, z=-0.397, visibility=0.08
# Landmark 13 in pixels: x=876, y=1100
# Landmark 14: x=-0.064, y=1.490, z=-0.628, visibility=0.30
# Landmark 14 in pixels: x=-82, y=1072
# Landmark 15: x=0.664, y=1.887, z=-0.752, visibility=0.05
# Landmark 15 in pixels: x=850, y=1358
# Landmark 16: x=-0.002, y=1.745, z=-1.265, visibility=0.12
# Landmark 16 in pixels: x=-1, y=1256
# Landmark 17: x=0.689, y=2.028, z=-0.854, visibility=0.06
# Landmark 17 in pixels: x=882, y=1460
# Landmark 18: x=0.001, y=1.873, z=-1.427, visibility=0.12
# Landmark 18 in pixels: x=1, y=1348
# Landmark 19: x=0.651, y=2.003, z=-0.920, visibility=0.09
# Landmark 19 in pixels: x=833, y=1442
# Landmark 20: x=0.043, y=1.815, z=-1.476, visibility=0.17
# Landmark 20 in pixels: x=55, y=1306
# Landmark 21: x=0.632, y=1.945, z=-0.799, visibility=0.08
# Landmark 21 in pixels: x=808, y=1400
# Landmark 22: x=0.048, y=1.768, z=-1.308, visibility=0.16
# Landmark 22 in pixels: x=61, y=1273
# Landmark 23: x=0.512, y=2.075, z=-0.056, visibility=0.00
# Landmark 23 in pixels: x=655, y=1493
# Landmark 24: x=0.182, y=2.083, z=0.062, visibility=0.00
# Landmark 24 in pixels: x=233, y=1499
# Landmark 25: x=0.530, y=2.941, z=-0.057, visibility=0.01
# Landmark 25 in pixels: x=677, y=2117
# Landmark 26: x=0.239, y=2.928, z=-0.241, visibility=0.00
# Landmark 26 in pixels: x=305, y=2108
# Landmark 27: x=0.541, y=3.713, z=0.620, visibility=0.00
# Landmark 27 in pixels: x=692, y=2673
# Landmark 28: x=0.264, y=3.716, z=0.254, visibility=0.00
# Landmark 28 in pixels: x=338, y=2675
# Landmark 29: x=0.547, y=3.840, z=0.642, visibility=0.00
# Landmark 29 in pixels: x=700, y=2764
# Landmark 30: x=0.264, y=3.857, z=0.279, visibility=0.00
# Landmark 30 in pixels: x=337, y=2776
# Landmark 31: x=0.489, y=3.992, z=-0.076, visibility=0.00
# Landmark 31 in pixels: x=626, y=2873
# Landmark 32: x=0.321, y=3.965, z=-0.500, visibility=0.00
# Landmark 32 in pixels: x=410, y=2854
# Landmark 0: x=0.366, y=0.595, z=-1.481, visibility=1.00
# Landmark 0 in pixels: x=468, y=428
# Landmark 1: x=0.392, y=0.491, z=-1.414, visibility=1.00
# Landmark 1 in pixels: x=501, y=353
# Landmark 2: x=0.409, y=0.489, z=-1.415, visibility=1.00
# Landmark 2 in pixels: x=523, y=352
# Landmark 3: x=0.424, y=0.488, z=-1.415, visibility=1.00
# Landmark 3 in pixels: x=543, y=351
# Landmark 4: x=0.332, y=0.492, z=-1.430, visibility=1.00
# Landmark 4 in pixels: x=425, y=354
# Landmark 5: x=0.310, y=0.490, z=-1.429, visibility=1.00
# Landmark 5 in pixels: x=396, y=352
# Landmark 6: x=0.288, y=0.491, z=-1.430, visibility=1.00
# Landmark 6 in pixels: x=369, y=353
# Landmark 7: x=0.446, y=0.515, z=-0.890, visibility=1.00
# Landmark 7 in pixels: x=570, y=370
# Landmark 8: x=0.254, y=0.527, z=-0.950, visibility=1.00
# Landmark 8 in pixels: x=324, y=379
# Landmark 9: x=0.396, y=0.683, z=-1.270, visibility=1.00
# Landmark 9 in pixels: x=507, y=491
# Landmark 10: x=0.329, y=0.694, z=-1.289, visibility=1.00
# Landmark 10 in pixels: x=421, y=499
# Landmark 11: x=0.592, y=0.984, z=-0.524, visibility=0.98
# Landmark 11 in pixels: x=757, y=708
# Landmark 12: x=0.116, y=0.948, z=-0.582, visibility=0.97
# Landmark 12 in pixels: x=147, y=682
# Landmark 13: x=0.685, y=1.517, z=-0.404, visibility=0.08
# Landmark 13 in pixels: x=876, y=1092
# Landmark 14: x=-0.065, y=1.483, z=-0.632, visibility=0.29
# Landmark 14 in pixels: x=-82, y=1067
# Landmark 15: x=0.664, y=1.854, z=-0.772, visibility=0.04
# Landmark 15 in pixels: x=849, y=1334
# Landmark 16: x=-0.003, y=1.714, z=-1.286, visibility=0.12
# Landmark 16 in pixels: x=-3, y=1234
# Landmark 17: x=0.689, y=1.988, z=-0.876, visibility=0.06
# Landmark 17 in pixels: x=881, y=1431
# Landmark 18: x=-0.000, y=1.835, z=-1.449, visibility=0.12
# Landmark 18 in pixels: x=0, y=1321
# Landmark 19: x=0.651, y=1.958, z=-0.940, visibility=0.09
# Landmark 19 in pixels: x=832, y=1410
# Landmark 20: x=0.041, y=1.775, z=-1.494, visibility=0.16
# Landmark 20 in pixels: x=52, y=1277
# Landmark 21: x=0.631, y=1.902, z=-0.818, visibility=0.08
# Landmark 21 in pixels: x=807, y=1369
# Landmark 22: x=0.046, y=1.731, z=-1.328, visibility=0.15
# Landmark 22 in pixels: x=59, y=1246
# Landmark 23: x=0.511, y=2.075, z=-0.052, visibility=0.00
# Landmark 23 in pixels: x=654, y=1493
# Landmark 24: x=0.181, y=2.083, z=0.058, visibility=0.00
# Landmark 24 in pixels: x=232, y=1499
# Landmark 25: x=0.529, y=2.941, z=-0.063, visibility=0.01
# Landmark 25 in pixels: x=677, y=2117
# Landmark 26: x=0.239, y=2.926, z=-0.248, visibility=0.00
# Landmark 26 in pixels: x=305, y=2107
# Landmark 27: x=0.540, y=3.715, z=0.587, visibility=0.00
# Landmark 27 in pixels: x=691, y=2674
# Landmark 28: x=0.264, y=3.716, z=0.229, visibility=0.00
# Landmark 28 in pixels: x=337, y=2675
# Landmark 29: x=0.547, y=3.843, z=0.608, visibility=0.00
# Landmark 29 in pixels: x=699, y=2766
# Landmark 30: x=0.263, y=3.857, z=0.254, visibility=0.00
# Landmark 30 in pixels: x=336, y=2777
# Landmark 31: x=0.489, y=3.992, z=-0.108, visibility=0.00
# Landmark 31 in pixels: x=625, y=2874
# Landmark 32: x=0.320, y=3.964, z=-0.522, visibility=0.00
# Landmark 32 in pixels: x=409, y=2853
# Landmark 0: x=0.365, y=0.594, z=-1.471, visibility=1.00
# Landmark 0 in pixels: x=467, y=427
# Landmark 1: x=0.391, y=0.490, z=-1.403, visibility=1.00
# Landmark 1 in pixels: x=500, y=352
# Landmark 2: x=0.409, y=0.488, z=-1.404, visibility=1.00
# Landmark 2 in pixels: x=523, y=351
# Landmark 3: x=0.424, y=0.487, z=-1.404, visibility=1.00
# Landmark 3 in pixels: x=542, y=350
# Landmark 4: x=0.332, y=0.490, z=-1.420, visibility=1.00
# Landmark 4 in pixels: x=425, y=352
# Landmark 5: x=0.310, y=0.489, z=-1.419, visibility=1.00
# Landmark 5 in pixels: x=396, y=351
# Landmark 6: x=0.288, y=0.489, z=-1.420, visibility=1.00
# Landmark 6 in pixels: x=368, y=352
# Landmark 7: x=0.446, y=0.515, z=-0.881, visibility=1.00
# Landmark 7 in pixels: x=570, y=370
# Landmark 8: x=0.254, y=0.526, z=-0.943, visibility=1.00
# Landmark 8 in pixels: x=324, y=378
# Landmark 9: x=0.396, y=0.682, z=-1.261, visibility=1.00
# Landmark 9 in pixels: x=506, y=490
# Landmark 10: x=0.328, y=0.692, z=-1.281, visibility=1.00
# Landmark 10 in pixels: x=420, y=498
# Landmark 11: x=0.592, y=0.983, z=-0.514, visibility=0.98
# Landmark 11 in pixels: x=757, y=707
# Landmark 12: x=0.115, y=0.948, z=-0.576, visibility=0.97
# Landmark 12 in pixels: x=146, y=682
# Landmark 13: x=0.685, y=1.514, z=-0.409, visibility=0.08
# Landmark 13 in pixels: x=876, y=1089
# Landmark 14: x=-0.068, y=1.479, z=-0.641, visibility=0.29
# Landmark 14 in pixels: x=-86, y=1064
# Landmark 15: x=0.663, y=1.843, z=-0.789, visibility=0.04
# Landmark 15 in pixels: x=848, y=1327
# Landmark 16: x=-0.004, y=1.697, z=-1.320, visibility=0.11
# Landmark 16 in pixels: x=-5, y=1221
# Landmark 17: x=0.687, y=1.977, z=-0.896, visibility=0.05
# Landmark 17 in pixels: x=879, y=1423
# Landmark 18: x=-0.001, y=1.809, z=-1.486, visibility=0.11
# Landmark 18 in pixels: x=-1, y=1302
# Landmark 19: x=0.649, y=1.943, z=-0.959, visibility=0.08
# Landmark 19 in pixels: x=831, y=1398
# Landmark 20: x=0.040, y=1.752, z=-1.529, visibility=0.16
# Landmark 20 in pixels: x=50, y=1261
# Landmark 21: x=0.630, y=1.887, z=-0.835, visibility=0.08
# Landmark 21 in pixels: x=806, y=1358
# ...
# Landmark 10 in pixels: x=391, y=517
# Landmark 11: x=0.589, y=0.951, z=-0.383, visibility=0.88
# Landmark 11 in pixels: x=753, y=684
# Landmark 12: x=0.114, y=0.945, z=-0.333, visibility=0.89
# Landmark 12 in pixels: x=146, y=680
# Landmark 13: x=0.715, y=1.345, z=-0.822, visibility=0.18
# Landmark 13 in pixels: x=915, y=968
# Landmark 14: x=-0.098, y=1.306, z=-0.939, visibility=0.37
# Landmark 14 in pixels: x=-125, y=940
# Landmark 15: x=0.651, y=1.219, z=-1.449, visibility=0.17
# Landmark 15 in pixels: x=833, y=877
# Landmark 16: x=0.008, y=0.949, z=-1.936, visibility=0.22
# Landmark 16 in pixels: x=10, y=682
# Landmark 17: x=0.648, y=1.204, z=-1.553, visibility=0.21
# Landmark 17 in pixels: x=828, y=866
# Landmark 18: x=0.037, y=0.861, z=-2.115, visibility=0.25
# Landmark 18 in pixels: x=47, y=619
# Landmark 19: x=0.630, y=1.137, z=-1.526, visibility=0.26
# Landmark 19 in pixels: x=806, y=818
# Landmark 20: x=0.053, y=0.802, z=-2.033, visibility=0.29
# Landmark 20 in pixels: x=67, y=577
# Landmark 21: x=0.620, y=1.149, z=-1.459, visibility=0.23
# Landmark 21 in pixels: x=793, y=826
# Landmark 22: x=0.053, y=0.841, z=-1.938, visibility=0.25
# Landmark 22 in pixels: x=68, y=605
# Landmark 23: x=0.513, y=2.174, z=-0.104, visibility=0.00
# Landmark 23 in pixels: x=656, y=1565
# Landmark 24: x=0.212, y=2.173, z=0.109, visibility=0.00
# Landmark 24 in pixels: x=271, y=1564
# Landmark 25: x=0.516, y=2.875, z=-0.322, visibility=0.01
# Landmark 25 in pixels: x=659, y=2070
# Landmark 26: x=0.215, y=2.799, z=-0.467, visibility=0.02
# Landmark 26 in pixels: x=274, y=2015
# Landmark 27: x=0.564, y=3.713, z=0.240, visibility=0.00
# Landmark 27 in pixels: x=722, y=2673
# Landmark 28: x=0.334, y=3.667, z=-0.045, visibility=0.00
# Landmark 28 in pixels: x=427, y=2640
# Landmark 29: x=0.578, y=3.852, z=0.259, visibility=0.00
# Landmark 29 in pixels: x=739, y=2773
# Landmark 30: x=0.357, y=3.791, z=-0.015, visibility=0.00
# Landmark 30 in pixels: x=457, y=2729
# Landmark 31: x=0.533, y=3.962, z=-0.357, visibility=0.00
# Landmark 31 in pixels: x=681, y=2852
# Landmark 32: x=0.362, y=3.948, z=-0.663, visibility=0.00
# Landmark 32 in pixels: x=463, y=2842
# Landmark 0: x=0.339, y=0.615, z=-1.294, visibility=1.00
# Landmark 0 in pixels: x=434, y=442
# Landmark 1: x=0.368, y=0.500, z=-1.220, visibility=1.00
# Landmark 1 in pixels: x=470, y=359
# Landmark 2: x=0.388, y=0.495, z=-1.220, visibility=1.00
# Landmark 2 in pixels: x=497, y=356
# Landmark 3: x=0.406, y=0.491, z=-1.220, visibility=1.00
# Landmark 3 in pixels: x=519, y=353
# Landmark 4: x=0.300, y=0.508, z=-1.226, visibility=1.00
# Landmark 4 in pixels: x=384, y=365
# Landmark 5: x=0.279, y=0.508, z=-1.227, visibility=1.00
# Landmark 5 in pixels: x=357, y=365
# Landmark 6: x=0.259, y=0.510, z=-1.227, visibility=1.00
# Landmark 6 in pixels: x=332, y=367
# Landmark 7: x=0.431, y=0.515, z=-0.667, visibility=1.00
# Landmark 7 in pixels: x=551, y=370
# Landmark 8: x=0.240, y=0.543, z=-0.688, visibility=1.00
# Landmark 8 in pixels: x=307, y=391
# Landmark 9: x=0.383, y=0.699, z=-1.073, visibility=1.00
# Landmark 9 in pixels: x=490, y=503
# Landmark 10: x=0.305, y=0.719, z=-1.081, visibility=1.00
# Landmark 10 in pixels: x=390, y=517
# Landmark 11: x=0.590, y=0.951, z=-0.345, visibility=0.89
# Landmark 11 in pixels: x=754, y=684
# Landmark 12: x=0.115, y=0.945, z=-0.304, visibility=0.89
# Landmark 12 in pixels: x=147, y=680
# Landmark 13: x=0.722, y=1.348, z=-0.785, visibility=0.18
# Landmark 13 in pixels: x=924, y=970
# Landmark 14: x=-0.104, y=1.289, z=-0.918, visibility=0.38
# Landmark 14 in pixels: x=-133, y=928
# Landmark 15: x=0.658, y=1.219, z=-1.419, visibility=0.16
# Landmark 15 in pixels: x=842, y=877
# Landmark 16: x=-0.001, y=0.938, z=-1.901, visibility=0.22
# Landmark 16 in pixels: x=-1, y=675
# Landmark 17: x=0.654, y=1.201, z=-1.528, visibility=0.21
# Landmark 17 in pixels: x=836, y=864
# Landmark 18: x=0.028, y=0.855, z=-2.076, visibility=0.24
# Landmark 18 in pixels: x=35, y=615
# Landmark 19: x=0.636, y=1.136, z=-1.498, visibility=0.25
# Landmark 19 in pixels: x=813, y=817
# Landmark 20: x=0.045, y=0.797, z=-1.995, visibility=0.29
# Landmark 20 in pixels: x=57, y=573
# Landmark 21: x=0.626, y=1.149, z=-1.427, visibility=0.22
# Landmark 21 in pixels: x=801, y=827
# Landmark 22: x=0.045, y=0.835, z=-1.902, visibility=0.25
# Landmark 22 in pixels: x=58, y=601
# Landmark 23: x=0.518, y=2.174, z=-0.104, visibility=0.00
# Landmark 23 in pixels: x=662, y=1565
# Landmark 24: x=0.216, y=2.173, z=0.108, visibility=0.00
# Landmark 24 in pixels: x=276, y=1564
# Landmark 25: x=0.521, y=2.859, z=-0.320, visibility=0.01
# Landmark 25 in pixels: x=666, y=2058
# Landmark 26: x=0.225, y=2.785, z=-0.429, visibility=0.02
# Landmark 26 in pixels: x=287, y=2005
# Landmark 27: x=0.572, y=3.697, z=0.266, visibility=0.00
# Landmark 27 in pixels: x=731, y=2662
# Landmark 28: x=0.341, y=3.651, z=-0.010, visibility=0.00
# Landmark 28 in pixels: x=436, y=2628
# Landmark 29: x=0.587, y=3.840, z=0.287, visibility=0.00
# Landmark 29 in pixels: x=750, y=2764
# Landmark 30: x=0.364, y=3.773, z=0.013, visibility=0.00
# Landmark 30 in pixels: x=465, y=2716
# Landmark 31: x=0.537, y=3.936, z=-0.321, visibility=0.00
# Landmark 31 in pixels: x=686, y=2833
# Landmark 32: x=0.362, y=3.934, z=-0.615, visibility=0.00
# Landmark 32 in pixels: x=462, y=2832
# Landmark 0: x=0.338, y=0.614, z=-1.266, visibility=1.00
# Landmark 0 in pixels: x=433, y=442
# Landmark 1: x=0.366, y=0.499, z=-1.193, visibility=1.00
# Landmark 1 in pixels: x=469, y=359
# Landmark 2: x=0.387, y=0.494, z=-1.193, visibility=1.00
# Landmark 2 in pixels: x=495, y=355
# Landmark 3: x=0.405, y=0.490, z=-1.193, visibility=1.00
# Landmark 3 in pixels: x=518, y=352
# Landmark 4: x=0.299, y=0.507, z=-1.200, visibility=1.00
# Landmark 4 in pixels: x=383, y=365
# Landmark 5: x=0.278, y=0.508, z=-1.200, visibility=1.00
# Landmark 5 in pixels: x=355, y=365
# Landmark 6: x=0.259, y=0.510, z=-1.201, visibility=1.00
# Landmark 6 in pixels: x=331, y=367
# Landmark 7: x=0.430, y=0.514, z=-0.645, visibility=1.00
# Landmark 7 in pixels: x=550, y=370
# Landmark 8: x=0.240, y=0.543, z=-0.667, visibility=1.00
# Landmark 8 in pixels: x=306, y=391
# Landmark 9: x=0.382, y=0.699, z=-1.047, visibility=1.00
# Landmark 9 in pixels: x=489, y=503
# Landmark 10: x=0.304, y=0.718, z=-1.055, visibility=1.00
# Landmark 10 in pixels: x=389, y=517
# Landmark 11: x=0.591, y=0.951, z=-0.326, visibility=0.89
# Landmark 11 in pixels: x=756, y=684
# Landmark 12: x=0.115, y=0.946, z=-0.303, visibility=0.89
# Landmark 12 in pixels: x=147, y=681
# Landmark 13: x=0.724, y=1.353, z=-0.754, visibility=0.18
# Landmark 13 in pixels: x=927, y=974
# Landmark 14: x=-0.104, y=1.294, z=-0.913, visibility=0.39
# Landmark 14 in pixels: x=-133, y=931
# Landmark 15: x=0.661, y=1.245, z=-1.403, visibility=0.16
# Landmark 15 in pixels: x=846, y=896
# Landmark 16: x=-0.008, y=0.954, z=-1.891, visibility=0.22
# Landmark 16 in pixels: x=-10, y=686
# Landmark 17: x=0.656, y=1.238, z=-1.516, visibility=0.20
# Landmark 17 in pixels: x=840, y=891
# Landmark 18: x=0.017, y=0.877, z=-2.070, visibility=0.24
# Landmark 18 in pixels: x=21, y=631
# Landmark 19: x=0.638, y=1.170, z=-1.496, visibility=0.25
# Landmark 19 in pixels: x=816, y=842
# Landmark 20: x=0.033, y=0.818, z=-1.994, visibility=0.29
# Landmark 20 in pixels: x=42, y=589
# Landmark 21: x=0.628, y=1.177, z=-1.416, visibility=0.21
# Landmark 21 in pixels: x=803, y=847
# Landmark 22: x=0.035, y=0.853, z=-1.895, visibility=0.25
# Landmark 22 in pixels: x=44, y=614
# Landmark 23: x=0.521, y=2.174, z=-0.091, visibility=0.00
# Landmark 23 in pixels: x=666, y=1565
# Landmark 24: x=0.217, y=2.173, z=0.096, visibility=0.00
# Landmark 24 in pixels: x=277, y=1564
# Landmark 25: x=0.527, y=2.928, z=-0.281, visibility=0.02
# Landmark 25 in pixels: x=675, y=2108
# Landmark 26: x=0.239, y=2.859, z=-0.394, visibility=0.02
# Landmark 26 in pixels: x=305, y=2058
# Landmark 27: x=0.577, y=3.759, z=0.293, visibility=0.00
# Landmark 27 in pixels: x=738, y=2706
# Landmark 28: x=0.342, y=3.726, z=-0.005, visibility=0.00
# Landmark 28 in pixels: x=437, y=2682
# Landmark 29: x=0.590, y=3.896, z=0.312, visibility=0.00
# Landmark 29 in pixels: x=755, y=2804
# Landmark 30: x=0.363, y=3.851, z=0.013, visibility=0.00
# Landmark 30 in pixels: x=464, y=2772
# Landmark 31: x=0.543, y=4.011, z=-0.315, visibility=0.00
# Landmark 31 in pixels: x=695, y=2887
# Landmark 32: x=0.367, y=4.005, z=-0.623, visibility=0.00
# Landmark 32 in pixels: x=469, y=2883
# Landmark 0: x=0.337, y=0.613, z=-1.181, visibility=1.00
# Landmark 0 in pixels: x=431, y=441
# Landmark 1: x=0.366, y=0.499, z=-1.107, visibility=1.00
# Landmark 1 in pixels: x=468, y=359
# Landmark 2: x=0.387, y=0.494, z=-1.107, visibility=1.00
# Landmark 2 in pixels: x=495, y=355
# Landmark 3: x=0.405, y=0.490, z=-1.107, visibility=1.00
# Landmark 3 in pixels: x=517, y=352
# Landmark 4: x=0.298, y=0.506, z=-1.108, visibility=1.00
# Landmark 4 in pixels: x=382, y=364
# Landmark 5: x=0.277, y=0.507, z=-1.109, visibility=1.00
# Landmark 5 in pixels: x=355, y=365
# Landmark 6: x=0.258, y=0.509, z=-1.109, visibility=1.00
# Landmark 6 in pixels: x=330, y=366
# Landmark 7: x=0.430, y=0.514, z=-0.569, visibility=1.00
# Landmark 7 in pixels: x=550, y=370
# Landmark 8: x=0.240, y=0.542, z=-0.567, visibility=1.00
# Landmark 8 in pixels: x=306, y=390
# Landmark 9: x=0.382, y=0.698, z=-0.967, visibility=1.00
# Landmark 9 in pixels: x=488, y=502
# Landmark 10: x=0.303, y=0.716, z=-0.970, visibility=1.00
# Landmark 10 in pixels: x=387, y=515
# Landmark 11: x=0.591, y=0.951, z=-0.292, visibility=0.89
# Landmark 11 in pixels: x=756, y=684
# Landmark 12: x=0.116, y=0.945, z=-0.230, visibility=0.90
# Landmark 12 in pixels: x=148, y=680
# Landmark 13: x=0.703, y=1.351, z=-0.744, visibility=0.18
# Landmark 13 in pixels: x=899, y=972
# Landmark 14: x=-0.094, y=1.293, z=-0.881, visibility=0.39
# Landmark 14 in pixels: x=-119, y=931
# Landmark 15: x=0.624, y=1.239, z=-1.348, visibility=0.15
# Landmark 15 in pixels: x=798, y=891
# Landmark 16: x=0.018, y=0.957, z=-1.879, visibility=0.22
# Landmark 16 in pixels: x=22, y=689
# Landmark 17: x=0.614, y=1.225, z=-1.458, visibility=0.19
# Landmark 17 in pixels: x=785, y=881
# Landmark 18: x=0.050, y=0.887, z=-2.058, visibility=0.24
# Landmark 18 in pixels: x=64, y=638
# Landmark 19: x=0.596, y=1.159, z=-1.430, visibility=0.24
# Landmark 19 in pixels: x=762, y=834
# Landmark 20: x=0.064, y=0.829, z=-1.980, visibility=0.29
# Landmark 20 in pixels: x=82, y=596
# Landmark 21: x=0.589, y=1.169, z=-1.356, visibility=0.21
# Landmark 21 in pixels: x=754, y=841
# Landmark 22: x=0.062, y=0.862, z=-1.882, visibility=0.25
# Landmark 22 in pixels: x=79, y=620
# Landmark 23: x=0.520, y=2.169, z=-0.092, visibility=0.00
# Landmark 23 in pixels: x=665, y=1561
# Landmark 24: x=0.218, y=2.167, z=0.097, visibility=0.00
# Landmark 24 in pixels: x=278, y=1559
# Landmark 25: x=0.524, y=2.874, z=-0.304, visibility=0.02
# Landmark 25 in pixels: x=671, y=2069
# Landmark 26: x=0.233, y=2.823, z=-0.381, visibility=0.02
# Landmark 26 in pixels: x=298, y=2032
# Landmark 27: x=0.574, y=3.717, z=0.249, visibility=0.00
# Landmark 27 in pixels: x=734, y=2676
# Landmark 28: x=0.341, y=3.682, z=-0.014, visibility=0.00
# Landmark 28 in pixels: x=436, y=2651
# Landmark 29: x=0.587, y=3.859, z=0.261, visibility=0.00
# Landmark 29 in pixels: x=751, y=2778
# Landmark 30: x=0.362, y=3.806, z=0.010, visibility=0.00
# Landmark 30 in pixels: x=463, y=2740
# Landmark 31: x=0.541, y=3.960, z=-0.364, visibility=0.00
# Landmark 31 in pixels: x=692, y=2851
# Landmark 32: x=0.366, y=3.958, z=-0.630, visibility=0.00
# Landmark 32 in pixels: x=468, y=2849
# Landmark 0: x=0.336, y=0.612, z=-1.160, visibility=1.00
# Landmark 0 in pixels: x=429, y=440
# Landmark 1: x=0.365, y=0.499, z=-1.087, visibility=1.00
# Landmark 1 in pixels: x=467, y=359
# Landmark 2: x=0.386, y=0.494, z=-1.087, visibility=1.00
# Landmark 2 in pixels: x=494, y=355
# Landmark 3: x=0.404, y=0.490, z=-1.088, visibility=1.00
# Landmark 3 in pixels: x=517, y=352
# Landmark 4: x=0.298, y=0.506, z=-1.089, visibility=1.00
# Landmark 4 in pixels: x=381, y=364
# Landmark 5: x=0.277, y=0.506, z=-1.089, visibility=1.00
# Landmark 5 in pixels: x=354, y=364
# Landmark 6: x=0.258, y=0.508, z=-1.089, visibility=1.00
# Landmark 6 in pixels: x=330, y=365
# Landmark 7: x=0.430, y=0.514, z=-0.554, visibility=1.00
# Landmark 7 in pixels: x=550, y=370
# Landmark 8: x=0.240, y=0.541, z=-0.551, visibility=1.00
# Landmark 8 in pixels: x=306, y=389
# Landmark 9: x=0.381, y=0.697, z=-0.948, visibility=1.00
# Landmark 9 in pixels: x=487, y=501
# Landmark 10: x=0.302, y=0.715, z=-0.950, visibility=1.00
# Landmark 10 in pixels: x=386, y=515
# Landmark 11: x=0.590, y=0.951, z=-0.285, visibility=0.89
# Landmark 11 in pixels: x=755, y=684
# Landmark 12: x=0.116, y=0.944, z=-0.217, visibility=0.90
# Landmark 12 in pixels: x=148, y=679
# Landmark 13: x=0.688, y=1.351, z=-0.737, visibility=0.17
# Landmark 13 in pixels: x=881, y=972
# Landmark 14: x=-0.087, y=1.293, z=-0.873, visibility=0.39
# Landmark 14 in pixels: x=-110, y=930
# Landmark 15: x=0.601, y=1.233, z=-1.319, visibility=0.15
# Landmark 15 in pixels: x=768, y=887
# Landmark 16: x=0.034, y=0.958, z=-1.866, visibility=0.22
# Landmark 16 in pixels: x=44, y=690
# Landmark 17: x=0.589, y=1.217, z=-1.424, visibility=0.19
# Landmark 17 in pixels: x=754, y=875
# Landmark 18: x=0.070, y=0.890, z=-2.041, visibility=0.24
# Landmark 18 in pixels: x=89, y=640
# Landmark 19: x=0.572, y=1.153, z=-1.392, visibility=0.23
# Landmark 19 in pixels: x=731, y=830
# Landmark 20: x=0.084, y=0.832, z=-1.961, visibility=0.29
# Landmark 20 in pixels: x=107, y=599
# Landmark 21: x=0.567, y=1.163, z=-1.324, visibility=0.20
# Landmark 21 in pixels: x=725, y=837
# Landmark 22: x=0.081, y=0.865, z=-1.867, visibility=0.25
# Landmark 22 in pixels: x=103, y=623
# Landmark 23: x=0.520, y=2.165, z=-0.093, visibility=0.00
# Landmark 23 in pixels: x=665, y=1558
# Landmark 24: x=0.218, y=2.162, z=0.097, visibility=0.00
# Landmark 24 in pixels: x=278, y=1556
# Landmark 25: x=0.524, y=2.857, z=-0.321, visibility=0.02
# Landmark 25 in pixels: x=670, y=2056
# Landmark 26: x=0.231, y=2.821, z=-0.328, visibility=0.02
# Landmark 26 in pixels: x=295, y=2031
# Landmark 27: x=0.571, y=3.707, z=0.242, visibility=0.00
# Landmark 27 in pixels: x=731, y=2669
# Landmark 28: x=0.339, y=3.675, z=-0.000, visibility=0.00
# Landmark 28 in pixels: x=433, y=2646
# Landmark 29: x=0.585, y=3.851, z=0.251, visibility=0.00
# Landmark 29 in pixels: x=748, y=2772
# Landmark 30: x=0.357, y=3.799, z=0.015, visibility=0.00
# Landmark 30 in pixels: x=456, y=2735
# Landmark 31: x=0.537, y=3.950, z=-0.367, visibility=0.00
# Landmark 31 in pixels: x=687, y=2844
# Landmark 32: x=0.363, y=3.948, z=-0.606, visibility=0.00
# Landmark 32 in pixels: x=465, y=2842
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 45
#      42 rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#      44 # Perform pose detection.
# ---> 45 results = pose_video.process(rgb_frame)
#      47 # If landmarks are detected, process them.
#      48 if results.pose_landmarks:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mediapipe\python\solutions\pose.py:185, in Pose.process(self, image)
#     164 def process(self, image: np.ndarray) -> NamedTuple:
#     165   """Processes an RGB image and returns the pose landmarks on the most prominent person detected.
#     166
#     167   Args:
#    (...)
#     182          "enable_segmentation" is set to true.
#     183   """
# --> 185   results = super().process(input_data={'image': image})
#     186   if results.pose_landmarks:  # pytype: disable=attribute-error
#     187     for landmark in results.pose_landmarks.landmark:  # pytype: disable=attribute-error
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mediapipe\python\solution_base.py:340, in SolutionBase.process(self, input_data)
#     334   else:
#     335     self._graph.add_packet_to_input_stream(
#     336         stream=stream_name,
#     337         packet=self._make_packet(input_stream_type,
#     338                                  data).at(self._simulated_timestamp))
# --> 340 self._graph.wait_until_idle()
#     341 # Create a NamedTuple object where the field names are mapping to the graph
#     342 # output stream names.
#     343 if self._output_stream_type_info is None:
#
# KeyboardInterrupt:

# %%
for lndmrk in mp_pose.PoseLandmark:
    print(f"{lndmrk.value}: {lndmrk.name}")
# Out:
# 0: NOSE
# 1: LEFT_EYE_INNER
# 2: LEFT_EYE
# 3: LEFT_EYE_OUTER
# 4: RIGHT_EYE_INNER
# 5: RIGHT_EYE
# 6: RIGHT_EYE_OUTER
# 7: LEFT_EAR
# 8: RIGHT_EAR
# 9: MOUTH_LEFT
# 10: MOUTH_RIGHT
# 11: LEFT_SHOULDER
# 12: RIGHT_SHOULDER
# 13: LEFT_ELBOW
# 14: RIGHT_ELBOW
# 15: LEFT_WRIST
# 16: RIGHT_WRIST
# 17: LEFT_PINKY
# 18: RIGHT_PINKY
# 19: LEFT_INDEX
# 20: RIGHT_INDEX
# 21: LEFT_THUMB
# 22: RIGHT_THUMB
# 23: LEFT_HIP
# 24: RIGHT_HIP
# 25: LEFT_KNEE
# 26: RIGHT_KNEE
# 27: LEFT_ANKLE
# 28: RIGHT_ANKLE
# 29: LEFT_HEEL
# 30: RIGHT_HEEL
# 31: LEFT_FOOT_INDEX
# 32: RIGHT_FOOT_INDEX

# %%
landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value]
# Out:
# x: 0.688451707
# y: 1.35051668
# z: -0.736725926
# visibility: 0.173643559

# %%
def calculate_angle(a, b, c):
    """
    Calculate the angle between three points using the cosine rule.
    
    Args:
        a: First point (x, y).
        b: Second point (x, y) - the joint point.
        c: Third point (x, y).
    
    Returns:
        angle: Angle in degrees.
    """
    a = np.array(a)
    b = np.array(b)
    c = np.array(c)

    # Calculate vectors
    ba = a - b
    bc = c - b

    # Calculate cosine angle using dot product
    cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
    
    # Convert from radians to degrees
    angle = np.degrees(np.arccos(cosine_angle))
    
    return angle

# Extract landmark coordinates
left_shoulder = (landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x * frame_width, 
                 landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y * frame_height)

left_elbow = (landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x * frame_width, 
              landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y * frame_height)

left_wrist = (landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x * frame_width, 
              landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y * frame_height)

# Calculate the angle
elbow_angle = calculate_angle(left_shoulder, left_elbow, left_wrist)

print(f"Left Elbow Angle: {elbow_angle:.2f} degrees")
# Out:
# Left Elbow Angle: 29.44 degrees

# %%
print("hello world")
# Out:
# hello world
