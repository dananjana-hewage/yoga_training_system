# %%
import math
from pickle import FALSE

import cv2
import numpy as np
from time import time
import mediapipe as mp
import matplotlib.pyplot as plt
from numpy.ma.core import left_shift

# %%
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

pose = mp_pose.Pose(
    static_image_mode=True,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5,
    model_complexity = 1
)
###################

# %%
def detectPose(image, pose, display=True):
    '''
    Perform pose detection on an image.
    Args:
        image: Input image with a prominent person for pose detection.
        pose: Mediapipe pose function for detection.
        display: If True, display the images and landmarks.
    Returns:
        output_image: Image with detected pose landmarks drawn.
        landmarks: List of detected landmarks in original scale.
    '''
    # Create a copy of the input image.
    output_image = image.copy()

    # Convert BGR to RGB format.
    imageRGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Perform Pose Detection.
    results = pose.process(imageRGB)

    # Retrieve the image dimensions.
    height, width, _ = image.shape

    # Initialize list for landmarks.
    landmarks = []

    # If landmarks are detected.
    if results.pose_landmarks:
        # Draw Pose landmarks on the image.
        mp_drawing.draw_landmarks(
            image=output_image,
            landmark_list=results.pose_landmarks,
            connections=mp_pose.POSE_CONNECTIONS
        )

        # Save the landmarks.
        for landmark in results.pose_landmarks.landmark:
            landmarks.append((int(landmark.x * width), int(landmark.y * height), landmark.z * width))

    # Display results if requested.
    if display:
        plt.figure(figsize=[22, 22])
        plt.subplot(121);
        plt.imshow(image[:, :, ::-1]);
        plt.title("Original Image");
        plt.axis('off');
        plt.subplot(122);
        plt.imshow(output_image[:, :, ::-1]);
        plt.title("Output Image");
        plt.axis('off');
        mp_drawing.plot_landmarks(results.pose_world_landmarks, mp_pose.POSE_CONNECTIONS)
    else:
        return output_image, landmarks

# %%
# Initialize Pose function for video.
pose_video = mp_pose.Pose(
    static_image_mode=False,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5,
    model_complexity=1
)

# Open the webcam (change index to 1 if another camera is used).
video = cv2.VideoCapture(0)

# Create named window for resizing.
cv2.namedWindow('Pose Detection', cv2.WINDOW_NORMAL)

# Set video resolution.
video.set(3, 1280)  # Width
video.set(4, 960)  # Height

# Initialize time for FPS calculation.
time1 = 0

# Video capture loop.
while video.isOpened():
    # Read a frame.
    ok, frame = video.read()

    # If frame is not read properly, break the loop.
    if not ok:
        print("Error: Unable to read frame.")
        break

    # Flip the frame horizontally for natural view.
    frame = cv2.flip(frame, 1)

    # Resize the frame.
    frame_height, frame_width, _ = frame.shape
    frame = cv2.resize(frame, (int(frame_width * (640 / frame_height)), 640))

    # Perform pose detection.
    try:
        # Convert the frame to RGB for processing.
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Perform pose detection.
        results = pose_video.process(rgb_frame)

        # If landmarks are detected, process them.
        if results.pose_landmarks:
            landmarks = results.pose_landmarks.landmark

            # Print and optionally process landmarks.
            for i, landmark in enumerate(landmarks):
                print(
                    f"Landmark {i}: x={landmark.x:.3f}, y={landmark.y:.3f}, z={landmark.z:.3f}, visibility={landmark.visibility:.2f}"
                )

                # Optionally, convert normalized coordinates to pixels.
                pixel_x = int(landmark.x * frame_width)
                pixel_y = int(landmark.y * frame_height)
                print(f"Landmark {i} in pixels: x={pixel_x}, y={pixel_y}")

            # Draw pose landmarks on the frame.
            mp_drawing.draw_landmarks(
                frame,
                results.pose_landmarks,
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
            )

    except Exception as e:
        print("Error during pose detection:", e)
        continue

    # Calculate and display FPS.
    time2 = time()
    if (time2 - time1) > 0:
        fps = 1.0 / (time2 - time1)
        cv2.putText(frame, f'FPS: {int(fps)}', (10, 30), cv2.FONT_HERSHEY_PLAIN, 2, (0, 255, 0), 3)
    time1 = time2

    # Display the frame.
    cv2.imshow('Pose Detection', frame)

    # Break on 'ESC' key press.
    if cv2.waitKey(1) & 0xFF == 27:
        break

# Release the video capture object and close windows.
video.release()
cv2.destroyAllWindows()
# Out:
# Landmark 0: x=0.633, y=0.687, z=-0.779, visibility=0.98
# Landmark 0 in pixels: x=810, y=494
# Landmark 1: x=0.659, y=0.606, z=-0.776, visibility=0.97
# Landmark 1 in pixels: x=843, y=436
# Landmark 2: x=0.673, y=0.600, z=-0.776, visibility=0.97
# Landmark 2 in pixels: x=861, y=432
# Landmark 3: x=0.687, y=0.596, z=-0.777, visibility=0.97
# Landmark 3 in pixels: x=879, y=429
# Landmark 4: x=0.620, y=0.620, z=-0.753, visibility=0.97
# Landmark 4 in pixels: x=793, y=446
# Landmark 5: x=0.608, y=0.623, z=-0.753, visibility=0.96
# Landmark 5 in pixels: x=778, y=448
# Landmark 6: x=0.600, y=0.626, z=-0.753, visibility=0.97
# Landmark 6 in pixels: x=768, y=450
# Landmark 7: x=0.710, y=0.618, z=-0.584, visibility=0.98
# Landmark 7 in pixels: x=908, y=444
# Landmark 8: x=0.609, y=0.644, z=-0.462, visibility=0.97
# Landmark 8 in pixels: x=779, y=463
# Landmark 9: x=0.668, y=0.735, z=-0.696, visibility=0.99
# Landmark 9 in pixels: x=854, y=529
# Landmark 10: x=0.624, y=0.738, z=-0.662, visibility=0.98
# Landmark 10 in pixels: x=798, y=531
# Landmark 11: x=0.846, y=0.936, z=-0.460, visibility=0.98
# Landmark 11 in pixels: x=1082, y=673
# Landmark 12: x=0.542, y=0.854, z=-0.298, visibility=0.99
# Landmark 12 in pixels: x=694, y=614
# Landmark 13: x=0.929, y=1.277, z=-0.561, visibility=0.13
# Landmark 13 in pixels: x=1188, y=919
# Landmark 14: x=0.376, y=0.950, z=-0.433, visibility=0.87
# Landmark 14 in pixels: x=481, y=684
# Landmark 15: x=0.927, y=1.538, z=-0.789, visibility=0.03
# Landmark 15 in pixels: x=1187, y=1107
# Landmark 16: x=0.263, y=0.686, z=-0.804, visibility=0.75
# Landmark 16 in pixels: x=336, y=494
# Landmark 17: x=0.943, y=1.644, z=-0.850, visibility=0.03
# Landmark 17 in pixels: x=1207, y=1183
# Landmark 18: x=0.224, y=0.604, z=-0.880, visibility=0.52
# Landmark 18 in pixels: x=286, y=435
# Landmark 19: x=0.914, y=1.611, z=-0.879, visibility=0.04
# Landmark 19 in pixels: x=1170, y=1159
# Landmark 20: x=0.228, y=0.584, z=-0.909, visibility=0.61
# Landmark 20 in pixels: x=292, y=420
# Landmark 21: x=0.901, y=1.570, z=-0.814, visibility=0.05
# Landmark 21 in pixels: x=1153, y=1130
# Landmark 22: x=0.249, y=0.623, z=-0.837, visibility=0.64
# Landmark 22 in pixels: x=319, y=448
# Landmark 23: x=0.787, y=1.640, z=-0.085, visibility=0.00
# Landmark 23 in pixels: x=1007, y=1180
# Landmark 24: x=0.571, y=1.630, z=0.088, visibility=0.00
# Landmark 24 in pixels: x=730, y=1173
# Landmark 25: x=0.764, y=2.202, z=-0.148, visibility=0.00
# Landmark 25 in pixels: x=978, y=1585
# Landmark 26: x=0.563, y=2.185, z=0.018, visibility=0.00
# Landmark 26 in pixels: x=720, y=1573
# Landmark 27: x=0.745, y=2.726, z=0.266, visibility=0.00
# Landmark 27 in pixels: x=953, y=1962
# Landmark 28: x=0.543, y=2.714, z=0.256, visibility=0.00
# Landmark 28 in pixels: x=695, y=1954
# Landmark 29: x=0.751, y=2.805, z=0.287, visibility=0.00
# Landmark 29 in pixels: x=961, y=2019
# Landmark 30: x=0.537, y=2.797, z=0.272, visibility=0.00
# Landmark 30 in pixels: x=687, y=2013
# Landmark 31: x=0.704, y=2.903, z=-0.124, visibility=0.00
# Landmark 31 in pixels: x=900, y=2090
# Landmark 32: x=0.561, y=2.893, z=-0.174, visibility=0.00
# Landmark 32 in pixels: x=718, y=2083
# Landmark 0: x=0.631, y=0.698, z=-0.784, visibility=0.99
# Landmark 0 in pixels: x=807, y=502
# Landmark 1: x=0.657, y=0.616, z=-0.775, visibility=0.98
# Landmark 1 in pixels: x=840, y=443
# Landmark 2: x=0.673, y=0.608, z=-0.775, visibility=0.98
# Landmark 2 in pixels: x=861, y=438
# Landmark 3: x=0.688, y=0.603, z=-0.776, visibility=0.98
# Landmark 3 in pixels: x=880, y=434
# Landmark 4: x=0.614, y=0.630, z=-0.754, visibility=0.97
# Landmark 4 in pixels: x=786, y=453
# Landmark 5: x=0.602, y=0.632, z=-0.753, visibility=0.97
# Landmark 5 in pixels: x=770, y=454
# Landmark 6: x=0.592, y=0.634, z=-0.754, visibility=0.97
# Landmark 6 in pixels: x=758, y=456
# Landmark 7: x=0.714, y=0.619, z=-0.506, visibility=0.98
# Landmark 7 in pixels: x=914, y=445
# Landmark 8: x=0.594, y=0.645, z=-0.411, visibility=0.97
# Landmark 8 in pixels: x=760, y=464
# Landmark 9: x=0.668, y=0.747, z=-0.683, visibility=0.99
# Landmark 9 in pixels: x=854, y=538
# Landmark 10: x=0.619, y=0.757, z=-0.655, visibility=0.98
# Landmark 10 in pixels: x=792, y=544
# Landmark 11: x=0.848, y=0.939, z=-0.310, visibility=0.98
# Landmark 11 in pixels: x=1084, y=675
# Landmark 12: x=0.534, y=0.854, z=-0.208, visibility=0.99
# Landmark 12 in pixels: x=683, y=614
# Landmark 13: x=0.924, y=1.280, z=-0.385, visibility=0.14
# Landmark 13 in pixels: x=1183, y=921
# Landmark 14: x=0.423, y=1.188, z=-0.362, visibility=0.80
# Landmark 14 in pixels: x=541, y=855
# Landmark 15: x=0.897, y=1.562, z=-0.651, visibility=0.03
# Landmark 15 in pixels: x=1148, y=1124
# Landmark 16: x=0.404, y=1.360, z=-0.968, visibility=0.68
# Landmark 16 in pixels: x=516, y=979
# Landmark 17: x=0.914, y=1.675, z=-0.727, visibility=0.03
# Landmark 17 in pixels: x=1169, y=1205
# Landmark 18: x=0.377, y=1.446, z=-1.086, visibility=0.47
# Landmark 18 in pixels: x=483, y=1041
# Landmark 19: x=0.873, y=1.669, z=-0.757, visibility=0.04
# Landmark 19 in pixels: x=1117, y=1202
# Landmark 20: x=0.409, y=1.431, z=-1.120, visibility=0.56
# Landmark 20 in pixels: x=523, y=1030
# Landmark 21: x=0.864, y=1.625, z=-0.674, visibility=0.05
# Landmark 21 in pixels: x=1105, y=1170
# Landmark 22: x=0.422, y=1.400, z=-1.004, visibility=0.58
# Landmark 22 in pixels: x=539, y=1007
# Landmark 23: x=0.776, y=1.639, z=-0.079, visibility=0.00
# Landmark 23 in pixels: x=993, y=1179
# Landmark 24: x=0.557, y=1.626, z=0.083, visibility=0.00
# Landmark 24 in pixels: x=712, y=1171
# Landmark 25: x=0.749, y=2.212, z=0.078, visibility=0.00
# Landmark 25 in pixels: x=958, y=1592
# Landmark 26: x=0.533, y=2.188, z=0.422, visibility=0.00
# Landmark 26 in pixels: x=681, y=1575
# Landmark 27: x=0.722, y=2.729, z=0.605, visibility=0.00
# Landmark 27 in pixels: x=924, y=1964
# Landmark 28: x=0.509, y=2.714, z=1.021, visibility=0.00
# Landmark 28 in pixels: x=651, y=1954
# Landmark 29: x=0.728, y=2.813, z=0.633, visibility=0.00
# Landmark 29 in pixels: x=932, y=2025
# Landmark 30: x=0.507, y=2.797, z=1.070, visibility=0.00
# Landmark 30 in pixels: x=648, y=2013
# Landmark 31: x=0.665, y=2.908, z=0.159, visibility=0.00
# Landmark 31 in pixels: x=850, y=2094
# Landmark 32: x=0.532, y=2.899, z=0.583, visibility=0.00
# Landmark 32 in pixels: x=681, y=2087
# Landmark 0: x=0.629, y=0.702, z=-0.737, visibility=0.99
# Landmark 0 in pixels: x=804, y=505
# Landmark 1: x=0.655, y=0.618, z=-0.719, visibility=0.98
# Landmark 1 in pixels: x=838, y=445
# Landmark 2: x=0.673, y=0.611, z=-0.719, visibility=0.98
# Landmark 2 in pixels: x=861, y=439
# Landmark 3: x=0.688, y=0.605, z=-0.719, visibility=0.98
# Landmark 3 in pixels: x=880, y=435
# Landmark 4: x=0.611, y=0.632, z=-0.705, visibility=0.97
# Landmark 4 in pixels: x=781, y=455
# Landmark 5: x=0.599, y=0.634, z=-0.704, visibility=0.97
# Landmark 5 in pixels: x=766, y=456
# Landmark 6: x=0.588, y=0.636, z=-0.704, visibility=0.97
# Landmark 6 in pixels: x=753, y=457
# Landmark 7: x=0.716, y=0.619, z=-0.449, visibility=0.99
# Landmark 7 in pixels: x=916, y=445
# Landmark 8: x=0.588, y=0.645, z=-0.364, visibility=0.98
# Landmark 8 in pixels: x=752, y=464
# Landmark 9: x=0.667, y=0.750, z=-0.625, visibility=0.99
# Landmark 9 in pixels: x=854, y=540
# Landmark 10: x=0.616, y=0.762, z=-0.602, visibility=0.99
# Landmark 10 in pixels: x=788, y=548
# Landmark 11: x=0.849, y=0.941, z=-0.257, visibility=0.98
# Landmark 11 in pixels: x=1086, y=677
# Landmark 12: x=0.528, y=0.854, z=-0.183, visibility=0.99
# Landmark 12 in pixels: x=675, y=614
# Landmark 13: x=0.917, y=1.299, z=-0.325, visibility=0.15
# Landmark 13 in pixels: x=1173, y=935
# Landmark 14: x=0.421, y=1.222, z=-0.338, visibility=0.75
# Landmark 14 in pixels: x=538, y=879
# Landmark 15: x=0.880, y=1.591, z=-0.580, visibility=0.03
# Landmark 15 in pixels: x=1126, y=1145
# Landmark 16: x=0.383, y=1.424, z=-0.949, visibility=0.61
# Landmark 16 in pixels: x=490, y=1025
# Landmark 17: x=0.895, y=1.705, z=-0.647, visibility=0.03
# Landmark 17 in pixels: x=1146, y=1227
# Landmark 18: x=0.350, y=1.513, z=-1.060, visibility=0.43
# Landmark 18 in pixels: x=448, y=1089
# Landmark 19: x=0.853, y=1.706, z=-0.671, visibility=0.04
# Landmark 19 in pixels: x=1091, y=1228
# Landmark 20: x=0.382, y=1.506, z=-1.096, visibility=0.51
# Landmark 20 in pixels: x=489, y=1084
# Landmark 21: x=0.844, y=1.661, z=-0.601, visibility=0.05
# Landmark 21 in pixels: x=1080, y=1195
# Landmark 22: x=0.399, y=1.474, z=-0.986, visibility=0.53
# Landmark 22 in pixels: x=510, y=1060
# Landmark 23: x=0.771, y=1.638, z=-0.067, visibility=0.00
# Landmark 23 in pixels: x=987, y=1179
# Landmark 24: x=0.546, y=1.626, z=0.071, visibility=0.00
# Landmark 24 in pixels: x=698, y=1170
# Landmark 25: x=0.739, y=2.222, z=0.043, visibility=0.00
# Landmark 25 in pixels: x=946, y=1599
# Landmark 26: x=0.520, y=2.195, z=0.386, visibility=0.00
# Landmark 26 in pixels: x=665, y=1580
# Landmark 27: x=0.714, y=2.738, z=0.517, visibility=0.00
# Landmark 27 in pixels: x=913, y=1971
# Landmark 28: x=0.501, y=2.716, z=0.909, visibility=0.00
# Landmark 28 in pixels: x=640, y=1955
# Landmark 29: x=0.721, y=2.829, z=0.541, visibility=0.00
# Landmark 29 in pixels: x=922, y=2036
# Landmark 30: x=0.499, y=2.802, z=0.951, visibility=0.00
# Landmark 30 in pixels: x=638, y=2017
# Landmark 31: x=0.654, y=2.917, z=0.085, visibility=0.00
# Landmark 31 in pixels: x=837, y=2100
# Landmark 32: x=0.526, y=2.909, z=0.483, visibility=0.00
# Landmark 32 in pixels: x=672, y=2094
# Landmark 0: x=0.628, y=0.707, z=-0.710, visibility=0.99
# Landmark 0 in pixels: x=804, y=509
# Landmark 1: x=0.655, y=0.623, z=-0.694, visibility=0.98
# Landmark 1 in pixels: x=838, y=448
# Landmark 2: x=0.673, y=0.615, z=-0.694, visibility=0.98
# Landmark 2 in pixels: x=861, y=442
# Landmark 3: x=0.689, y=0.609, z=-0.694, visibility=0.98
# Landmark 3 in pixels: x=881, y=438
# Landmark 4: x=0.610, y=0.638, z=-0.678, visibility=0.97
# Landmark 4 in pixels: x=780, y=459
# Landmark 5: x=0.598, y=0.639, z=-0.677, visibility=0.97
# Landmark 5 in pixels: x=765, y=460
# Landmark 6: x=0.587, y=0.641, z=-0.677, visibility=0.98
# Landmark 6 in pixels: x=751, y=461
# Landmark 7: x=0.718, y=0.620, z=-0.436, visibility=0.99
# Landmark 7 in pixels: x=918, y=446
# Landmark 8: x=0.586, y=0.647, z=-0.336, visibility=0.98
# Landmark 8 in pixels: x=749, y=465
# Landmark 9: x=0.667, y=0.755, z=-0.602, visibility=0.99
# Landmark 9 in pixels: x=854, y=543
# Landmark 10: x=0.614, y=0.769, z=-0.574, visibility=0.99
# Landmark 10 in pixels: x=786, y=553
# Landmark 11: x=0.851, y=0.947, z=-0.279, visibility=0.98
# Landmark 11 in pixels: x=1089, y=681
# Landmark 12: x=0.526, y=0.857, z=-0.154, visibility=0.99
# Landmark 12 in pixels: x=673, y=616
# Landmark 13: x=0.915, y=1.300, z=-0.365, visibility=0.16
# Landmark 13 in pixels: x=1170, y=935
# Landmark 14: x=0.428, y=1.227, z=-0.324, visibility=0.69
# Landmark 14 in pixels: x=547, y=883
# Landmark 15: x=0.877, y=1.602, z=-0.597, visibility=0.03
# Landmark 15 in pixels: x=1123, y=1153
# Landmark 16: x=0.389, y=1.436, z=-0.976, visibility=0.55
# Landmark 16 in pixels: x=498, y=1034
# Landmark 17: x=0.894, y=1.719, z=-0.664, visibility=0.03
# Landmark 17 in pixels: x=1144, y=1237
# Landmark 18: x=0.353, y=1.525, z=-1.089, visibility=0.39
# Landmark 18 in pixels: x=451, y=1097
# Landmark 19: x=0.850, y=1.724, z=-0.687, visibility=0.04
# Landmark 19 in pixels: x=1087, y=1241
# Landmark 20: x=0.386, y=1.526, z=-1.125, visibility=0.46
# Landmark 20 in pixels: x=494, y=1098
# Landmark 21: x=0.841, y=1.677, z=-0.616, visibility=0.05
# Landmark 21 in pixels: x=1076, y=1207
# Landmark 22: x=0.404, y=1.492, z=-1.014, visibility=0.48
# Landmark 22 in pixels: x=516, y=1074
# Landmark 23: x=0.764, y=1.637, z=-0.068, visibility=0.00
# Landmark 23 in pixels: x=977, y=1178
# Landmark 24: x=0.544, y=1.624, z=0.072, visibility=0.00
# Landmark 24 in pixels: x=696, y=1169
# Landmark 25: x=0.734, y=2.227, z=0.053, visibility=0.00
# Landmark 25 in pixels: x=939, y=1603
# Landmark 26: x=0.516, y=2.197, z=0.421, visibility=0.00
# Landmark 26 in pixels: x=660, y=1582
# Landmark 27: x=0.705, y=2.745, z=0.544, visibility=0.00
# Landmark 27 in pixels: x=901, y=1976
# Landmark 28: x=0.492, y=2.717, z=0.970, visibility=0.00
# Landmark 28 in pixels: x=629, y=1956
# Landmark 29: x=0.712, y=2.836, z=0.570, visibility=0.00
# Landmark 29 in pixels: x=911, y=2042
# Landmark 30: x=0.489, y=2.803, z=1.015, visibility=0.00
# Landmark 30 in pixels: x=625, y=2018
# Landmark 31: x=0.641, y=2.925, z=0.115, visibility=0.00
# Landmark 31 in pixels: x=819, y=2106
# Landmark 32: x=0.516, y=2.916, z=0.545, visibility=0.00
# Landmark 32 in pixels: x=660, y=2099
# Landmark 0: x=0.626, y=0.711, z=-0.699, visibility=0.99
# Landmark 0 in pixels: x=801, y=511
# Landmark 1: x=0.653, y=0.626, z=-0.681, visibility=0.98
# Landmark 1 in pixels: x=835, y=450
# Landmark 2: x=0.672, y=0.617, z=-0.681, visibility=0.98
# Landmark 2 in pixels: x=860, y=444
# Landmark 3: x=0.689, y=0.611, z=-0.681, visibility=0.98
# Landmark 3 in pixels: x=881, y=439
# Landmark 4: x=0.608, y=0.640, z=-0.668, visibility=0.98
# Landmark 4 in pixels: x=778, y=461
# Landmark 5: x=0.596, y=0.642, z=-0.667, visibility=0.98
# Landmark 5 in pixels: x=762, y=462
# Landmark 6: x=0.585, y=0.644, z=-0.667, visibility=0.98
# Landmark 6 in pixels: x=748, y=463
# Landmark 7: x=0.718, y=0.620, z=-0.420, visibility=0.99
# Landmark 7 in pixels: x=918, y=446
# Landmark 8: x=0.585, y=0.648, z=-0.338, visibility=0.98
# Landmark 8 in pixels: x=748, y=466
# Landmark 9: x=0.666, y=0.759, z=-0.589, visibility=0.99
# Landmark 9 in pixels: x=852, y=546
# Landmark 10: x=0.612, y=0.773, z=-0.566, visibility=0.99
# Landmark 10 in pixels: x=782, y=556
# Landmark 11: x=0.851, y=0.947, z=-0.233, visibility=0.99
# Landmark 11 in pixels: x=1089, y=681
# Landmark 12: x=0.525, y=0.857, z=-0.161, visibility=0.99
# Landmark 12 in pixels: x=672, y=616
# Landmark 13: x=0.913, y=1.302, z=-0.278, visibility=0.17
# Landmark 13 in pixels: x=1169, y=937
# Landmark 14: x=0.422, y=1.213, z=-0.325, visibility=0.64
# Landmark 14 in pixels: x=540, y=873
# Landmark 15: x=0.874, y=1.603, z=-0.497, visibility=0.03
# Landmark 15 in pixels: x=1118, y=1153
# Landmark 16: x=0.386, y=1.418, z=-0.945, visibility=0.50
# Landmark 16 in pixels: x=494, y=1021
# Landmark 17: x=0.889, y=1.718, z=-0.554, visibility=0.03
# Landmark 17 in pixels: x=1137, y=1236
# Landmark 18: x=0.353, y=1.508, z=-1.053, visibility=0.35
# Landmark 18 in pixels: x=451, y=1085
# Landmark 19: x=0.847, y=1.719, z=-0.577, visibility=0.04
# Landmark 19 in pixels: x=1084, y=1237
# Landmark 20: x=0.387, y=1.501, z=-1.084, visibility=0.42
# Landmark 20 in pixels: x=495, y=1080
# Landmark 21: x=0.838, y=1.674, z=-0.516, visibility=0.05
# Landmark 21 in pixels: x=1072, y=1205
# Landmark 22: x=0.404, y=1.470, z=-0.980, visibility=0.44
# Landmark 22 in pixels: x=517, y=1058
# Landmark 23: x=0.763, y=1.631, z=-0.060, visibility=0.00
# Landmark 23 in pixels: x=976, y=1174
# Landmark 24: x=0.540, y=1.613, z=0.064, visibility=0.00
# Landmark 24 in pixels: x=691, y=1161
# Landmark 25: x=0.732, y=2.225, z=0.040, visibility=0.00
# Landmark 25 in pixels: x=937, y=1602
# Landmark 26: x=0.513, y=2.192, z=0.349, visibility=0.00
# Landmark 26 in pixels: x=657, y=1578
# Landmark 27: x=0.705, y=2.741, z=0.505, visibility=0.00
# Landmark 27 in pixels: x=902, y=1973
# Landmark 28: x=0.491, y=2.709, z=0.838, visibility=0.00
# Landmark 28 in pixels: x=628, y=1950
# Landmark 29: x=0.712, y=2.836, z=0.528, visibility=0.00
# Landmark 29 in pixels: x=911, y=2041
# Landmark 30: x=0.488, y=2.796, z=0.877, visibility=0.00
# Landmark 30 in pixels: x=624, y=2012
# Landmark 31: x=0.645, y=2.920, z=0.077, visibility=0.00
# Landmark 31 in pixels: x=825, y=2102
# Landmark 32: x=0.517, y=2.911, z=0.406, visibility=0.00
# Landmark 32 in pixels: x=661, y=2095
# Landmark 0: x=0.620, y=0.712, z=-0.664, visibility=0.99
# Landmark 0 in pixels: x=794, y=512
# Landmark 1: x=0.648, y=0.627, z=-0.647, visibility=0.98
# Landmark 1 in pixels: x=829, y=451
# Landmark 2: x=0.668, y=0.618, z=-0.647, visibility=0.98
# Landmark 2 in pixels: x=855, y=444
# Landmark 3: x=0.687, y=0.612, z=-0.648, visibility=0.98
# Landmark 3 in pixels: x=878, y=440
# Landmark 4: x=0.604, y=0.642, z=-0.631, visibility=0.98
# Landmark 4 in pixels: x=773, y=461
# Landmark 5: x=0.593, y=0.643, z=-0.630, visibility=0.98
# Landmark 5 in pixels: x=759, y=463
# Landmark 6: x=0.583, y=0.645, z=-0.630, visibility=0.98
# Landmark 6 in pixels: x=745, y=464
# Landmark 7: x=0.718, y=0.621, z=-0.400, visibility=0.99
# Landmark 7 in pixels: x=918, y=446
# Landmark 8: x=0.585, y=0.649, z=-0.300, visibility=0.98
# Landmark 8 in pixels: x=749, y=467
# Landmark 9: x=0.662, y=0.760, z=-0.561, visibility=0.99
# Landmark 9 in pixels: x=847, y=547
# Landmark 10: x=0.608, y=0.774, z=-0.533, visibility=0.99
# Landmark 10 in pixels: x=778, y=557
# Landmark 11: x=0.853, y=0.954, z=-0.247, visibility=0.99
# Landmark 11 in pixels: x=1091, y=686
# Landmark 12: x=0.526, y=0.860, z=-0.140, visibility=0.99
# Landmark 12 in pixels: x=672, y=619
# Landmark 13: x=0.914, y=1.329, z=-0.318, visibility=0.19
# Landmark 13 in pixels: x=1169, y=957
# Landmark 14: x=0.414, y=1.194, z=-0.338, visibility=0.61
# Landmark 14 in pixels: x=529, y=859
# Landmark 15: x=0.877, y=1.637, z=-0.522, visibility=0.03
# Landmark 15 in pixels: x=1122, y=1178
# Landmark 16: x=0.379, y=1.347, z=-1.052, visibility=0.46
# Landmark 16 in pixels: x=485, y=969
# Landmark 17: x=0.891, y=1.760, z=-0.578, visibility=0.03
# Landmark 17 in pixels: x=1140, y=1267
# Landmark 18: x=0.329, y=1.420, z=-1.164, visibility=0.33
# Landmark 18 in pixels: x=421, y=1022
# Landmark 19: x=0.848, y=1.757, z=-0.595, visibility=0.05
# Landmark 19 in pixels: x=1085, y=1264
# Landmark 20: x=0.374, y=1.415, z=-1.197, visibility=0.39
# Landmark 20 in pixels: x=478, y=1018
# Landmark 21: x=0.839, y=1.710, z=-0.538, visibility=0.06
# Landmark 21 in pixels: x=1073, y=1231
# Landmark 22: x=0.386, y=1.394, z=-1.091, visibility=0.41
# Landmark 22 in pixels: x=494, y=1003
# Landmark 23: x=0.760, y=1.637, z=-0.062, visibility=0.00
# Landmark 23 in pixels: x=973, y=1178
# Landmark 24: x=0.535, y=1.619, z=0.066, visibility=0.00
# Landmark 24 in pixels: x=685, y=1165
# Landmark 25: x=0.728, y=2.241, z=0.026, visibility=0.00
# Landmark 25 in pixels: x=932, y=1613
# Landmark 26: x=0.503, y=2.202, z=0.358, visibility=0.00
# Landmark 26 in pixels: x=643, y=1585
# Landmark 27: x=0.700, y=2.762, z=0.499, visibility=0.00
# Landmark 27 in pixels: x=895, y=1988
# Landmark 28: x=0.480, y=2.722, z=0.823, visibility=0.00
# Landmark 28 in pixels: x=613, y=1960
# Landmark 29: x=0.707, y=2.857, z=0.524, visibility=0.00
# Landmark 29 in pixels: x=904, y=2057
# Landmark 30: x=0.476, y=2.812, z=0.860, visibility=0.00
# Landmark 30 in pixels: x=609, y=2024
# Landmark 31: x=0.639, y=2.942, z=0.077, visibility=0.00
# Landmark 31 in pixels: x=817, y=2118
# Landmark 32: x=0.506, y=2.928, z=0.400, visibility=0.00
# Landmark 32 in pixels: x=647, y=2108
# Landmark 0: x=0.618, y=0.711, z=-0.667, visibility=0.99
# Landmark 0 in pixels: x=790, y=512
# Landmark 1: x=0.647, y=0.626, z=-0.651, visibility=0.99
# Landmark 1 in pixels: x=827, y=450
# Landmark 2: x=0.667, y=0.618, z=-0.651, visibility=0.99
# Landmark 2 in pixels: x=854, y=444
# Landmark 3: x=0.686, y=0.612, z=-0.651, visibility=0.99
# Landmark 3 in pixels: x=878, y=440
# Landmark 4: x=0.603, y=0.641, z=-0.635, visibility=0.98
# Landmark 4 in pixels: x=771, y=461
# Landmark 5: x=0.591, y=0.643, z=-0.634, visibility=0.98
# Landmark 5 in pixels: x=756, y=462
# Landmark 6: x=0.581, y=0.645, z=-0.634, visibility=0.98
# Landmark 6 in pixels: x=743, y=464
# Landmark 7: x=0.718, y=0.621, z=-0.404, visibility=0.99
# Landmark 7 in pixels: x=918, y=446
# Landmark 8: x=0.584, y=0.649, z=-0.306, visibility=0.98
# Landmark 8 in pixels: x=748, y=467
# Landmark 9: x=0.660, y=0.760, z=-0.563, visibility=0.99
# Landmark 9 in pixels: x=844, y=547
# Landmark 10: x=0.605, y=0.773, z=-0.537, visibility=0.99
# Landmark 10 in pixels: x=774, y=556
# Landmark 11: x=0.853, y=0.954, z=-0.245, visibility=0.99
# Landmark 11 in pixels: x=1091, y=686
# Landmark 12: x=0.523, y=0.860, z=-0.142, visibility=0.99
# Landmark 12 in pixels: x=669, y=619
# Landmark 13: x=0.916, y=1.324, z=-0.317, visibility=0.20
# Landmark 13 in pixels: x=1172, y=953
# Landmark 14: x=0.421, y=1.203, z=-0.319, visibility=0.57
# Landmark 14 in pixels: x=538, y=865
# Landmark 15: x=0.876, y=1.625, z=-0.522, visibility=0.03
# Landmark 15 in pixels: x=1121, y=1170
# Landmark 16: x=0.402, y=1.417, z=-1.000, visibility=0.42
# Landmark 16 in pixels: x=515, y=1020
# Landmark 17: x=0.890, y=1.745, z=-0.579, visibility=0.03
# Landmark 17 in pixels: x=1139, y=1256
# Landmark 18: x=0.369, y=1.512, z=-1.094, visibility=0.30
# Landmark 18 in pixels: x=471, y=1088
# Landmark 19: x=0.845, y=1.741, z=-0.595, visibility=0.05
# Landmark 19 in pixels: x=1081, y=1253
# Landmark 20: x=0.408, y=1.508, z=-1.143, visibility=0.36
# Landmark 20 in pixels: x=521, y=1085
# Landmark 21: x=0.837, y=1.696, z=-0.537, visibility=0.06
# Landmark 21 in pixels: x=1070, y=1221
# Landmark 22: x=0.422, y=1.474, z=-1.049, visibility=0.38
# Landmark 22 in pixels: x=540, y=1061
# Landmark 23: x=0.760, y=1.633, z=-0.062, visibility=0.00
# Landmark 23 in pixels: x=973, y=1175
# Landmark 24: x=0.536, y=1.617, z=0.066, visibility=0.00
# Landmark 24 in pixels: x=685, y=1164
# Landmark 25: x=0.730, y=2.239, z=0.066, visibility=0.00
# Landmark 25 in pixels: x=934, y=1612
# Landmark 26: x=0.507, y=2.202, z=0.391, visibility=0.00
# Landmark 26 in pixels: x=648, y=1585
# Landmark 27: x=0.703, y=2.760, z=0.549, visibility=0.00
# Landmark 27 in pixels: x=899, y=1987
# Landmark 28: x=0.484, y=2.721, z=0.922, visibility=0.00
# Landmark 28 in pixels: x=620, y=1959
# Landmark 29: x=0.710, y=2.852, z=0.574, visibility=0.00
# Landmark 29 in pixels: x=909, y=2053
# Landmark 30: x=0.481, y=2.812, z=0.965, visibility=0.00
# Landmark 30 in pixels: x=615, y=2024
# Landmark 31: x=0.643, y=2.940, z=0.119, visibility=0.00
# Landmark 31 in pixels: x=823, y=2116
# Landmark 32: x=0.511, y=2.926, z=0.497, visibility=0.00
# Landmark 32 in pixels: x=654, y=2106
# Landmark 0: x=0.616, y=0.712, z=-0.650, visibility=0.99
# Landmark 0 in pixels: x=788, y=512
# Landmark 1: x=0.645, y=0.627, z=-0.634, visibility=0.99
# Landmark 1 in pixels: x=825, y=451
# Landmark 2: x=0.666, y=0.618, z=-0.634, visibility=0.99
# Landmark 2 in pixels: x=852, y=444
# Landmark 3: x=0.685, y=0.612, z=-0.635, visibility=0.99
# Landmark 3 in pixels: x=877, y=440
# Landmark 4: x=0.602, y=0.642, z=-0.621, visibility=0.98
# Landmark 4 in pixels: x=770, y=461
# Landmark 5: x=0.591, y=0.643, z=-0.620, visibility=0.98
# Landmark 5 in pixels: x=755, y=463
# Landmark 6: x=0.580, y=0.646, z=-0.620, visibility=0.98
# Landmark 6 in pixels: x=742, y=464
# Landmark 7: x=0.718, y=0.621, z=-0.380, visibility=0.99
# Landmark 7 in pixels: x=918, y=447
# Landmark 8: x=0.585, y=0.649, z=-0.292, visibility=0.99
# Landmark 8 in pixels: x=748, y=467
# Landmark 9: x=0.659, y=0.761, z=-0.543, visibility=1.00
# Landmark 9 in pixels: x=843, y=548
# Landmark 10: x=0.604, y=0.774, z=-0.519, visibility=0.99
# Landmark 10 in pixels: x=772, y=557
# Landmark 11: x=0.853, y=0.954, z=-0.223, visibility=0.99
# Landmark 11 in pixels: x=1091, y=686
# Landmark 12: x=0.523, y=0.860, z=-0.140, visibility=0.99
# Landmark 12 in pixels: x=669, y=619
# Landmark 13: x=0.916, y=1.320, z=-0.269, visibility=0.21
# Landmark 13 in pixels: x=1172, y=950
# Landmark 14: x=0.421, y=1.200, z=-0.350, visibility=0.53
# Landmark 14 in pixels: x=538, y=864
# Landmark 15: x=0.878, y=1.626, z=-0.450, visibility=0.04
# Landmark 15 in pixels: x=1124, y=1170
# Landmark 16: x=0.385, y=1.384, z=-1.083, visibility=0.38
# Landmark 16 in pixels: x=493, y=996
# Landmark 17: x=0.891, y=1.750, z=-0.500, visibility=0.03
# Landmark 17 in pixels: x=1140, y=1260
# Landmark 18: x=0.349, y=1.466, z=-1.199, visibility=0.28
# Landmark 18 in pixels: x=446, y=1055
# Landmark 19: x=0.850, y=1.750, z=-0.522, visibility=0.05
# Landmark 19 in pixels: x=1088, y=1259
# Landmark 20: x=0.383, y=1.465, z=-1.227, visibility=0.33
# Landmark 20 in pixels: x=490, y=1054
# Landmark 21: x=0.841, y=1.702, z=-0.466, visibility=0.06
# Landmark 21 in pixels: x=1076, y=1225
# Landmark 22: x=0.401, y=1.437, z=-1.120, visibility=0.35
# Landmark 22 in pixels: x=512, y=1034
# Landmark 23: x=0.755, y=1.629, z=-0.062, visibility=0.00
# Landmark 23 in pixels: x=966, y=1172
# Landmark 24: x=0.533, y=1.615, z=0.066, visibility=0.00
# Landmark 24 in pixels: x=682, y=1162
# Landmark 25: x=0.730, y=2.238, z=0.067, visibility=0.00
# Landmark 25 in pixels: x=933, y=1611
# Landmark 26: x=0.507, y=2.202, z=0.462, visibility=0.00
# Landmark 26 in pixels: x=648, y=1585
# Landmark 27: x=0.705, y=2.758, z=0.554, visibility=0.00
# Landmark 27 in pixels: x=902, y=1985
# Landmark 28: x=0.486, y=2.722, z=1.050, visibility=0.00
# Landmark 28 in pixels: x=621, y=1959
# Landmark 29: x=0.712, y=2.850, z=0.581, visibility=0.00
# Landmark 29 in pixels: x=911, y=2051
# Landmark 30: x=0.482, y=2.812, z=1.100, visibility=0.00
# Landmark 30 in pixels: x=616, y=2024
# Landmark 31: x=0.644, y=2.938, z=0.133, visibility=0.00
# Landmark 31 in pixels: x=824, y=2115
# Landmark 32: x=0.514, y=2.928, z=0.641, visibility=0.00
# Landmark 32 in pixels: x=658, y=2108
# Landmark 0: x=0.613, y=0.711, z=-0.642, visibility=0.99
# Landmark 0 in pixels: x=784, y=512
# Landmark 1: x=0.643, y=0.626, z=-0.627, visibility=0.99
# Landmark 1 in pixels: x=822, y=450
# Landmark 2: x=0.664, y=0.618, z=-0.627, visibility=0.99
# Landmark 2 in pixels: x=850, y=444
# Landmark 3: x=0.684, y=0.612, z=-0.628, visibility=0.99
# Landmark 3 in pixels: x=875, y=440
# Landmark 4: x=0.599, y=0.641, z=-0.609, visibility=0.98
# Landmark 4 in pixels: x=767, y=461
# Landmark 5: x=0.588, y=0.643, z=-0.608, visibility=0.98
# Landmark 5 in pixels: x=753, y=463
# Landmark 6: x=0.578, y=0.646, z=-0.608, visibility=0.98
# Landmark 6 in pixels: x=740, y=464
# Landmark 7: x=0.718, y=0.621, z=-0.389, visibility=0.99
# Landmark 7 in pixels: x=918, y=447
# Landmark 8: x=0.583, y=0.649, z=-0.281, visibility=0.99
# Landmark 8 in pixels: x=746, y=467
# Landmark 9: x=0.656, y=0.761, z=-0.541, visibility=1.00
# Landmark 9 in pixels: x=839, y=548
# Landmark 10: x=0.601, y=0.773, z=-0.511, visibility=0.99
# Landmark 10 in pixels: x=768, y=556
# Landmark 11: x=0.852, y=0.953, z=-0.237, visibility=0.99
# Landmark 11 in pixels: x=1091, y=686
# Landmark 12: x=0.520, y=0.859, z=-0.110, visibility=0.99
# Landmark 12 in pixels: x=666, y=618
# Landmark 13: x=0.916, y=1.306, z=-0.310, visibility=0.20
# Landmark 13 in pixels: x=1172, y=940
# Landmark 14: x=0.434, y=1.226, z=-0.238, visibility=0.49
# Landmark 14 in pixels: x=555, y=882
# Landmark 15: x=0.876, y=1.623, z=-0.512, visibility=0.04
# Landmark 15 in pixels: x=1121, y=1168
# Landmark 16: x=0.424, y=1.447, z=-0.824, visibility=0.35
# Landmark 16 in pixels: x=543, y=1042
# Landmark 17: x=0.891, y=1.746, z=-0.570, visibility=0.03
# Landmark 17 in pixels: x=1140, y=1256
# Landmark 18: x=0.396, y=1.543, z=-0.927, visibility=0.25
# Landmark 18 in pixels: x=506, y=1110
# Landmark 19: x=0.848, y=1.739, z=-0.591, visibility=0.06
# Landmark 19 in pixels: x=1085, y=1252
# Landmark 20: x=0.431, y=1.537, z=-0.948, visibility=0.31
# Landmark 20 in pixels: x=551, y=1106
# Landmark 21: x=0.839, y=1.693, z=-0.530, visibility=0.06
# Landmark 21 in pixels: x=1074, y=1218
# Landmark 22: x=0.446, y=1.501, z=-0.855, visibility=0.32
# Landmark 22 in pixels: x=570, y=1080
# Landmark 23: x=0.754, y=1.620, z=-0.063, visibility=0.00
# Landmark 23 in pixels: x=964, y=1166
# Landmark 24: x=0.532, y=1.605, z=0.067, visibility=0.00
# Landmark 24 in pixels: x=680, y=1155
# Landmark 25: x=0.730, y=2.228, z=0.046, visibility=0.00
# Landmark 25 in pixels: x=934, y=1604
# Landmark 26: x=0.509, y=2.194, z=0.388, visibility=0.00
# Landmark 26 in pixels: x=652, y=1579
# Landmark 27: x=0.706, y=2.746, z=0.519, visibility=0.00
# Landmark 27 in pixels: x=903, y=1976
# Landmark 28: x=0.488, y=2.711, z=0.896, visibility=0.00
# Landmark 28 in pixels: x=625, y=1951
# Landmark 29: x=0.713, y=2.839, z=0.544, visibility=0.00
# Landmark 29 in pixels: x=913, y=2044
# Landmark 30: x=0.485, y=2.801, z=0.936, visibility=0.00
# Landmark 30 in pixels: x=620, y=2016
# Landmark 31: x=0.646, y=2.925, z=0.100, visibility=0.00
# Landmark 31 in pixels: x=826, y=2106
# Landmark 32: x=0.516, y=2.916, z=0.470, visibility=0.00
# Landmark 32 in pixels: x=660, y=2099
# Landmark 0: x=0.613, y=0.711, z=-0.658, visibility=0.99
# Landmark 0 in pixels: x=784, y=512
# Landmark 1: x=0.643, y=0.626, z=-0.645, visibility=0.99
# Landmark 1 in pixels: x=822, y=450
# Landmark 2: x=0.664, y=0.618, z=-0.645, visibility=0.99
# Landmark 2 in pixels: x=850, y=444
# Landmark 3: x=0.684, y=0.612, z=-0.645, visibility=0.99
# Landmark 3 in pixels: x=875, y=440
# Landmark 4: x=0.599, y=0.641, z=-0.628, visibility=0.99
# Landmark 4 in pixels: x=766, y=461
# Landmark 5: x=0.588, y=0.643, z=-0.628, visibility=0.99
# Landmark 5 in pixels: x=752, y=463
# Landmark 6: x=0.578, y=0.645, z=-0.628, visibility=0.99
# Landmark 6 in pixels: x=739, y=464
# Landmark 7: x=0.718, y=0.621, z=-0.407, visibility=0.99
# Landmark 7 in pixels: x=918, y=447
# Landmark 8: x=0.583, y=0.649, z=-0.298, visibility=0.99
# Landmark 8 in pixels: x=745, y=467
# Landmark 9: x=0.655, y=0.761, z=-0.556, visibility=1.00
# Landmark 9 in pixels: x=838, y=548
# Landmark 10: x=0.600, y=0.773, z=-0.531, visibility=0.99
# Landmark 10 in pixels: x=768, y=556
# Landmark 11: x=0.853, y=0.953, z=-0.249, visibility=0.99
# Landmark 11 in pixels: x=1091, y=686
# Landmark 12: x=0.520, y=0.866, z=-0.119, visibility=0.99
# Landmark 12 in pixels: x=666, y=623
# Landmark 13: x=0.918, y=1.305, z=-0.356, visibility=0.20
# Landmark 13 in pixels: x=1174, y=939
# Landmark 14: x=0.449, y=1.261, z=-0.208, visibility=0.44
# Landmark 14 in pixels: x=574, y=907
# Landmark 15: x=0.878, y=1.620, z=-0.598, visibility=0.04
# Landmark 15 in pixels: x=1123, y=1166
# Landmark 16: x=0.444, y=1.488, z=-0.765, visibility=0.32
# Landmark 16 in pixels: x=568, y=1071
# Landmark 17: x=0.892, y=1.741, z=-0.668, visibility=0.03
# Landmark 17 in pixels: x=1142, y=1253
# Landmark 18: x=0.417, y=1.587, z=-0.863, visibility=0.23
# Landmark 18 in pixels: x=533, y=1142
# Landmark 19: x=0.851, y=1.738, z=-0.690, visibility=0.06
# Landmark 19 in pixels: x=1089, y=1251
# Landmark 20: x=0.453, y=1.581, z=-0.888, visibility=0.28
# Landmark 20 in pixels: x=579, y=1138
# Landmark 21: x=0.842, y=1.691, z=-0.616, visibility=0.07
# Landmark 21 in pixels: x=1077, y=1217
# Landmark 22: x=0.468, y=1.542, z=-0.796, visibility=0.30
# Landmark 22 in pixels: x=598, y=1110
# Landmark 23: x=0.755, y=1.625, z=-0.070, visibility=0.00
# Landmark 23 in pixels: x=966, y=1169
# Landmark 24: x=0.533, y=1.609, z=0.075, visibility=0.00
# Landmark 24 in pixels: x=682, y=1158
# Landmark 25: x=0.730, y=2.232, z=0.042, visibility=0.00
# Landmark 25 in pixels: x=934, y=1607
# Landmark 26: x=0.510, y=2.200, z=0.447, visibility=0.00
# Landmark 26 in pixels: x=653, y=1583
# Landmark 27: x=0.706, y=2.749, z=0.530, visibility=0.00
# Landmark 27 in pixels: x=903, y=1979
# Landmark 28: x=0.490, y=2.715, z=1.017, visibility=0.00
# Landmark 28 in pixels: x=626, y=1954
# Landmark 29: x=0.714, y=2.843, z=0.557, visibility=0.00
# Landmark 29 in pixels: x=913, y=2046
# Landmark 30: x=0.487, y=2.805, z=1.063, visibility=0.00
# Landmark 30 in pixels: x=622, y=2019
# Landmark 31: x=0.648, y=2.927, z=0.094, visibility=0.00
# Landmark 31 in pixels: x=828, y=2107
# Landmark 32: x=0.521, y=2.921, z=0.592, visibility=0.00
# Landmark 32 in pixels: x=666, y=2102
# Landmark 0: x=0.612, y=0.712, z=-0.687, visibility=0.99
# Landmark 0 in pixels: x=783, y=512
# Landmark 1: x=0.642, y=0.627, z=-0.670, visibility=0.99
# Landmark 1 in pixels: x=821, y=451
# Landmark 2: x=0.663, y=0.618, z=-0.670, visibility=0.99
# Landmark 2 in pixels: x=848, y=444
# Landmark 3: x=0.683, y=0.612, z=-0.671, visibility=0.99
# Landmark 3 in pixels: x=874, y=440
# Landmark 4: x=0.599, y=0.642, z=-0.649, visibility=0.99
# Landmark 4 in pixels: x=766, y=462
# Landmark 5: x=0.588, y=0.644, z=-0.648, visibility=0.99
# Landmark 5 in pixels: x=752, y=463
# Landmark 6: x=0.578, y=0.647, z=-0.648, visibility=0.99
# Landmark 6 in pixels: x=739, y=465
# Landmark 7: x=0.718, y=0.621, z=-0.418, visibility=0.99
# Landmark 7 in pixels: x=918, y=447
# Landmark 8: x=0.583, y=0.651, z=-0.309, visibility=0.99
# Landmark 8 in pixels: x=745, y=468
# Landmark 9: x=0.655, y=0.762, z=-0.582, visibility=1.00
# Landmark 9 in pixels: x=838, y=548
# Landmark 10: x=0.600, y=0.775, z=-0.547, visibility=0.99
# Landmark 10 in pixels: x=768, y=557
# Landmark 11: x=0.854, y=0.954, z=-0.264, visibility=0.99
# Landmark 11 in pixels: x=1093, y=686
# Landmark 12: x=0.521, y=0.870, z=-0.129, visibility=0.99
# Landmark 12 in pixels: x=666, y=626
# Landmark 13: x=0.919, y=1.307, z=-0.395, visibility=0.21
# Landmark 13 in pixels: x=1175, y=941
# Landmark 14: x=0.455, y=1.266, z=-0.243, visibility=0.41
# Landmark 14 in pixels: x=582, y=911
# Landmark 15: x=0.879, y=1.620, z=-0.665, visibility=0.04
# Landmark 15 in pixels: x=1125, y=1166
# Landmark 16: x=0.447, y=1.484, z=-0.827, visibility=0.29
# Landmark 16 in pixels: x=572, y=1068
# Landmark 17: x=0.894, y=1.742, z=-0.742, visibility=0.03
# Landmark 17 in pixels: x=1144, y=1254
# Landmark 18: x=0.419, y=1.582, z=-0.922, visibility=0.21
# Landmark 18 in pixels: x=536, y=1139
# Landmark 19: x=0.852, y=1.741, z=-0.765, visibility=0.06
# Landmark 19 in pixels: x=1090, y=1253
# Landmark 20: x=0.455, y=1.577, z=-0.947, visibility=0.26
# Landmark 20 in pixels: x=582, y=1135
# Landmark 21: x=0.843, y=1.693, z=-0.684, visibility=0.07
# Landmark 21 in pixels: x=1078, y=1219
# Landmark 22: x=0.469, y=1.538, z=-0.859, visibility=0.27
# Landmark 22 in pixels: x=600, y=1107
# Landmark 23: x=0.756, y=1.630, z=-0.073, visibility=0.00
# Landmark 23 in pixels: x=967, y=1173
# Landmark 24: x=0.536, y=1.617, z=0.077, visibility=0.00
# Landmark 24 in pixels: x=685, y=1164
# Landmark 25: x=0.732, y=2.241, z=0.085, visibility=0.00
# Landmark 25 in pixels: x=937, y=1613
# Landmark 26: x=0.511, y=2.207, z=0.454, visibility=0.00
# Landmark 26 in pixels: x=654, y=1588
# Landmark 27: x=0.712, y=2.755, z=0.609, visibility=0.00
# Landmark 27 in pixels: x=911, y=1983
# Landmark 28: x=0.499, y=2.720, z=1.034, visibility=0.00
# Landmark 28 in pixels: x=638, y=1958
# Landmark 29: x=0.721, y=2.850, z=0.639, visibility=0.00
# Landmark 29 in pixels: x=923, y=2052
# Landmark 30: x=0.497, y=2.809, z=1.082, visibility=0.00
# Landmark 30 in pixels: x=636, y=2022
# Landmark 31: x=0.652, y=2.933, z=0.177, visibility=0.00
# Landmark 31 in pixels: x=834, y=2111
# Landmark 32: x=0.534, y=2.929, z=0.611, visibility=0.00
# Landmark 32 in pixels: x=683, y=2108
# Landmark 0: x=0.612, y=0.712, z=-0.622, visibility=0.99
# Landmark 0 in pixels: x=783, y=512
# Landmark 1: x=0.642, y=0.626, z=-0.610, visibility=0.99
# Landmark 1 in pixels: x=821, y=451
# Landmark 2: x=0.663, y=0.618, z=-0.610, visibility=0.99
# Landmark 2 in pixels: x=848, y=444
# Landmark 3: x=0.683, y=0.611, z=-0.610, visibility=0.99
# Landmark 3 in pixels: x=874, y=439
# Landmark 4: x=0.599, y=0.642, z=-0.588, visibility=0.99
# Landmark 4 in pixels: x=766, y=462
# Landmark 5: x=0.588, y=0.644, z=-0.587, visibility=0.99
# Landmark 5 in pixels: x=752, y=463
# Landmark 6: x=0.577, y=0.647, z=-0.587, visibility=0.99
# Landmark 6 in pixels: x=739, y=465
# Landmark 7: x=0.718, y=0.621, z=-0.391, visibility=0.99
# Landmark 7 in pixels: x=918, y=446
# Landmark 8: x=0.582, y=0.651, z=-0.263, visibility=0.99
# Landmark 8 in pixels: x=745, y=468
# Landmark 9: x=0.655, y=0.762, z=-0.528, visibility=1.00
# Landmark 9 in pixels: x=838, y=548
# Landmark 10: x=0.600, y=0.775, z=-0.492, visibility=0.99
# Landmark 10 in pixels: x=768, y=557
# Landmark 11: x=0.856, y=0.954, z=-0.262, visibility=0.99
# Landmark 11 in pixels: x=1095, y=686
# Landmark 12: x=0.520, y=0.870, z=-0.101, visibility=0.99
# Landmark 12 in pixels: x=666, y=626
# Landmark 13: x=0.919, y=1.309, z=-0.382, visibility=0.21
# Landmark 13 in pixels: x=1175, y=942
# Landmark 14: x=0.457, y=1.268, z=-0.186, visibility=0.38
# Landmark 14 in pixels: x=584, y=913
# Landmark 15: x=0.875, y=1.625, z=-0.590, visibility=0.04
# Landmark 15 in pixels: x=1119, y=1169
# Landmark 16: x=0.459, y=1.495, z=-0.706, visibility=0.26
# Landmark 16 in pixels: x=587, y=1076
# Landmark 17: x=0.890, y=1.748, z=-0.656, visibility=0.03
# Landmark 17 in pixels: x=1139, y=1258
# Landmark 18: x=0.435, y=1.599, z=-0.795, visibility=0.19
# Landmark 18 in pixels: x=556, y=1151
# Landmark 19: x=0.844, y=1.745, z=-0.668, visibility=0.06
# Landmark 19 in pixels: x=1079, y=1256
# Landmark 20: x=0.470, y=1.588, z=-0.811, visibility=0.24
# Landmark 20 in pixels: x=602, y=1143
# Landmark 21: x=0.836, y=1.698, z=-0.603, visibility=0.07
# Landmark 21 in pixels: x=1069, y=1222
# Landmark 22: x=0.484, y=1.548, z=-0.732, visibility=0.25
# Landmark 22 in pixels: x=619, y=1114
# Landmark 23: x=0.756, y=1.634, z=-0.073, visibility=0.00
# Landmark 23 in pixels: x=967, y=1176
# Landmark 24: x=0.536, y=1.621, z=0.078, visibility=0.00
# Landmark 24 in pixels: x=686, y=1167
# Landmark 25: x=0.732, y=2.243, z=0.067, visibility=0.00
# Landmark 25 in pixels: x=937, y=1614
# Landmark 26: x=0.512, y=2.210, z=0.428, visibility=0.00
# Landmark 26 in pixels: x=655, y=1590
# Landmark 27: x=0.713, y=2.757, z=0.606, visibility=0.00
# Landmark 27 in pixels: x=912, y=1985
# Landmark 28: x=0.501, y=2.721, z=0.966, visibility=0.00
# Landmark 28 in pixels: x=641, y=1959
# Landmark 29: x=0.722, y=2.851, z=0.635, visibility=0.00
# Landmark 29 in pixels: x=924, y=2052
# Landmark 30: x=0.499, y=2.809, z=1.010, visibility=0.00
# Landmark 30 in pixels: x=638, y=2022
# Landmark 31: x=0.653, y=2.937, z=0.163, visibility=0.00
# Landmark 31 in pixels: x=835, y=2114
# Landmark 32: x=0.536, y=2.931, z=0.554, visibility=0.00
# Landmark 32 in pixels: x=686, y=2110
# Landmark 0: x=0.611, y=0.712, z=-0.642, visibility=1.00
# Landmark 0 in pixels: x=782, y=512
# Landmark 1: x=0.641, y=0.626, z=-0.630, visibility=0.99
# Landmark 1 in pixels: x=820, y=450
# Landmark 2: x=0.663, y=0.618, z=-0.630, visibility=0.99
# Landmark 2 in pixels: x=848, y=444
# Landmark 3: x=0.683, y=0.611, z=-0.630, visibility=0.99
# Landmark 3 in pixels: x=874, y=439
# Landmark 4: x=0.598, y=0.642, z=-0.608, visibility=0.99
# Landmark 4 in pixels: x=765, y=462
# Landmark 5: x=0.587, y=0.644, z=-0.608, visibility=0.99
# Landmark 5 in pixels: x=750, y=463
# Landmark 6: x=0.577, y=0.647, z=-0.608, visibility=0.99
# Landmark 6 in pixels: x=737, y=465
# Landmark 7: x=0.718, y=0.620, z=-0.404, visibility=0.99
# Landmark 7 in pixels: x=918, y=446
# Landmark 8: x=0.582, y=0.651, z=-0.281, visibility=0.99
# Landmark 8 in pixels: x=745, y=468
# Landmark 9: x=0.654, y=0.762, z=-0.546, visibility=1.00
# Landmark 9 in pixels: x=837, y=548
# Landmark 10: x=0.600, y=0.774, z=-0.512, visibility=0.99
# Landmark 10 in pixels: x=767, y=557
# Landmark 11: x=0.856, y=0.954, z=-0.267, visibility=0.99
# Landmark 11 in pixels: x=1096, y=686
# Landmark 12: x=0.520, y=0.873, z=-0.116, visibility=0.99
# Landmark 12 in pixels: x=665, y=628
# Landmark 13: x=0.919, y=1.309, z=-0.377, visibility=0.22
# Landmark 13 in pixels: x=1176, y=942
# Landmark 14: x=0.456, y=1.271, z=-0.214, visibility=0.35
# Landmark 14 in pixels: x=584, y=915
# Landmark 15: x=0.875, y=1.624, z=-0.586, visibility=0.04
# Landmark 15 in pixels: x=1119, y=1168
# Landmark 16: x=0.462, y=1.492, z=-0.753, visibility=0.24
# Landmark 16 in pixels: x=591, y=1073
# Landmark 17: x=0.890, y=1.746, z=-0.653, visibility=0.03
# Landmark 17 in pixels: x=1139, y=1257
# Landmark 18: x=0.438, y=1.592, z=-0.850, visibility=0.18
# Landmark 18 in pixels: x=560, y=1146
# Landmark 19: x=0.843, y=1.745, z=-0.668, visibility=0.06
# Landmark 19 in pixels: x=1079, y=1256
# Landmark 20: x=0.473, y=1.584, z=-0.871, visibility=0.22
# Landmark 20 in pixels: x=605, y=1140
# Landmark 21: x=0.835, y=1.698, z=-0.601, visibility=0.07
# Landmark 21 in pixels: x=1069, y=1222
# Landmark 22: x=0.486, y=1.544, z=-0.782, visibility=0.23
# Landmark 22 in pixels: x=622, y=1111
# Landmark 23: x=0.757, y=1.640, z=-0.073, visibility=0.00
# Landmark 23 in pixels: x=968, y=1181
# Landmark 24: x=0.536, y=1.625, z=0.077, visibility=0.00
# Landmark 24 in pixels: x=686, y=1169
# Landmark 25: x=0.733, y=2.245, z=0.073, visibility=0.00
# Landmark 25 in pixels: x=937, y=1616
# Landmark 26: x=0.513, y=2.213, z=0.448, visibility=0.00
# Landmark 26 in pixels: x=656, y=1593
# Landmark 27: x=0.713, y=2.762, z=0.585, visibility=0.00
# Landmark 27 in pixels: x=912, y=1988
# Landmark 28: x=0.500, y=2.725, z=1.028, visibility=0.00
# Landmark 28 in pixels: x=640, y=1961
# Landmark 29: x=0.721, y=2.856, z=0.613, visibility=0.00
# Landmark 29 in pixels: x=923, y=2056
# Landmark 30: x=0.498, y=2.813, z=1.077, visibility=0.00
# Landmark 30 in pixels: x=637, y=2025
# Landmark 31: x=0.652, y=2.941, z=0.152, visibility=0.00
# Landmark 31 in pixels: x=834, y=2117
# Landmark 32: x=0.535, y=2.935, z=0.612, visibility=0.00
# Landmark 32 in pixels: x=684, y=2113
# Landmark 0: x=0.610, y=0.712, z=-0.667, visibility=1.00
# Landmark 0 in pixels: x=781, y=512
# Landmark 1: x=0.641, y=0.627, z=-0.653, visibility=0.99
# Landmark 1 in pixels: x=819, y=451
# Landmark 2: x=0.662, y=0.618, z=-0.653, visibility=0.99
# Landmark 2 in pixels: x=847, y=444
# Landmark 3: x=0.683, y=0.611, z=-0.654, visibility=0.99
# Landmark 3 in pixels: x=873, y=439
# Landmark 4: x=0.597, y=0.643, z=-0.628, visibility=0.99
# Landmark 4 in pixels: x=764, y=462
# Landmark 5: x=0.586, y=0.645, z=-0.627, visibility=0.99
# Landmark 5 in pixels: x=750, y=464
# Landmark 6: x=0.576, y=0.648, z=-0.627, visibility=0.99
# Landmark 6 in pixels: x=737, y=466
# Landmark 7: x=0.718, y=0.620, z=-0.417, visibility=1.00
# Landmark 7 in pixels: x=918, y=446
# Landmark 8: x=0.582, y=0.652, z=-0.289, visibility=0.99
# Landmark 8 in pixels: x=744, y=469
# Landmark 9: x=0.654, y=0.763, z=-0.568, visibility=1.00
# Landmark 9 in pixels: x=836, y=549
# Landmark 10: x=0.599, y=0.776, z=-0.527, visibility=1.00
# Landmark 10 in pixels: x=766, y=558
# Landmark 11: x=0.857, y=0.954, z=-0.280, visibility=0.99
# Landmark 11 in pixels: x=1096, y=686
# Landmark 12: x=0.520, y=0.873, z=-0.120, visibility=1.00
# Landmark 12 in pixels: x=665, y=628
# Landmark 13: x=0.919, y=1.310, z=-0.387, visibility=0.23
# Landmark 13 in pixels: x=1176, y=943
# Landmark 14: x=0.462, y=1.266, z=-0.228, visibility=0.32
# Landmark 14 in pixels: x=590, y=911
# Landmark 15: x=0.875, y=1.629, z=-0.600, visibility=0.04
# Landmark 15 in pixels: x=1120, y=1173
# Landmark 16: x=0.460, y=1.469, z=-0.774, visibility=0.21
# Landmark 16 in pixels: x=589, y=1057
# Landmark 17: x=0.892, y=1.753, z=-0.672, visibility=0.03
# Landmark 17 in pixels: x=1142, y=1262
# Landmark 18: x=0.435, y=1.564, z=-0.865, visibility=0.16
# Landmark 18 in pixels: x=556, y=1125
# Landmark 19: x=0.844, y=1.756, z=-0.688, visibility=0.06
# Landmark 19 in pixels: x=1080, y=1264
# Landmark 20: x=0.468, y=1.556, z=-0.873, visibility=0.20
# Landmark 20 in pixels: x=598, y=1120
# Landmark 21: x=0.836, y=1.707, z=-0.616, visibility=0.07
# Landmark 21 in pixels: x=1070, y=1229
# Landmark 22: x=0.481, y=1.519, z=-0.800, visibility=0.21
# Landmark 22 in pixels: x=616, y=1093
# Landmark 23: x=0.758, y=1.644, z=-0.077, visibility=0.00
# Landmark 23 in pixels: x=969, y=1183
# Landmark 24: x=0.537, y=1.628, z=0.082, visibility=0.00
# Landmark 24 in pixels: x=687, y=1171
# Landmark 25: x=0.733, y=2.249, z=0.065, visibility=0.00
# Landmark 25 in pixels: x=938, y=1619
# Landmark 26: x=0.514, y=2.216, z=0.465, visibility=0.00
# Landmark 26 in pixels: x=657, y=1595
# Landmark 27: x=0.712, y=2.766, z=0.569, visibility=0.00
# Landmark 27 in pixels: x=911, y=1991
# Landmark 28: x=0.500, y=2.729, z=1.049, visibility=0.00
# Landmark 28 in pixels: x=640, y=1964
# Landmark 29: x=0.721, y=2.860, z=0.596, visibility=0.00
# Landmark 29 in pixels: x=923, y=2058
# Landmark 30: x=0.498, y=2.816, z=1.098, visibility=0.00
# Landmark 30 in pixels: x=637, y=2027
# Landmark 31: x=0.652, y=2.946, z=0.132, visibility=0.00
# Landmark 31 in pixels: x=833, y=2120
# Landmark 32: x=0.535, y=2.940, z=0.625, visibility=0.00
# Landmark 32 in pixels: x=684, y=2116
# Landmark 0: x=0.610, y=0.712, z=-0.660, visibility=1.00
# Landmark 0 in pixels: x=780, y=512
# Landmark 1: x=0.640, y=0.627, z=-0.647, visibility=0.99
# Landmark 1 in pixels: x=819, y=451
# Landmark 2: x=0.662, y=0.618, z=-0.647, visibility=0.99
# Landmark 2 in pixels: x=847, y=444
# Landmark 3: x=0.682, y=0.611, z=-0.648, visibility=0.99
# Landmark 3 in pixels: x=873, y=439
# Landmark 4: x=0.597, y=0.643, z=-0.624, visibility=0.99
# Landmark 4 in pixels: x=763, y=462
# Landmark 5: x=0.586, y=0.645, z=-0.623, visibility=0.99
# Landmark 5 in pixels: x=749, y=464
# Landmark 6: x=0.576, y=0.648, z=-0.623, visibility=0.99
# Landmark 6 in pixels: x=736, y=466
# Landmark 7: x=0.717, y=0.620, z=-0.418, visibility=1.00
# Landmark 7 in pixels: x=918, y=446
# Landmark 8: x=0.582, y=0.652, z=-0.289, visibility=0.99
# Landmark 8 in pixels: x=744, y=469
# Landmark 9: x=0.653, y=0.763, z=-0.564, visibility=1.00
# Landmark 9 in pixels: x=835, y=549
# Landmark 10: x=0.599, y=0.775, z=-0.526, visibility=1.00
# Landmark 10 in pixels: x=766, y=558
# Landmark 11: x=0.857, y=0.954, z=-0.277, visibility=0.99
# Landmark 11 in pixels: x=1096, y=686
# Landmark 12: x=0.520, y=0.873, z=-0.123, visibility=1.00
# Landmark 12 in pixels: x=665, y=628
# Landmark 13: x=0.920, y=1.310, z=-0.366, visibility=0.24
# Landmark 13 in pixels: x=1176, y=942
# Landmark 14: x=0.467, y=1.278, z=-0.223, visibility=0.30
# Landmark 14 in pixels: x=597, y=920
# Landmark 15: x=0.876, y=1.628, z=-0.569, visibility=0.04
# Landmark 15 in pixels: x=1121, y=1172
# Landmark 16: x=0.469, y=1.501, z=-0.781, visibility=0.19
# Landmark 16 in pixels: x=600, y=1081
# Landmark 17: x=0.893, y=1.751, z=-0.636, visibility=0.03
# Landmark 17 in pixels: x=1143, y=1260
# Landmark 18: x=0.445, y=1.603, z=-0.879, visibility=0.15
# Landmark 18 in pixels: x=569, y=1153
# Landmark 19: x=0.845, y=1.753, z=-0.657, visibility=0.06
# Landmark 19 in pixels: x=1081, y=1261
# Landmark 20: x=0.478, y=1.598, z=-0.902, visibility=0.18
# Landmark 20 in pixels: x=611, y=1150
# Landmark 21: x=0.837, y=1.705, z=-0.585, visibility=0.07
# Landmark 21 in pixels: x=1071, y=1227
# Landmark 22: x=0.491, y=1.556, z=-0.811, visibility=0.19
# Landmark 22 in pixels: x=628, y=1120
# Landmark 23: x=0.758, y=1.644, z=-0.076, visibility=0.00
# Landmark 23 in pixels: x=970, y=1183
# Landmark 24: x=0.538, y=1.627, z=0.081, visibility=0.00
# Landmark 24 in pixels: x=688, y=1171
# Landmark 25: x=0.733, y=2.248, z=0.064, visibility=0.00
# Landmark 25 in pixels: x=937, y=1618
# Landmark 26: x=0.514, y=2.215, z=0.434, visibility=0.00
# Landmark 26 in pixels: x=657, y=1595
# Landmark 27: x=0.710, y=2.766, z=0.542, visibility=0.00
# Landmark 27 in pixels: x=909, y=1991
# Landmark 28: x=0.499, y=2.729, z=0.955, visibility=0.00
# Landmark 28 in pixels: x=638, y=1964
# Landmark 29: x=0.718, y=2.859, z=0.567, visibility=0.00
# Landmark 29 in pixels: x=919, y=2058
# Landmark 30: x=0.496, y=2.816, z=0.993, visibility=0.00
# Landmark 30 in pixels: x=634, y=2027
# Landmark 31: x=0.649, y=2.945, z=0.115, visibility=0.00
# Landmark 31 in pixels: x=831, y=2120
# Landmark 32: x=0.530, y=2.939, z=0.539, visibility=0.00
# Landmark 32 in pixels: x=678, y=2116
# Landmark 0: x=0.610, y=0.712, z=-0.663, visibility=1.00
# Landmark 0 in pixels: x=781, y=512
# Landmark 1: x=0.640, y=0.627, z=-0.650, visibility=0.99
# Landmark 1 in pixels: x=819, y=451
# Landmark 2: x=0.662, y=0.618, z=-0.649, visibility=0.99
# Landmark 2 in pixels: x=847, y=444
# Landmark 3: x=0.682, y=0.611, z=-0.650, visibility=0.99
# Landmark 3 in pixels: x=873, y=439
# Landmark 4: x=0.597, y=0.643, z=-0.627, visibility=0.99
# Landmark 4 in pixels: x=763, y=462
# Landmark 5: x=0.586, y=0.645, z=-0.626, visibility=0.99
# Landmark 5 in pixels: x=749, y=464
# Landmark 6: x=0.576, y=0.647, z=-0.626, visibility=0.99
# Landmark 6 in pixels: x=737, y=466
# Landmark 7: x=0.717, y=0.620, z=-0.417, visibility=1.00
# Landmark 7 in pixels: x=918, y=446
# Landmark 8: x=0.582, y=0.652, z=-0.292, visibility=0.99
# Landmark 8 in pixels: x=744, y=469
# Landmark 9: x=0.653, y=0.763, z=-0.566, visibility=1.00
# Landmark 9 in pixels: x=835, y=549
# Landmark 10: x=0.598, y=0.775, z=-0.529, visibility=1.00
# Landmark 10 in pixels: x=766, y=558
# Landmark 11: x=0.857, y=0.954, z=-0.271, visibility=1.00
# Landmark 11 in pixels: x=1096, y=686
# Landmark 12: x=0.519, y=0.873, z=-0.123, visibility=1.00
# Landmark 12 in pixels: x=663, y=628
# Landmark 13: x=0.919, y=1.309, z=-0.346, visibility=0.24
# Landmark 13 in pixels: x=1176, y=942
# Landmark 14: x=0.463, y=1.279, z=-0.229, visibility=0.28
# Landmark 14 in pixels: x=593, y=920
# Landmark 15: x=0.875, y=1.627, z=-0.542, visibility=0.04
# Landmark 15 in pixels: x=1120, y=1171
# Landmark 16: x=0.463, y=1.487, z=-0.795, visibility=0.18
# Landmark 16 in pixels: x=592, y=1070
# Landmark 17: x=0.893, y=1.750, z=-0.608, visibility=0.03
# Landmark 17 in pixels: x=1143, y=1259
# Landmark 18: x=0.438, y=1.581, z=-0.901, visibility=0.14
# Landmark 18 in pixels: x=560, y=1138
# Landmark 19: x=0.844, y=1.751, z=-0.628, visibility=0.06
# Landmark 19 in pixels: x=1080, y=1260
# Landmark 20: x=0.471, y=1.574, z=-0.920, visibility=0.17
# Landmark 20 in pixels: x=603, y=1133
# Landmark 21: x=0.836, y=1.703, z=-0.560, visibility=0.07
# Landmark 21 in pixels: x=1070, y=1226
# ...
# Landmark 26 in pixels: x=609, y=1506
# Landmark 27: x=0.736, y=2.818, z=0.726, visibility=0.00
# Landmark 27 in pixels: x=942, y=2028
# Landmark 28: x=0.459, y=2.814, z=0.795, visibility=0.00
# Landmark 28 in pixels: x=586, y=2025
# Landmark 29: x=0.748, y=2.933, z=0.770, visibility=0.00
# Landmark 29 in pixels: x=957, y=2111
# Landmark 30: x=0.451, y=2.921, z=0.836, visibility=0.00
# Landmark 30 in pixels: x=577, y=2103
# Landmark 31: x=0.677, y=3.057, z=0.271, visibility=0.00
# Landmark 31 in pixels: x=866, y=2200
# Landmark 32: x=0.505, y=3.091, z=0.266, visibility=0.00
# Landmark 32 in pixels: x=646, y=2225
# Landmark 0: x=0.616, y=-0.030, z=-0.836, visibility=1.00
# Landmark 0 in pixels: x=787, y=-21
# Landmark 1: x=0.644, y=-0.104, z=-0.809, visibility=1.00
# Landmark 1 in pixels: x=824, y=-74
# Landmark 2: x=0.660, y=-0.098, z=-0.809, visibility=1.00
# Landmark 2 in pixels: x=844, y=-70
# Landmark 3: x=0.674, y=-0.091, z=-0.809, visibility=1.00
# Landmark 3 in pixels: x=862, y=-65
# Landmark 4: x=0.597, y=-0.105, z=-0.798, visibility=1.00
# Landmark 4 in pixels: x=764, y=-75
# Landmark 5: x=0.583, y=-0.098, z=-0.797, visibility=1.00
# Landmark 5 in pixels: x=746, y=-70
# Landmark 6: x=0.569, y=-0.090, z=-0.798, visibility=1.00
# Landmark 6 in pixels: x=728, y=-65
# Landmark 7: x=0.701, y=-0.043, z=-0.568, visibility=1.00
# Landmark 7 in pixels: x=897, y=-30
# Landmark 8: x=0.560, y=-0.042, z=-0.498, visibility=1.00
# Landmark 8 in pixels: x=717, y=-30
# Landmark 9: x=0.643, y=0.053, z=-0.742, visibility=1.00
# Landmark 9 in pixels: x=822, y=38
# Landmark 10: x=0.586, y=0.057, z=-0.721, visibility=1.00
# Landmark 10 in pixels: x=750, y=40
# Landmark 11: x=0.854, y=0.308, z=-0.459, visibility=1.00
# Landmark 11 in pixels: x=1093, y=222
# Landmark 12: x=0.441, y=0.308, z=-0.365, visibility=1.00
# Landmark 12 in pixels: x=564, y=221
# Landmark 13: x=0.955, y=0.852, z=-0.383, visibility=0.73
# Landmark 13 in pixels: x=1222, y=613
# Landmark 14: x=0.284, y=0.823, z=-0.276, visibility=0.54
# Landmark 14 in pixels: x=362, y=592
# Landmark 15: x=1.001, y=1.413, z=-0.464, visibility=0.07
# Landmark 15 in pixels: x=1281, y=1017
# Landmark 16: x=0.137, y=1.267, z=-0.538, visibility=0.10
# Landmark 16 in pixels: x=175, y=912
# Landmark 17: x=1.047, y=1.566, z=-0.524, visibility=0.05
# Landmark 17 in pixels: x=1340, y=1127
# Landmark 18: x=0.074, y=1.387, z=-0.598, visibility=0.10
# Landmark 18 in pixels: x=94, y=998
# Landmark 19: x=0.987, y=1.613, z=-0.575, visibility=0.09
# Landmark 19 in pixels: x=1263, y=1161
# Landmark 20: x=0.114, y=1.413, z=-0.710, visibility=0.15
# Landmark 20 in pixels: x=145, y=1017
# Landmark 21: x=0.961, y=1.555, z=-0.494, visibility=0.10
# Landmark 21 in pixels: x=1230, y=1119
# Landmark 22: x=0.147, y=1.378, z=-0.597, visibility=0.15
# Landmark 22 in pixels: x=188, y=992
# Landmark 23: x=0.785, y=1.283, z=-0.073, visibility=0.00
# Landmark 23 in pixels: x=1005, y=923
# Landmark 24: x=0.509, y=1.273, z=0.078, visibility=0.00
# Landmark 24 in pixels: x=651, y=916
# Landmark 25: x=0.753, y=2.100, z=0.096, visibility=0.00
# Landmark 25 in pixels: x=963, y=1511
# Landmark 26: x=0.472, y=2.090, z=0.252, visibility=0.00
# Landmark 26 in pixels: x=604, y=1504
# Landmark 27: x=0.730, y=2.816, z=0.853, visibility=0.00
# Landmark 27 in pixels: x=934, y=2027
# Landmark 28: x=0.457, y=2.810, z=0.784, visibility=0.00
# Landmark 28 in pixels: x=584, y=2022
# Landmark 29: x=0.739, y=2.931, z=0.903, visibility=0.00
# Landmark 29 in pixels: x=945, y=2110
# Landmark 30: x=0.450, y=2.917, z=0.825, visibility=0.00
# Landmark 30 in pixels: x=575, y=2100
# Landmark 31: x=0.676, y=3.054, z=0.431, visibility=0.00
# Landmark 31 in pixels: x=864, y=2198
# Landmark 32: x=0.504, y=3.084, z=0.268, visibility=0.00
# Landmark 32 in pixels: x=645, y=2220
# Landmark 0: x=0.624, y=-0.037, z=-0.743, visibility=1.00
# Landmark 0 in pixels: x=798, y=-26
# Landmark 1: x=0.650, y=-0.105, z=-0.704, visibility=1.00
# Landmark 1 in pixels: x=832, y=-75
# Landmark 2: x=0.665, y=-0.097, z=-0.704, visibility=1.00
# Landmark 2 in pixels: x=851, y=-70
# Landmark 3: x=0.679, y=-0.090, z=-0.704, visibility=1.00
# Landmark 3 in pixels: x=868, y=-64
# Landmark 4: x=0.606, y=-0.109, z=-0.704, visibility=1.00
# Landmark 4 in pixels: x=775, y=-78
# Landmark 5: x=0.591, y=-0.103, z=-0.704, visibility=1.00
# Landmark 5 in pixels: x=756, y=-74
# Landmark 6: x=0.577, y=-0.096, z=-0.704, visibility=1.00
# Landmark 6 in pixels: x=739, y=-68
# Landmark 7: x=0.703, y=-0.042, z=-0.456, visibility=1.00
# Landmark 7 in pixels: x=900, y=-30
# Landmark 8: x=0.563, y=-0.044, z=-0.440, visibility=1.00
# Landmark 8 in pixels: x=720, y=-31
# Landmark 9: x=0.649, y=0.047, z=-0.651, visibility=1.00
# Landmark 9 in pixels: x=830, y=33
# Landmark 10: x=0.593, y=0.048, z=-0.646, visibility=1.00
# Landmark 10 in pixels: x=758, y=34
# Landmark 11: x=0.854, y=0.308, z=-0.356, visibility=1.00
# Landmark 11 in pixels: x=1093, y=221
# Landmark 12: x=0.440, y=0.308, z=-0.357, visibility=1.00
# Landmark 12 in pixels: x=562, y=221
# Landmark 13: x=0.956, y=0.851, z=-0.262, visibility=0.73
# Landmark 13 in pixels: x=1223, y=612
# Landmark 14: x=0.285, y=0.821, z=-0.260, visibility=0.53
# Landmark 14 in pixels: x=365, y=591
# Landmark 15: x=1.010, y=1.417, z=-0.369, visibility=0.06
# Landmark 15 in pixels: x=1293, y=1020
# Landmark 16: x=0.150, y=1.296, z=-0.481, visibility=0.10
# Landmark 16 in pixels: x=191, y=932
# Landmark 17: x=1.058, y=1.572, z=-0.421, visibility=0.05
# Landmark 17 in pixels: x=1354, y=1131
# Landmark 18: x=0.089, y=1.426, z=-0.538, visibility=0.10
# Landmark 18 in pixels: x=113, y=1026
# Landmark 19: x=0.998, y=1.619, z=-0.478, visibility=0.09
# Landmark 19 in pixels: x=1277, y=1165
# Landmark 20: x=0.133, y=1.459, z=-0.646, visibility=0.14
# Landmark 20 in pixels: x=169, y=1050
# Landmark 21: x=0.971, y=1.560, z=-0.402, visibility=0.10
# Landmark 21 in pixels: x=1243, y=1122
# Landmark 22: x=0.165, y=1.416, z=-0.538, visibility=0.15
# Landmark 22 in pixels: x=211, y=1019
# Landmark 23: x=0.784, y=1.281, z=-0.062, visibility=0.00
# Landmark 23 in pixels: x=1003, y=922
# Landmark 24: x=0.506, y=1.272, z=0.066, visibility=0.00
# Landmark 24 in pixels: x=647, y=915
# Landmark 25: x=0.749, y=2.099, z=0.057, visibility=0.00
# Landmark 25 in pixels: x=959, y=1511
# Landmark 26: x=0.471, y=2.090, z=0.130, visibility=0.00
# Landmark 26 in pixels: x=602, y=1504
# Landmark 27: x=0.724, y=2.814, z=0.720, visibility=0.00
# Landmark 27 in pixels: x=927, y=2026
# Landmark 28: x=0.454, y=2.808, z=0.558, visibility=0.00
# Landmark 28 in pixels: x=580, y=2021
# Landmark 29: x=0.731, y=2.928, z=0.758, visibility=0.00
# Landmark 29 in pixels: x=936, y=2107
# Landmark 30: x=0.447, y=2.914, z=0.585, visibility=0.00
# Landmark 30 in pixels: x=571, y=2098
# Landmark 31: x=0.673, y=3.052, z=0.293, visibility=0.00
# Landmark 31 in pixels: x=862, y=2197
# Landmark 32: x=0.499, y=3.082, z=0.031, visibility=0.00
# Landmark 32 in pixels: x=638, y=2219
# Landmark 0: x=0.624, y=-0.036, z=-0.922, visibility=1.00
# Landmark 0 in pixels: x=798, y=-26
# Landmark 1: x=0.650, y=-0.107, z=-0.897, visibility=1.00
# Landmark 1 in pixels: x=832, y=-77
# Landmark 2: x=0.665, y=-0.099, z=-0.897, visibility=1.00
# Landmark 2 in pixels: x=851, y=-71
# Landmark 3: x=0.679, y=-0.091, z=-0.897, visibility=1.00
# Landmark 3 in pixels: x=869, y=-65
# Landmark 4: x=0.605, y=-0.113, z=-0.889, visibility=1.00
# Landmark 4 in pixels: x=774, y=-81
# Landmark 5: x=0.591, y=-0.107, z=-0.889, visibility=1.00
# Landmark 5 in pixels: x=756, y=-77
# Landmark 6: x=0.577, y=-0.100, z=-0.889, visibility=1.00
# Landmark 6 in pixels: x=738, y=-71
# Landmark 7: x=0.705, y=-0.043, z=-0.653, visibility=1.00
# Landmark 7 in pixels: x=901, y=-31
# Landmark 8: x=0.563, y=-0.049, z=-0.600, visibility=1.00
# Landmark 8 in pixels: x=720, y=-35
# Landmark 9: x=0.650, y=0.048, z=-0.827, visibility=1.00
# Landmark 9 in pixels: x=831, y=34
# Landmark 10: x=0.593, y=0.049, z=-0.811, visibility=1.00
# Landmark 10 in pixels: x=758, y=35
# Landmark 11: x=0.855, y=0.308, z=-0.507, visibility=1.00
# Landmark 11 in pixels: x=1094, y=221
# Landmark 12: x=0.437, y=0.308, z=-0.469, visibility=1.00
# Landmark 12 in pixels: x=559, y=221
# Landmark 13: x=0.955, y=0.855, z=-0.377, visibility=0.73
# Landmark 13 in pixels: x=1222, y=615
# Landmark 14: x=0.290, y=0.822, z=-0.354, visibility=0.53
# Landmark 14 in pixels: x=371, y=591
# Landmark 15: x=1.002, y=1.419, z=-0.412, visibility=0.06
# Landmark 15 in pixels: x=1282, y=1021
# Landmark 16: x=0.161, y=1.336, z=-0.559, visibility=0.10
# Landmark 16 in pixels: x=205, y=961
# Landmark 17: x=1.044, y=1.574, z=-0.450, visibility=0.05
# Landmark 17 in pixels: x=1336, y=1133
# Landmark 18: x=0.100, y=1.472, z=-0.609, visibility=0.10
# Landmark 18 in pixels: x=128, y=1059
# Landmark 19: x=0.984, y=1.620, z=-0.501, visibility=0.09
# Landmark 19 in pixels: x=1259, y=1166
# Landmark 20: x=0.147, y=1.504, z=-0.718, visibility=0.14
# Landmark 20 in pixels: x=188, y=1082
# Landmark 21: x=0.959, y=1.561, z=-0.438, visibility=0.10
# Landmark 21 in pixels: x=1228, y=1123
# Landmark 22: x=0.180, y=1.460, z=-0.613, visibility=0.15
# Landmark 22 in pixels: x=230, y=1051
# Landmark 23: x=0.781, y=1.285, z=-0.061, visibility=0.00
# Landmark 23 in pixels: x=999, y=924
# Landmark 24: x=0.500, y=1.271, z=0.065, visibility=0.00
# Landmark 24 in pixels: x=639, y=915
# Landmark 25: x=0.740, y=2.106, z=0.049, visibility=0.00
# Landmark 25 in pixels: x=947, y=1516
# Landmark 26: x=0.461, y=2.091, z=0.136, visibility=0.00
# Landmark 26 in pixels: x=590, y=1505
# Landmark 27: x=0.705, y=2.824, z=0.717, visibility=0.00
# Landmark 27 in pixels: x=901, y=2033
# Landmark 28: x=0.438, y=2.814, z=0.577, visibility=0.00
# Landmark 28 in pixels: x=561, y=2025
# Landmark 29: x=0.711, y=2.939, z=0.757, visibility=0.00
# Landmark 29 in pixels: x=909, y=2116
# Landmark 30: x=0.430, y=2.924, z=0.608, visibility=0.00
# Landmark 30 in pixels: x=550, y=2105
# Landmark 31: x=0.651, y=3.067, z=0.287, visibility=0.00
# Landmark 31 in pixels: x=833, y=2208
# Landmark 32: x=0.478, y=3.089, z=0.052, visibility=0.00
# Landmark 32 in pixels: x=612, y=2224
# Landmark 0: x=0.627, y=-0.036, z=-0.921, visibility=1.00
# Landmark 0 in pixels: x=802, y=-26
# Landmark 1: x=0.654, y=-0.107, z=-0.867, visibility=1.00
# Landmark 1 in pixels: x=837, y=-76
# Landmark 2: x=0.669, y=-0.099, z=-0.866, visibility=1.00
# Landmark 2 in pixels: x=855, y=-71
# Landmark 3: x=0.682, y=-0.091, z=-0.866, visibility=1.00
# Landmark 3 in pixels: x=873, y=-65
# Landmark 4: x=0.609, y=-0.113, z=-0.879, visibility=1.00
# Landmark 4 in pixels: x=779, y=-81
# Landmark 5: x=0.594, y=-0.107, z=-0.878, visibility=1.00
# Landmark 5 in pixels: x=760, y=-77
# Landmark 6: x=0.580, y=-0.100, z=-0.878, visibility=1.00
# Landmark 6 in pixels: x=742, y=-72
# Landmark 7: x=0.706, y=-0.043, z=-0.601, visibility=1.00
# Landmark 7 in pixels: x=903, y=-31
# Landmark 8: x=0.563, y=-0.050, z=-0.566, visibility=1.00
# Landmark 8 in pixels: x=720, y=-36
# Landmark 9: x=0.652, y=0.045, z=-0.818, visibility=1.00
# Landmark 9 in pixels: x=834, y=32
# Landmark 10: x=0.595, y=0.048, z=-0.787, visibility=1.00
# Landmark 10 in pixels: x=761, y=34
# Landmark 11: x=0.855, y=0.307, z=-0.481, visibility=1.00
# Landmark 11 in pixels: x=1094, y=221
# Landmark 12: x=0.436, y=0.308, z=-0.432, visibility=1.00
# Landmark 12 in pixels: x=558, y=221
# Landmark 13: x=0.955, y=0.852, z=-0.359, visibility=0.72
# Landmark 13 in pixels: x=1222, y=613
# Landmark 14: x=0.301, y=0.823, z=-0.333, visibility=0.52
# Landmark 14 in pixels: x=385, y=592
# Landmark 15: x=1.002, y=1.420, z=-0.416, visibility=0.06
# Landmark 15 in pixels: x=1282, y=1022
# Landmark 16: x=0.173, y=1.354, z=-0.520, visibility=0.10
# Landmark 16 in pixels: x=220, y=974
# Landmark 17: x=1.045, y=1.575, z=-0.463, visibility=0.05
# Landmark 17 in pixels: x=1337, y=1134
# Landmark 18: x=0.114, y=1.491, z=-0.577, visibility=0.09
# Landmark 18 in pixels: x=145, y=1073
# Landmark 19: x=0.984, y=1.621, z=-0.515, visibility=0.09
# Landmark 19 in pixels: x=1259, y=1167
# Landmark 20: x=0.162, y=1.525, z=-0.683, visibility=0.14
# Landmark 20 in pixels: x=207, y=1098
# Landmark 21: x=0.959, y=1.562, z=-0.445, visibility=0.09
# Landmark 21 in pixels: x=1227, y=1124
# Landmark 22: x=0.195, y=1.479, z=-0.576, visibility=0.15
# Landmark 22 in pixels: x=250, y=1065
# Landmark 23: x=0.778, y=1.281, z=-0.061, visibility=0.00
# Landmark 23 in pixels: x=995, y=922
# Landmark 24: x=0.498, y=1.266, z=0.065, visibility=0.00
# Landmark 24 in pixels: x=637, y=911
# Landmark 25: x=0.739, y=2.105, z=0.012, visibility=0.00
# Landmark 25 in pixels: x=945, y=1515
# Landmark 26: x=0.462, y=2.088, z=0.115, visibility=0.00
# Landmark 26 in pixels: x=591, y=1503
# Landmark 27: x=0.704, y=2.823, z=0.643, visibility=0.00
# Landmark 27 in pixels: x=901, y=2032
# Landmark 28: x=0.440, y=2.812, z=0.524, visibility=0.00
# Landmark 28 in pixels: x=562, y=2024
# Landmark 29: x=0.711, y=2.939, z=0.679, visibility=0.00
# Landmark 29 in pixels: x=909, y=2116
# Landmark 30: x=0.432, y=2.924, z=0.550, visibility=0.00
# Landmark 30 in pixels: x=552, y=2104
# Landmark 31: x=0.650, y=3.064, z=0.204, visibility=0.00
# Landmark 31 in pixels: x=832, y=2205
# Landmark 32: x=0.477, y=3.082, z=-0.001, visibility=0.00
# Landmark 32 in pixels: x=610, y=2219
# Landmark 0: x=0.629, y=-0.034, z=-1.021, visibility=1.00
# Landmark 0 in pixels: x=804, y=-24
# Landmark 1: x=0.655, y=-0.107, z=-0.991, visibility=1.00
# Landmark 1 in pixels: x=838, y=-76
# Landmark 2: x=0.671, y=-0.099, z=-0.990, visibility=1.00
# Landmark 2 in pixels: x=858, y=-70
# Landmark 3: x=0.685, y=-0.090, z=-0.991, visibility=1.00
# Landmark 3 in pixels: x=876, y=-65
# Landmark 4: x=0.609, y=-0.112, z=-0.987, visibility=1.00
# Landmark 4 in pixels: x=779, y=-80
# Landmark 5: x=0.594, y=-0.107, z=-0.987, visibility=1.00
# Landmark 5 in pixels: x=760, y=-76
# Landmark 6: x=0.580, y=-0.100, z=-0.987, visibility=1.00
# Landmark 6 in pixels: x=741, y=-71
# Landmark 7: x=0.710, y=-0.044, z=-0.727, visibility=1.00
# Landmark 7 in pixels: x=908, y=-31
# Landmark 8: x=0.563, y=-0.050, z=-0.691, visibility=1.00
# Landmark 8 in pixels: x=720, y=-36
# Landmark 9: x=0.656, y=0.046, z=-0.918, visibility=1.00
# Landmark 9 in pixels: x=839, y=33
# Landmark 10: x=0.596, y=0.049, z=-0.905, visibility=1.00
# Landmark 10 in pixels: x=762, y=35
# Landmark 11: x=0.855, y=0.307, z=-0.564, visibility=1.00
# Landmark 11 in pixels: x=1094, y=221
# Landmark 12: x=0.435, y=0.308, z=-0.549, visibility=1.00
# Landmark 12 in pixels: x=557, y=221
# Landmark 13: x=0.954, y=0.853, z=-0.423, visibility=0.73
# Landmark 13 in pixels: x=1220, y=614
# Landmark 14: x=0.306, y=0.823, z=-0.445, visibility=0.53
# Landmark 14 in pixels: x=391, y=592
# Landmark 15: x=1.002, y=1.424, z=-0.466, visibility=0.06
# Landmark 15 in pixels: x=1282, y=1025
# Landmark 16: x=0.179, y=1.375, z=-0.654, visibility=0.10
# Landmark 16 in pixels: x=229, y=989
# Landmark 17: x=1.045, y=1.580, z=-0.509, visibility=0.05
# Landmark 17 in pixels: x=1337, y=1137
# Landmark 18: x=0.121, y=1.515, z=-0.713, visibility=0.09
# Landmark 18 in pixels: x=154, y=1090
# Landmark 19: x=0.984, y=1.626, z=-0.568, visibility=0.09
# Landmark 19 in pixels: x=1259, y=1170
# Landmark 20: x=0.169, y=1.550, z=-0.820, visibility=0.14
# Landmark 20 in pixels: x=215, y=1116
# Landmark 21: x=0.959, y=1.567, z=-0.497, visibility=0.09
# Landmark 21 in pixels: x=1227, y=1128
# Landmark 22: x=0.201, y=1.504, z=-0.708, visibility=0.14
# Landmark 22 in pixels: x=257, y=1082
# Landmark 23: x=0.777, y=1.282, z=-0.057, visibility=0.00
# Landmark 23 in pixels: x=994, y=923
# Landmark 24: x=0.497, y=1.266, z=0.061, visibility=0.00
# Landmark 24 in pixels: x=635, y=911
# Landmark 25: x=0.738, y=2.106, z=0.060, visibility=0.00
# Landmark 25 in pixels: x=944, y=1516
# Landmark 26: x=0.461, y=2.090, z=0.142, visibility=0.00
# Landmark 26 in pixels: x=590, y=1504
# Landmark 27: x=0.704, y=2.826, z=0.747, visibility=0.00
# Landmark 27 in pixels: x=900, y=2034
# Landmark 28: x=0.440, y=2.816, z=0.615, visibility=0.00
# Landmark 28 in pixels: x=563, y=2027
# Landmark 29: x=0.710, y=2.941, z=0.789, visibility=0.00
# Landmark 29 in pixels: x=908, y=2117
# Landmark 30: x=0.432, y=2.928, z=0.647, visibility=0.00
# Landmark 30 in pixels: x=553, y=2108
# Landmark 31: x=0.651, y=3.068, z=0.309, visibility=0.00
# Landmark 31 in pixels: x=832, y=2208
# Landmark 32: x=0.478, y=3.087, z=0.078, visibility=0.00
# Landmark 32 in pixels: x=611, y=2222
# Error: Unable to read frame.

# %%
for lndmrk in mp_pose.PoseLandmark:
    print(f"{lndmrk.value}: {lndmrk.name}")
# Out:
# 0: NOSE
# 1: LEFT_EYE_INNER
# 2: LEFT_EYE
# 3: LEFT_EYE_OUTER
# 4: RIGHT_EYE_INNER
# 5: RIGHT_EYE
# 6: RIGHT_EYE_OUTER
# 7: LEFT_EAR
# 8: RIGHT_EAR
# 9: MOUTH_LEFT
# 10: MOUTH_RIGHT
# 11: LEFT_SHOULDER
# 12: RIGHT_SHOULDER
# 13: LEFT_ELBOW
# 14: RIGHT_ELBOW
# 15: LEFT_WRIST
# 16: RIGHT_WRIST
# 17: LEFT_PINKY
# 18: RIGHT_PINKY
# 19: LEFT_INDEX
# 20: RIGHT_INDEX
# 21: LEFT_THUMB
# 22: RIGHT_THUMB
# 23: LEFT_HIP
# 24: RIGHT_HIP
# 25: LEFT_KNEE
# 26: RIGHT_KNEE
# 27: LEFT_ANKLE
# 28: RIGHT_ANKLE
# 29: LEFT_HEEL
# 30: RIGHT_HEEL
# 31: LEFT_FOOT_INDEX
# 32: RIGHT_FOOT_INDEX

# %%
landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value]
# Out:
# x: 0.688451707
# y: 1.35051668
# z: -0.736725926
# visibility: 0.173643559

# %%
def calculate_angle(a, b, c):
    """
    Calculate the angle between three points using the cosine rule.
    
    Args:
        a: First point (x, y).
        b: Second point (x, y) - the joint point.
        c: Third point (x, y).
    
    Returns:
        angle: Angle in degrees.
    """
    a = np.array(a)
    b = np.array(b)
    c = np.array(c)

    # Calculate vectors
    ba = a - b
    bc = c - b

    # Calculate cosine angle using dot product
    cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
    
    # Convert from radians to degrees
    angle = np.degrees(np.arccos(cosine_angle))
    
    return angle

# Extract landmark coordinates
left_shoulder = (landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x * frame_width, 
                 landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y * frame_height)

left_elbow = (landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x * frame_width, 
              landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y * frame_height)

left_wrist = (landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x * frame_width, 
              landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y * frame_height)

# Calculate the angle
elbow_angle = calculate_angle(left_shoulder, left_elbow, left_wrist)

print(f"Left Elbow Angle: {elbow_angle:.2f} degrees")
# Out:
# Left Elbow Angle: 29.44 degrees

# %%
print("hello world")
# Out:
# hello world
