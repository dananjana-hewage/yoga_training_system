# %%
import math
from pickle import FALSE

import cv2
import numpy as np
from time import time
import mediapipe as mp
import matplotlib.pyplot as plt
from numpy.ma.core import left_shift

# %%
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

pose = mp_pose.Pose(
    static_image_mode=True,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5,
    model_complexity = 1
)
###################

# %%
def detectPose(image, pose, display=True):
    '''
    Perform pose detection on an image.
    Args:
        image: Input image with a prominent person for pose detection.
        pose: Mediapipe pose function for detection.
        display: If True, display the images and landmarks.
    Returns:
        output_image: Image with detected pose landmarks drawn.
        landmarks: List of detected landmarks in original scale.
    '''
    # Create a copy of the input image.
    output_image = image.copy()

    # Convert BGR to RGB format.
    imageRGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Perform Pose Detection.
    results = pose.process(imageRGB)

    # Retrieve the image dimensions.
    height, width, _ = image.shape

    # Initialize list for landmarks.
    landmarks = []

    # If landmarks are detected.
    if results.pose_landmarks:
        # Draw Pose landmarks on the image.
        mp_drawing.draw_landmarks(
            image=output_image,
            landmark_list=results.pose_landmarks,
            connections=mp_pose.POSE_CONNECTIONS
        )

        # Save the landmarks.
        for landmark in results.pose_landmarks.landmark:
            landmarks.append((int(landmark.x * width), int(landmark.y * height), landmark.z * width))

    # Display results if requested.
    if display:
        plt.figure(figsize=[22, 22])
        plt.subplot(121)
        plt.imshow(image[:, :, ::-1])
        plt.title("Original Image")
        plt.axis('off')
        plt.subplot(122)
        plt.imshow(output_image[:, :, ::-1])
        plt.title("Output Image")
        plt.axis('off')
        mp_drawing.plot_landmarks(results.pose_world_landmarks, mp_pose.POSE_CONNECTIONS)
    else:
        return output_image, landmarks

# %%
# Initialize Pose function for video.
pose_video = mp_pose.Pose(
    static_image_mode=False,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5,
    model_complexity=1
)

# Open the webcam (change index to 1 if another camera is used).
video = cv2.VideoCapture(0)

# Create named window for resizing.
cv2.namedWindow('Pose Detection', cv2.WINDOW_NORMAL)

# Set video resolution.
video.set(3, 1280)  # Width
video.set(4, 960)  # Height

# Initialize time for FPS calculation.
time1 = 0

# Video capture loop.
while video.isOpened():
    # Read a frame.
    ok, frame = video.read()

    # If frame is not read properly, break the loop.
    if not ok:
        print("Error: Unable to read frame.")
        break

    # Flip the frame horizontally for natural view.
    frame = cv2.flip(frame, 1)

    # Resize the frame.
    frame_height, frame_width, _ = frame.shape
    frame = cv2.resize(frame, (int(frame_width * (640 / frame_height)), 640))

    # Perform pose detection.
    try:
        # Convert the frame to RGB for processing.
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Perform pose detection.
        results = pose_video.process(rgb_frame)

        # If landmarks are detected, process them.
        if results.pose_landmarks:
            landmarks = results.pose_landmarks.landmark

            # Print and optionally process landmarks.
            for i, landmark in enumerate(landmarks):
                print(
                    f"Landmark {i}: x={landmark.x:.3f}, y={landmark.y:.3f}, visibility={landmark.visibility:.2f}"
                )

                # Optionally, convert normalized coordinates to pixels.
                pixel_x = int(landmark.x * frame_width)
                pixel_y = int(landmark.y * frame_height)
                print(f"Landmark {i} in pixels: x={pixel_x}, y={pixel_y}")

            # Draw pose landmarks on the frame.
            mp_drawing.draw_landmarks(
                frame,
                results.pose_landmarks,
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
            )

    except Exception as e:
        print("Error during pose detection:", e)
        continue

    # Calculate and display FPS.
    time2 = time()
    if (time2 - time1) > 0:
        fps = 1.0 / (time2 - time1)
        cv2.putText(frame, f'FPS: {int(fps)}', (10, 30), cv2.FONT_HERSHEY_PLAIN, 2, (0, 255, 0), 3)
    time1 = time2

    # Display the frame.
    cv2.imshow('Pose Detection', frame)

    # Break on 'ESC' key press.
    if cv2.waitKey(1) & 0xFF == 27:
        break

# Release the video capture object and close windows.
video.release()
cv2.destroyAllWindows()
# Out:
# Landmark 0: x=0.368, y=0.836, visibility=1.00
# Landmark 0 in pixels: x=470, y=602
# Landmark 1: x=0.406, y=0.746, visibility=1.00
# Landmark 1 in pixels: x=520, y=536
# Landmark 2: x=0.423, y=0.744, visibility=1.00
# Landmark 2 in pixels: x=541, y=535
# Landmark 3: x=0.437, y=0.742, visibility=1.00
# Landmark 3 in pixels: x=558, y=534
# Landmark 4: x=0.342, y=0.739, visibility=1.00
# Landmark 4 in pixels: x=437, y=531
# Landmark 5: x=0.324, y=0.732, visibility=1.00
# Landmark 5 in pixels: x=414, y=527
# Landmark 6: x=0.308, y=0.725, visibility=1.00
# Landmark 6 in pixels: x=393, y=522
# Landmark 7: x=0.464, y=0.727, visibility=1.00
# Landmark 7 in pixels: x=594, y=523
# Landmark 8: x=0.271, y=0.706, visibility=1.00
# Landmark 8 in pixels: x=346, y=508
# Landmark 9: x=0.396, y=0.909, visibility=0.99
# Landmark 9 in pixels: x=506, y=654
# Landmark 10: x=0.332, y=0.899, visibility=0.99
# Landmark 10 in pixels: x=424, y=647
# Landmark 11: x=0.496, y=0.956, visibility=0.87
# Landmark 11 in pixels: x=635, y=688
# Landmark 12: x=0.196, y=0.957, visibility=0.80
# Landmark 12 in pixels: x=251, y=688
# Landmark 13: x=0.542, y=1.032, visibility=0.11
# Landmark 13 in pixels: x=693, y=742
# Landmark 14: x=0.101, y=1.092, visibility=0.43
# Landmark 14 in pixels: x=129, y=786
# Landmark 15: x=0.545, y=1.003, visibility=0.14
# Landmark 15 in pixels: x=698, y=722
# Landmark 16: x=0.150, y=0.932, visibility=0.24
# Landmark 16 in pixels: x=192, y=671
# Landmark 17: x=0.557, y=1.002, visibility=0.18
# Landmark 17 in pixels: x=713, y=721
# Landmark 18: x=0.164, y=0.880, visibility=0.23
# Landmark 18 in pixels: x=209, y=633
# Landmark 19: x=0.549, y=0.983, visibility=0.21
# Landmark 19 in pixels: x=702, y=707
# Landmark 20: x=0.168, y=0.858, visibility=0.24
# Landmark 20 in pixels: x=214, y=617
# Landmark 21: x=0.537, y=0.984, visibility=0.21
# Landmark 21 in pixels: x=687, y=708
# Landmark 22: x=0.171, y=0.881, visibility=0.21
# Landmark 22 in pixels: x=218, y=634
# Landmark 23: x=0.424, y=1.503, visibility=0.01
# Landmark 23 in pixels: x=542, y=1081
# Landmark 24: x=0.271, y=1.507, visibility=0.01
# Landmark 24 in pixels: x=346, y=1085
# Landmark 25: x=0.473, y=1.165, visibility=0.06
# Landmark 25 in pixels: x=605, y=838
# Landmark 26: x=0.262, y=1.264, visibility=0.03
# Landmark 26 in pixels: x=335, y=909
# Landmark 27: x=0.433, y=1.256, visibility=0.01
# Landmark 27 in pixels: x=553, y=904
# Landmark 28: x=0.388, y=1.241, visibility=0.01
# Landmark 28 in pixels: x=496, y=893
# Landmark 29: x=0.405, y=1.315, visibility=0.02
# Landmark 29 in pixels: x=518, y=946
# Landmark 30: x=0.406, y=1.267, visibility=0.01
# Landmark 30 in pixels: x=519, y=912
# Landmark 31: x=0.446, y=1.274, visibility=0.02
# Landmark 31 in pixels: x=570, y=917
# Landmark 32: x=0.419, y=1.234, visibility=0.01
# Landmark 32 in pixels: x=535, y=888
# Landmark 0: x=0.370, y=0.838, visibility=1.00
# Landmark 0 in pixels: x=473, y=603
# Landmark 1: x=0.406, y=0.747, visibility=1.00
# Landmark 1 in pixels: x=520, y=537
# Landmark 2: x=0.423, y=0.745, visibility=1.00
# Landmark 2 in pixels: x=541, y=536
# Landmark 3: x=0.437, y=0.742, visibility=1.00
# Landmark 3 in pixels: x=559, y=534
# Landmark 4: x=0.346, y=0.738, visibility=1.00
# Landmark 4 in pixels: x=443, y=531
# Landmark 5: x=0.325, y=0.728, visibility=1.00
# Landmark 5 in pixels: x=416, y=523
# Landmark 6: x=0.309, y=0.718, visibility=1.00
# Landmark 6 in pixels: x=394, y=516
# Landmark 7: x=0.464, y=0.721, visibility=1.00
# Landmark 7 in pixels: x=594, y=518
# Landmark 8: x=0.278, y=0.700, visibility=1.00
# Landmark 8 in pixels: x=356, y=504
# Landmark 9: x=0.396, y=0.907, visibility=0.99
# Landmark 9 in pixels: x=506, y=653
# Landmark 10: x=0.334, y=0.898, visibility=0.99
# Landmark 10 in pixels: x=427, y=646
# Landmark 11: x=0.521, y=0.928, visibility=0.87
# Landmark 11 in pixels: x=667, y=668
# Landmark 12: x=0.198, y=0.941, visibility=0.82
# Landmark 12 in pixels: x=253, y=677
# Landmark 13: x=0.583, y=1.027, visibility=0.10
# Landmark 13 in pixels: x=746, y=739
# Landmark 14: x=0.095, y=1.077, visibility=0.43
# Landmark 14 in pixels: x=121, y=775
# Landmark 15: x=0.545, y=0.996, visibility=0.14
# Landmark 15 in pixels: x=697, y=716
# Landmark 16: x=0.152, y=0.968, visibility=0.23
# Landmark 16 in pixels: x=195, y=696
# Landmark 17: x=0.546, y=0.993, visibility=0.17
# Landmark 17 in pixels: x=699, y=715
# Landmark 18: x=0.174, y=0.943, visibility=0.21
# Landmark 18 in pixels: x=222, y=679
# Landmark 19: x=0.537, y=0.965, visibility=0.20
# Landmark 19 in pixels: x=686, y=694
# Landmark 20: x=0.180, y=0.914, visibility=0.22
# Landmark 20 in pixels: x=230, y=657
# Landmark 21: x=0.529, y=0.964, visibility=0.20
# Landmark 21 in pixels: x=677, y=693
# Landmark 22: x=0.180, y=0.923, visibility=0.20
# Landmark 22 in pixels: x=230, y=664
# Landmark 23: x=0.441, y=1.453, visibility=0.01
# Landmark 23 in pixels: x=564, y=1045
# Landmark 24: x=0.284, y=1.460, visibility=0.01
# Landmark 24 in pixels: x=362, y=1051
# Landmark 25: x=0.475, y=1.143, visibility=0.06
# Landmark 25 in pixels: x=608, y=822
# Landmark 26: x=0.263, y=1.259, visibility=0.03
# Landmark 26 in pixels: x=336, y=906
# Landmark 27: x=0.406, y=1.244, visibility=0.01
# Landmark 27 in pixels: x=520, y=895
# Landmark 28: x=0.353, y=1.240, visibility=0.01
# Landmark 28 in pixels: x=451, y=892
# Landmark 29: x=0.375, y=1.284, visibility=0.02
# Landmark 29 in pixels: x=480, y=924
# Landmark 30: x=0.363, y=1.259, visibility=0.01
# Landmark 30 in pixels: x=464, y=906
# Landmark 31: x=0.425, y=1.293, visibility=0.02
# Landmark 31 in pixels: x=543, y=930
# Landmark 32: x=0.369, y=1.244, visibility=0.01
# Landmark 32 in pixels: x=471, y=896
# Landmark 0: x=0.372, y=0.837, visibility=1.00
# Landmark 0 in pixels: x=475, y=602
# Landmark 1: x=0.406, y=0.747, visibility=1.00
# Landmark 1 in pixels: x=520, y=538
# Landmark 2: x=0.423, y=0.746, visibility=1.00
# Landmark 2 in pixels: x=541, y=537
# Landmark 3: x=0.437, y=0.744, visibility=1.00
# Landmark 3 in pixels: x=559, y=535
# Landmark 4: x=0.349, y=0.737, visibility=1.00
# Landmark 4 in pixels: x=447, y=530
# Landmark 5: x=0.328, y=0.725, visibility=1.00
# Landmark 5 in pixels: x=419, y=522
# Landmark 6: x=0.311, y=0.714, visibility=1.00
# Landmark 6 in pixels: x=397, y=514
# Landmark 7: x=0.464, y=0.722, visibility=1.00
# Landmark 7 in pixels: x=594, y=519
# Landmark 8: x=0.284, y=0.696, visibility=1.00
# Landmark 8 in pixels: x=363, y=501
# Landmark 9: x=0.396, y=0.902, visibility=0.99
# Landmark 9 in pixels: x=506, y=649
# Landmark 10: x=0.335, y=0.890, visibility=0.99
# Landmark 10 in pixels: x=429, y=640
# Landmark 11: x=0.523, y=0.935, visibility=0.88
# Landmark 11 in pixels: x=669, y=673
# Landmark 12: x=0.198, y=0.941, visibility=0.83
# Landmark 12 in pixels: x=253, y=677
# Landmark 13: x=0.578, y=1.045, visibility=0.10
# Landmark 13 in pixels: x=740, y=752
# Landmark 14: x=0.083, y=1.077, visibility=0.43
# Landmark 14 in pixels: x=106, y=775
# Landmark 15: x=0.545, y=0.987, visibility=0.15
# Landmark 15 in pixels: x=697, y=710
# Landmark 16: x=0.129, y=0.938, visibility=0.23
# Landmark 16 in pixels: x=165, y=675
# Landmark 17: x=0.547, y=0.973, visibility=0.18
# Landmark 17 in pixels: x=700, y=700
# Landmark 18: x=0.140, y=0.888, visibility=0.22
# Landmark 18 in pixels: x=178, y=639
# Landmark 19: x=0.537, y=0.945, visibility=0.21
# Landmark 19 in pixels: x=687, y=680
# Landmark 20: x=0.134, y=0.846, visibility=0.23
# Landmark 20 in pixels: x=171, y=609
# Landmark 21: x=0.529, y=0.950, visibility=0.21
# Landmark 21 in pixels: x=677, y=683
# Landmark 22: x=0.156, y=0.885, visibility=0.21
# Landmark 22 in pixels: x=200, y=637
# Landmark 23: x=0.447, y=1.470, visibility=0.01
# Landmark 23 in pixels: x=572, y=1058
# Landmark 24: x=0.286, y=1.464, visibility=0.01
# Landmark 24 in pixels: x=365, y=1054
# Landmark 25: x=0.478, y=1.147, visibility=0.06
# Landmark 25 in pixels: x=612, y=825
# Landmark 26: x=0.254, y=1.258, visibility=0.03
# Landmark 26 in pixels: x=324, y=906
# Landmark 27: x=0.409, y=1.290, visibility=0.01
# Landmark 27 in pixels: x=523, y=928
# Landmark 28: x=0.357, y=1.283, visibility=0.01
# Landmark 28 in pixels: x=457, y=923
# Landmark 29: x=0.377, y=1.353, visibility=0.02
# Landmark 29 in pixels: x=482, y=974
# Landmark 30: x=0.373, y=1.322, visibility=0.01
# Landmark 30 in pixels: x=477, y=951
# Landmark 31: x=0.423, y=1.318, visibility=0.02
# Landmark 31 in pixels: x=541, y=949
# Landmark 32: x=0.373, y=1.284, visibility=0.01
# Landmark 32 in pixels: x=477, y=924
# Landmark 0: x=0.373, y=0.833, visibility=1.00
# Landmark 0 in pixels: x=477, y=599
# Landmark 1: x=0.407, y=0.747, visibility=1.00
# Landmark 1 in pixels: x=521, y=537
# Landmark 2: x=0.424, y=0.746, visibility=1.00
# Landmark 2 in pixels: x=542, y=537
# Landmark 3: x=0.438, y=0.744, visibility=1.00
# Landmark 3 in pixels: x=560, y=535
# Landmark 4: x=0.353, y=0.734, visibility=1.00
# Landmark 4 in pixels: x=452, y=528
# Landmark 5: x=0.331, y=0.722, visibility=1.00
# Landmark 5 in pixels: x=423, y=520
# Landmark 6: x=0.313, y=0.712, visibility=1.00
# Landmark 6 in pixels: x=401, y=512
# Landmark 7: x=0.464, y=0.732, visibility=1.00
# Landmark 7 in pixels: x=594, y=526
# Landmark 8: x=0.286, y=0.696, visibility=1.00
# Landmark 8 in pixels: x=365, y=501
# Landmark 9: x=0.396, y=0.898, visibility=0.99
# Landmark 9 in pixels: x=507, y=646
# Landmark 10: x=0.336, y=0.886, visibility=0.99
# Landmark 10 in pixels: x=430, y=637
# Landmark 11: x=0.494, y=0.936, visibility=0.86
# Landmark 11 in pixels: x=632, y=673
# Landmark 12: x=0.198, y=0.943, visibility=0.82
# Landmark 12 in pixels: x=253, y=679
# Landmark 13: x=0.572, y=1.060, visibility=0.11
# Landmark 13 in pixels: x=732, y=763
# Landmark 14: x=0.083, y=1.092, visibility=0.43
# Landmark 14 in pixels: x=105, y=786
# Landmark 15: x=0.545, y=0.965, visibility=0.16
# Landmark 15 in pixels: x=697, y=695
# Landmark 16: x=0.130, y=0.921, visibility=0.24
# Landmark 16 in pixels: x=166, y=662
# Landmark 17: x=0.548, y=0.940, visibility=0.20
# Landmark 17 in pixels: x=701, y=676
# Landmark 18: x=0.141, y=0.856, visibility=0.23
# Landmark 18 in pixels: x=180, y=616
# Landmark 19: x=0.538, y=0.915, visibility=0.23
# Landmark 19 in pixels: x=688, y=658
# Landmark 20: x=0.147, y=0.829, visibility=0.24
# Landmark 20 in pixels: x=188, y=596
# Landmark 21: x=0.530, y=0.926, visibility=0.22
# Landmark 21 in pixels: x=678, y=666
# Landmark 22: x=0.162, y=0.862, visibility=0.21
# Landmark 22 in pixels: x=206, y=620
# Landmark 23: x=0.445, y=1.560, visibility=0.01
# Landmark 23 in pixels: x=570, y=1122
# Landmark 24: x=0.278, y=1.564, visibility=0.01
# Landmark 24 in pixels: x=355, y=1126
# Landmark 25: x=0.487, y=1.148, visibility=0.07
# Landmark 25 in pixels: x=623, y=826
# Landmark 26: x=0.253, y=1.259, visibility=0.03
# Landmark 26 in pixels: x=323, y=906
# Landmark 27: x=0.409, y=1.285, visibility=0.01
# Landmark 27 in pixels: x=523, y=925
# Landmark 28: x=0.361, y=1.263, visibility=0.01
# Landmark 28 in pixels: x=462, y=909
# Landmark 29: x=0.380, y=1.350, visibility=0.02
# Landmark 29 in pixels: x=486, y=972
# Landmark 30: x=0.378, y=1.315, visibility=0.01
# Landmark 30 in pixels: x=483, y=947
# Landmark 31: x=0.424, y=1.291, visibility=0.02
# Landmark 31 in pixels: x=543, y=929
# Landmark 32: x=0.377, y=1.207, visibility=0.01
# Landmark 32 in pixels: x=482, y=869
# Landmark 0: x=0.374, y=0.833, visibility=1.00
# Landmark 0 in pixels: x=478, y=599
# Landmark 1: x=0.408, y=0.746, visibility=1.00
# Landmark 1 in pixels: x=521, y=537
# Landmark 2: x=0.424, y=0.746, visibility=1.00
# Landmark 2 in pixels: x=542, y=537
# Landmark 3: x=0.439, y=0.745, visibility=1.00
# Landmark 3 in pixels: x=561, y=536
# Landmark 4: x=0.353, y=0.732, visibility=1.00
# Landmark 4 in pixels: x=452, y=526
# Landmark 5: x=0.331, y=0.718, visibility=1.00
# Landmark 5 in pixels: x=423, y=517
# Landmark 6: x=0.313, y=0.707, visibility=1.00
# Landmark 6 in pixels: x=400, y=509
# Landmark 7: x=0.464, y=0.740, visibility=1.00
# Landmark 7 in pixels: x=594, y=533
# Landmark 8: x=0.285, y=0.696, visibility=1.00
# Landmark 8 in pixels: x=364, y=500
# Landmark 9: x=0.396, y=0.899, visibility=0.99
# Landmark 9 in pixels: x=507, y=646
# Landmark 10: x=0.336, y=0.886, visibility=0.99
# Landmark 10 in pixels: x=430, y=637
# Landmark 11: x=0.487, y=0.944, visibility=0.85
# Landmark 11 in pixels: x=623, y=679
# Landmark 12: x=0.187, y=0.954, visibility=0.82
# Landmark 12 in pixels: x=239, y=686
# Landmark 13: x=0.573, y=1.097, visibility=0.12
# Landmark 13 in pixels: x=732, y=789
# Landmark 14: x=0.058, y=1.123, visibility=0.45
# Landmark 14 in pixels: x=74, y=808
# Landmark 15: x=0.568, y=0.971, visibility=0.17
# Landmark 15 in pixels: x=727, y=698
# Landmark 16: x=0.112, y=0.919, visibility=0.26
# Landmark 16 in pixels: x=143, y=662
# Landmark 17: x=0.579, y=0.949, visibility=0.21
# Landmark 17 in pixels: x=741, y=683
# Landmark 18: x=0.120, y=0.849, visibility=0.25
# Landmark 18 in pixels: x=153, y=611
# Landmark 19: x=0.571, y=0.926, visibility=0.24
# Landmark 19 in pixels: x=730, y=666
# Landmark 20: x=0.134, y=0.824, visibility=0.25
# Landmark 20 in pixels: x=171, y=593
# Landmark 21: x=0.559, y=0.932, visibility=0.23
# Landmark 21 in pixels: x=715, y=670
# Landmark 22: x=0.143, y=0.858, visibility=0.23
# Landmark 22 in pixels: x=183, y=617
# Landmark 23: x=0.435, y=1.600, visibility=0.01
# Landmark 23 in pixels: x=557, y=1151
# Landmark 24: x=0.262, y=1.591, visibility=0.01
# Landmark 24 in pixels: x=335, y=1145
# Landmark 25: x=0.486, y=1.161, visibility=0.07
# Landmark 25 in pixels: x=622, y=835
# Landmark 26: x=0.227, y=1.262, visibility=0.03
# Landmark 26 in pixels: x=291, y=908
# Landmark 27: x=0.412, y=1.285, visibility=0.01
# Landmark 27 in pixels: x=527, y=925
# Landmark 28: x=0.342, y=1.253, visibility=0.01
# Landmark 28 in pixels: x=438, y=901
# Landmark 29: x=0.383, y=1.356, visibility=0.02
# Landmark 29 in pixels: x=489, y=976
# Landmark 30: x=0.359, y=1.308, visibility=0.01
# Landmark 30 in pixels: x=459, y=941
# Landmark 31: x=0.424, y=1.279, visibility=0.02
# Landmark 31 in pixels: x=542, y=920
# Landmark 32: x=0.366, y=1.168, visibility=0.01
# Landmark 32 in pixels: x=468, y=841
# Landmark 0: x=0.373, y=0.833, visibility=1.00
# Landmark 0 in pixels: x=477, y=599
# Landmark 1: x=0.406, y=0.746, visibility=1.00
# Landmark 1 in pixels: x=519, y=537
# Landmark 2: x=0.423, y=0.746, visibility=1.00
# Landmark 2 in pixels: x=541, y=537
# Landmark 3: x=0.439, y=0.745, visibility=1.00
# Landmark 3 in pixels: x=561, y=536
# Landmark 4: x=0.352, y=0.731, visibility=1.00
# Landmark 4 in pixels: x=450, y=526
# Landmark 5: x=0.329, y=0.718, visibility=1.00
# Landmark 5 in pixels: x=420, y=516
# Landmark 6: x=0.312, y=0.708, visibility=1.00
# Landmark 6 in pixels: x=399, y=509
# Landmark 7: x=0.464, y=0.745, visibility=1.00
# Landmark 7 in pixels: x=593, y=536
# Landmark 8: x=0.284, y=0.697, visibility=1.00
# Landmark 8 in pixels: x=364, y=502
# Landmark 9: x=0.394, y=0.900, visibility=0.99
# Landmark 9 in pixels: x=504, y=647
# Landmark 10: x=0.334, y=0.886, visibility=0.99
# Landmark 10 in pixels: x=427, y=637
# Landmark 11: x=0.486, y=0.968, visibility=0.85
# Landmark 11 in pixels: x=622, y=696
# Landmark 12: x=0.181, y=0.963, visibility=0.82
# Landmark 12 in pixels: x=231, y=693
# Landmark 13: x=0.571, y=1.139, visibility=0.12
# Landmark 13 in pixels: x=730, y=819
# Landmark 14: x=0.040, y=1.131, visibility=0.48
# Landmark 14 in pixels: x=51, y=814
# Landmark 15: x=0.587, y=1.000, visibility=0.18
# Landmark 15 in pixels: x=750, y=719
# Landmark 16: x=0.078, y=0.874, visibility=0.29
# Landmark 16 in pixels: x=99, y=629
# Landmark 17: x=0.603, y=0.967, visibility=0.22
# Landmark 17 in pixels: x=771, y=696
# Landmark 18: x=0.095, y=0.806, visibility=0.27
# Landmark 18 in pixels: x=121, y=580
# Landmark 19: x=0.598, y=0.940, visibility=0.25
# Landmark 19 in pixels: x=764, y=676
# Landmark 20: x=0.100, y=0.766, visibility=0.28
# Landmark 20 in pixels: x=128, y=551
# Landmark 21: x=0.584, y=0.955, visibility=0.24
# Landmark 21 in pixels: x=746, y=687
# Landmark 22: x=0.102, y=0.818, visibility=0.25
# Landmark 22 in pixels: x=130, y=588
# Landmark 23: x=0.425, y=1.643, visibility=0.01
# Landmark 23 in pixels: x=544, y=1182
# Landmark 24: x=0.256, y=1.616, visibility=0.01
# Landmark 24 in pixels: x=327, y=1163
# Landmark 25: x=0.464, y=1.219, visibility=0.07
# Landmark 25 in pixels: x=593, y=877
# Landmark 26: x=0.220, y=1.288, visibility=0.03
# Landmark 26 in pixels: x=281, y=927
# Landmark 27: x=0.406, y=1.299, visibility=0.01
# Landmark 27 in pixels: x=519, y=935
# Landmark 28: x=0.313, y=1.252, visibility=0.01
# Landmark 28 in pixels: x=400, y=901
# Landmark 29: x=0.375, y=1.371, visibility=0.02
# Landmark 29 in pixels: x=480, y=986
# Landmark 30: x=0.326, y=1.304, visibility=0.01
# Landmark 30 in pixels: x=417, y=938
# Landmark 31: x=0.407, y=1.280, visibility=0.02
# Landmark 31 in pixels: x=521, y=921
# Landmark 32: x=0.322, y=1.178, visibility=0.01
# Landmark 32 in pixels: x=412, y=848
# Landmark 0: x=0.371, y=0.832, visibility=1.00
# Landmark 0 in pixels: x=474, y=599
# Landmark 1: x=0.403, y=0.746, visibility=1.00
# Landmark 1 in pixels: x=516, y=537
# Landmark 2: x=0.420, y=0.746, visibility=1.00
# Landmark 2 in pixels: x=538, y=537
# Landmark 3: x=0.437, y=0.745, visibility=1.00
# Landmark 3 in pixels: x=558, y=536
# Landmark 4: x=0.348, y=0.728, visibility=1.00
# Landmark 4 in pixels: x=445, y=524
# Landmark 5: x=0.326, y=0.716, visibility=1.00
# Landmark 5 in pixels: x=417, y=515
# Landmark 6: x=0.310, y=0.706, visibility=1.00
# Landmark 6 in pixels: x=396, y=508
# Landmark 7: x=0.460, y=0.745, visibility=1.00
# Landmark 7 in pixels: x=589, y=536
# Landmark 8: x=0.283, y=0.697, visibility=1.00
# Landmark 8 in pixels: x=362, y=502
# Landmark 9: x=0.392, y=0.900, visibility=0.99
# Landmark 9 in pixels: x=501, y=648
# Landmark 10: x=0.330, y=0.886, visibility=0.99
# Landmark 10 in pixels: x=422, y=637
# Landmark 11: x=0.474, y=0.978, visibility=0.85
# Landmark 11 in pixels: x=606, y=704
# Landmark 12: x=0.175, y=0.976, visibility=0.83
# Landmark 12 in pixels: x=223, y=702
# Landmark 13: x=0.570, y=1.138, visibility=0.13
# Landmark 13 in pixels: x=729, y=819
# Landmark 14: x=0.046, y=1.177, visibility=0.48
# Landmark 14 in pixels: x=59, y=847
# Landmark 15: x=0.579, y=1.007, visibility=0.18
# Landmark 15 in pixels: x=741, y=724
# Landmark 16: x=0.110, y=0.931, visibility=0.29
# Landmark 16 in pixels: x=140, y=670
# Landmark 17: x=0.593, y=0.971, visibility=0.22
# Landmark 17 in pixels: x=758, y=699
# Landmark 18: x=0.129, y=0.860, visibility=0.28
# Landmark 18 in pixels: x=165, y=618
# Landmark 19: x=0.587, y=0.943, visibility=0.25
# Landmark 19 in pixels: x=750, y=679
# Landmark 20: x=0.136, y=0.825, visibility=0.29
# Landmark 20 in pixels: x=173, y=593
# Landmark 21: x=0.574, y=0.961, visibility=0.25
# Landmark 21 in pixels: x=734, y=691
# Landmark 22: x=0.138, y=0.862, visibility=0.26
# Landmark 22 in pixels: x=176, y=620
# Landmark 23: x=0.416, y=1.680, visibility=0.01
# Landmark 23 in pixels: x=532, y=1209
# Landmark 24: x=0.247, y=1.679, visibility=0.01
# Landmark 24 in pixels: x=316, y=1208
# Landmark 25: x=0.464, y=1.271, visibility=0.08
# Landmark 25 in pixels: x=594, y=915
# Landmark 26: x=0.238, y=1.335, visibility=0.04
# Landmark 26 in pixels: x=304, y=960
# Landmark 27: x=0.408, y=1.390, visibility=0.01
# Landmark 27 in pixels: x=521, y=1001
# Landmark 28: x=0.328, y=1.334, visibility=0.01
# Landmark 28 in pixels: x=420, y=960
# Landmark 29: x=0.377, y=1.464, visibility=0.02
# Landmark 29 in pixels: x=482, y=1053
# Landmark 30: x=0.340, y=1.378, visibility=0.01
# Landmark 30 in pixels: x=435, y=992
# Landmark 31: x=0.412, y=1.378, visibility=0.02
# Landmark 31 in pixels: x=527, y=992
# Landmark 32: x=0.346, y=1.292, visibility=0.01
# Landmark 32 in pixels: x=442, y=930
# Landmark 0: x=0.366, y=0.828, visibility=1.00
# Landmark 0 in pixels: x=467, y=596
# Landmark 1: x=0.400, y=0.746, visibility=1.00
# Landmark 1 in pixels: x=511, y=536
# Landmark 2: x=0.418, y=0.746, visibility=1.00
# Landmark 2 in pixels: x=534, y=536
# Landmark 3: x=0.435, y=0.745, visibility=1.00
# Landmark 3 in pixels: x=556, y=536
# Landmark 4: x=0.343, y=0.727, visibility=1.00
# Landmark 4 in pixels: x=438, y=523
# Landmark 5: x=0.322, y=0.715, visibility=1.00
# Landmark 5 in pixels: x=411, y=514
# Landmark 6: x=0.306, y=0.705, visibility=1.00
# Landmark 6 in pixels: x=391, y=507
# Landmark 7: x=0.458, y=0.745, visibility=1.00
# Landmark 7 in pixels: x=586, y=536
# Landmark 8: x=0.279, y=0.697, visibility=1.00
# Landmark 8 in pixels: x=357, y=502
# Landmark 9: x=0.390, y=0.901, visibility=0.99
# Landmark 9 in pixels: x=498, y=648
# Landmark 10: x=0.324, y=0.885, visibility=0.99
# Landmark 10 in pixels: x=414, y=637
# Landmark 11: x=0.481, y=0.994, visibility=0.85
# Landmark 11 in pixels: x=615, y=715
# Landmark 12: x=0.161, y=0.985, visibility=0.84
# Landmark 12 in pixels: x=205, y=709
# Landmark 13: x=0.595, y=1.237, visibility=0.15
# Landmark 13 in pixels: x=761, y=890
# Landmark 14: x=0.043, y=1.246, visibility=0.48
# Landmark 14 in pixels: x=55, y=896
# Landmark 15: x=0.577, y=1.053, visibility=0.19
# Landmark 15 in pixels: x=738, y=758
# Landmark 16: x=0.106, y=0.955, visibility=0.30
# Landmark 16 in pixels: x=136, y=687
# Landmark 17: x=0.589, y=1.000, visibility=0.24
# Landmark 17 in pixels: x=753, y=720
# Landmark 18: x=0.129, y=0.912, visibility=0.29
# Landmark 18 in pixels: x=164, y=656
# Landmark 19: x=0.581, y=0.962, visibility=0.27
# Landmark 19 in pixels: x=744, y=692
# Landmark 20: x=0.137, y=0.874, visibility=0.30
# Landmark 20 in pixels: x=175, y=629
# Landmark 21: x=0.570, y=0.990, visibility=0.26
# Landmark 21 in pixels: x=730, y=712
# Landmark 22: x=0.141, y=0.911, visibility=0.26
# Landmark 22 in pixels: x=180, y=655
# Landmark 23: x=0.417, y=1.734, visibility=0.01
# Landmark 23 in pixels: x=533, y=1248
# Landmark 24: x=0.245, y=1.703, visibility=0.01
# Landmark 24 in pixels: x=314, y=1226
# Landmark 25: x=0.447, y=1.508, visibility=0.08
# Landmark 25 in pixels: x=571, y=1085
# Landmark 26: x=0.222, y=1.542, visibility=0.03
# Landmark 26 in pixels: x=284, y=1110
# Landmark 27: x=0.409, y=1.708, visibility=0.01
# Landmark 27 in pixels: x=523, y=1229
# Landmark 28: x=0.304, y=1.636, visibility=0.01
# Landmark 28 in pixels: x=389, y=1177
# Landmark 29: x=0.386, y=1.784, visibility=0.02
# Landmark 29 in pixels: x=493, y=1284
# Landmark 30: x=0.319, y=1.681, visibility=0.01
# Landmark 30 in pixels: x=408, y=1210
# Landmark 31: x=0.414, y=1.738, visibility=0.02
# Landmark 31 in pixels: x=530, y=1251
# Landmark 32: x=0.305, y=1.656, visibility=0.01
# Landmark 32 in pixels: x=390, y=1192
# Landmark 0: x=0.365, y=0.828, visibility=1.00
# Landmark 0 in pixels: x=467, y=596
# Landmark 1: x=0.400, y=0.745, visibility=1.00
# Landmark 1 in pixels: x=512, y=536
# Landmark 2: x=0.418, y=0.745, visibility=1.00
# Landmark 2 in pixels: x=534, y=536
# Landmark 3: x=0.435, y=0.745, visibility=1.00
# Landmark 3 in pixels: x=557, y=536
# Landmark 4: x=0.343, y=0.726, visibility=1.00
# Landmark 4 in pixels: x=438, y=522
# Landmark 5: x=0.322, y=0.713, visibility=1.00
# Landmark 5 in pixels: x=411, y=513
# Landmark 6: x=0.305, y=0.702, visibility=1.00
# Landmark 6 in pixels: x=390, y=505
# Landmark 7: x=0.458, y=0.745, visibility=1.00
# Landmark 7 in pixels: x=586, y=536
# Landmark 8: x=0.278, y=0.697, visibility=1.00
# Landmark 8 in pixels: x=355, y=501
# Landmark 9: x=0.389, y=0.903, visibility=0.99
# Landmark 9 in pixels: x=498, y=650
# Landmark 10: x=0.323, y=0.885, visibility=0.99
# Landmark 10 in pixels: x=412, y=637
# Landmark 11: x=0.482, y=1.000, visibility=0.84
# Landmark 11 in pixels: x=617, y=720
# Landmark 12: x=0.154, y=0.989, visibility=0.84
# Landmark 12 in pixels: x=197, y=712
# Landmark 13: x=0.590, y=1.224, visibility=0.15
# Landmark 13 in pixels: x=754, y=881
# Landmark 14: x=0.036, y=1.246, visibility=0.50
# Landmark 14 in pixels: x=46, y=897
# Landmark 15: x=0.560, y=1.049, visibility=0.20
# Landmark 15 in pixels: x=716, y=755
# Landmark 16: x=0.081, y=0.954, visibility=0.31
# Landmark 16 in pixels: x=103, y=686
# Landmark 17: x=0.561, y=1.002, visibility=0.25
# Landmark 17 in pixels: x=717, y=721
# Landmark 18: x=0.109, y=0.904, visibility=0.30
# Landmark 18 in pixels: x=139, y=651
# Landmark 19: x=0.550, y=0.955, visibility=0.28
# Landmark 19 in pixels: x=703, y=687
# Landmark 20: x=0.117, y=0.860, visibility=0.31
# Landmark 20 in pixels: x=149, y=619
# Landmark 21: x=0.542, y=0.963, visibility=0.27
# Landmark 21 in pixels: x=693, y=693
# Landmark 22: x=0.126, y=0.900, visibility=0.27
# Landmark 22 in pixels: x=160, y=648
# Landmark 23: x=0.417, y=1.730, visibility=0.01
# Landmark 23 in pixels: x=533, y=1245
# Landmark 24: x=0.238, y=1.701, visibility=0.01
# Landmark 24 in pixels: x=304, y=1224
# Landmark 25: x=0.446, y=1.379, visibility=0.07
# Landmark 25 in pixels: x=571, y=992
# Landmark 26: x=0.196, y=1.458, visibility=0.04
# Landmark 26 in pixels: x=250, y=1049
# Landmark 27: x=0.401, y=1.519, visibility=0.01
# Landmark 27 in pixels: x=512, y=1093
# Landmark 28: x=0.286, y=1.493, visibility=0.01
# Landmark 28 in pixels: x=366, y=1075
# Landmark 29: x=0.370, y=1.589, visibility=0.01
# Landmark 29 in pixels: x=474, y=1144
# Landmark 30: x=0.299, y=1.515, visibility=0.01
# Landmark 30 in pixels: x=382, y=1090
# Landmark 31: x=0.414, y=1.537, visibility=0.02
# Landmark 31 in pixels: x=529, y=1106
# Landmark 32: x=0.300, y=1.525, visibility=0.01
# Landmark 32 in pixels: x=384, y=1098
# Landmark 0: x=0.365, y=0.830, visibility=1.00
# Landmark 0 in pixels: x=466, y=597
# Landmark 1: x=0.400, y=0.747, visibility=1.00
# Landmark 1 in pixels: x=511, y=537
# Landmark 2: x=0.418, y=0.747, visibility=1.00
# Landmark 2 in pixels: x=534, y=537
# Landmark 3: x=0.435, y=0.747, visibility=1.00
# Landmark 3 in pixels: x=556, y=537
# Landmark 4: x=0.343, y=0.726, visibility=1.00
# Landmark 4 in pixels: x=438, y=522
# Landmark 5: x=0.322, y=0.714, visibility=1.00
# Landmark 5 in pixels: x=411, y=513
# Landmark 6: x=0.305, y=0.703, visibility=1.00
# Landmark 6 in pixels: x=390, y=505
# Landmark 7: x=0.458, y=0.745, visibility=1.00
# Landmark 7 in pixels: x=585, y=536
# Landmark 8: x=0.277, y=0.696, visibility=1.00
# Landmark 8 in pixels: x=355, y=501
# Landmark 9: x=0.389, y=0.912, visibility=0.99
# Landmark 9 in pixels: x=497, y=656
# Landmark 10: x=0.321, y=0.888, visibility=0.99
# Landmark 10 in pixels: x=410, y=639
# Landmark 11: x=0.483, y=0.998, visibility=0.85
# Landmark 11 in pixels: x=617, y=718
# Landmark 12: x=0.151, y=0.987, visibility=0.85
# Landmark 12 in pixels: x=193, y=710
# Landmark 13: x=0.587, y=1.196, visibility=0.16
# Landmark 13 in pixels: x=751, y=860
# Landmark 14: x=0.037, y=1.274, visibility=0.49
# Landmark 14 in pixels: x=46, y=917
# Landmark 15: x=0.546, y=1.042, visibility=0.23
# Landmark 15 in pixels: x=698, y=749
# Landmark 16: x=0.113, y=1.008, visibility=0.32
# Landmark 16 in pixels: x=145, y=725
# Landmark 17: x=0.548, y=0.987, visibility=0.28
# Landmark 17 in pixels: x=701, y=710
# Landmark 18: x=0.138, y=0.937, visibility=0.32
# Landmark 18 in pixels: x=176, y=674
# Landmark 19: x=0.538, y=0.943, visibility=0.31
# Landmark 19 in pixels: x=689, y=678
# Landmark 20: x=0.144, y=0.890, visibility=0.33
# Landmark 20 in pixels: x=183, y=640
# Landmark 21: x=0.507, y=0.946, visibility=0.30
# Landmark 21 in pixels: x=648, y=680
# Landmark 22: x=0.152, y=0.923, visibility=0.28
# Landmark 22 in pixels: x=194, y=664
# Landmark 23: x=0.416, y=1.698, visibility=0.01
# Landmark 23 in pixels: x=532, y=1222
# Landmark 24: x=0.236, y=1.682, visibility=0.01
# Landmark 24 in pixels: x=302, y=1211
# Landmark 25: x=0.443, y=1.368, visibility=0.07
# Landmark 25 in pixels: x=567, y=984
# Landmark 26: x=0.206, y=1.415, visibility=0.04
# Landmark 26 in pixels: x=263, y=1019
# Landmark 27: x=0.402, y=1.544, visibility=0.01
# Landmark 27 in pixels: x=514, y=1111
# Landmark 28: x=0.294, y=1.493, visibility=0.01
# Landmark 28 in pixels: x=375, y=1074
# Landmark 29: x=0.372, y=1.618, visibility=0.01
# Landmark 29 in pixels: x=476, y=1164
# Landmark 30: x=0.304, y=1.533, visibility=0.01
# Landmark 30 in pixels: x=388, y=1103
# Landmark 31: x=0.418, y=1.571, visibility=0.02
# Landmark 31 in pixels: x=534, y=1131
# Landmark 32: x=0.314, y=1.509, visibility=0.01
# Landmark 32 in pixels: x=402, y=1086
# Landmark 0: x=0.364, y=0.830, visibility=1.00
# Landmark 0 in pixels: x=466, y=597
# Landmark 1: x=0.399, y=0.747, visibility=1.00
# Landmark 1 in pixels: x=511, y=537
# Landmark 2: x=0.417, y=0.747, visibility=1.00
# Landmark 2 in pixels: x=534, y=538
# Landmark 3: x=0.435, y=0.747, visibility=1.00
# Landmark 3 in pixels: x=556, y=537
# Landmark 4: x=0.343, y=0.726, visibility=1.00
# Landmark 4 in pixels: x=438, y=522
# Landmark 5: x=0.321, y=0.714, visibility=1.00
# Landmark 5 in pixels: x=411, y=513
# Landmark 6: x=0.304, y=0.703, visibility=1.00
# Landmark 6 in pixels: x=389, y=505
# Landmark 7: x=0.455, y=0.745, visibility=1.00
# Landmark 7 in pixels: x=582, y=536
# Landmark 8: x=0.275, y=0.696, visibility=1.00
# Landmark 8 in pixels: x=352, y=501
# Landmark 9: x=0.387, y=0.913, visibility=0.99
# Landmark 9 in pixels: x=495, y=657
# Landmark 10: x=0.319, y=0.887, visibility=0.99
# Landmark 10 in pixels: x=408, y=638
# Landmark 11: x=0.478, y=0.996, visibility=0.85
# Landmark 11 in pixels: x=611, y=717
# Landmark 12: x=0.152, y=0.986, visibility=0.86
# Landmark 12 in pixels: x=194, y=709
# Landmark 13: x=0.556, y=1.208, visibility=0.17
# Landmark 13 in pixels: x=711, y=869
# Landmark 14: x=0.076, y=1.294, visibility=0.49
# Landmark 14 in pixels: x=96, y=932
# Landmark 15: x=0.501, y=1.008, visibility=0.26
# Landmark 15 in pixels: x=641, y=725
# Landmark 16: x=0.173, y=1.005, visibility=0.34
# Landmark 16 in pixels: x=220, y=723
# Landmark 17: x=0.505, y=0.972, visibility=0.31
# Landmark 17 in pixels: x=645, y=700
# Landmark 18: x=0.199, y=0.927, visibility=0.34
# Landmark 18 in pixels: x=254, y=667
# Landmark 19: x=0.499, y=0.932, visibility=0.34
# Landmark 19 in pixels: x=638, y=671
# Landmark 20: x=0.199, y=0.884, visibility=0.35
# Landmark 20 in pixels: x=255, y=636
# Landmark 21: x=0.480, y=0.944, visibility=0.33
# Landmark 21 in pixels: x=615, y=679
# Landmark 22: x=0.205, y=0.918, visibility=0.30
# Landmark 22 in pixels: x=262, y=660
# Landmark 23: x=0.410, y=1.701, visibility=0.01
# Landmark 23 in pixels: x=524, y=1224
# Landmark 24: x=0.233, y=1.690, visibility=0.01
# Landmark 24 in pixels: x=297, y=1216
# Landmark 25: x=0.420, y=1.405, visibility=0.07
# Landmark 25 in pixels: x=538, y=1011
# Landmark 26: x=0.220, y=1.445, visibility=0.04
# Landmark 26 in pixels: x=281, y=1040
# Landmark 27: x=0.395, y=1.621, visibility=0.01
# Landmark 27 in pixels: x=506, y=1167
# Landmark 28: x=0.298, y=1.565, visibility=0.01
# Landmark 28 in pixels: x=381, y=1127
# Landmark 29: x=0.371, y=1.701, visibility=0.01
# Landmark 29 in pixels: x=474, y=1224
# Landmark 30: x=0.313, y=1.600, visibility=0.00
# Landmark 30 in pixels: x=401, y=1151
# Landmark 31: x=0.411, y=1.651, visibility=0.02
# Landmark 31 in pixels: x=526, y=1188
# Landmark 32: x=0.319, y=1.618, visibility=0.01
# Landmark 32 in pixels: x=408, y=1164
# Landmark 0: x=0.364, y=0.830, visibility=1.00
# Landmark 0 in pixels: x=466, y=597
# Landmark 1: x=0.399, y=0.747, visibility=1.00
# Landmark 1 in pixels: x=510, y=537
# Landmark 2: x=0.417, y=0.748, visibility=1.00
# Landmark 2 in pixels: x=534, y=538
# Landmark 3: x=0.435, y=0.748, visibility=1.00
# Landmark 3 in pixels: x=556, y=538
# Landmark 4: x=0.343, y=0.726, visibility=1.00
# Landmark 4 in pixels: x=438, y=522
# Landmark 5: x=0.321, y=0.714, visibility=1.00
# Landmark 5 in pixels: x=410, y=513
# Landmark 6: x=0.304, y=0.703, visibility=1.00
# Landmark 6 in pixels: x=388, y=505
# Landmark 7: x=0.455, y=0.748, visibility=1.00
# Landmark 7 in pixels: x=582, y=538
# Landmark 8: x=0.274, y=0.697, visibility=1.00
# Landmark 8 in pixels: x=350, y=501
# Landmark 9: x=0.388, y=0.915, visibility=0.99
# Landmark 9 in pixels: x=496, y=658
# Landmark 10: x=0.319, y=0.888, visibility=0.99
# Landmark 10 in pixels: x=407, y=639
# Landmark 11: x=0.479, y=0.998, visibility=0.84
# Landmark 11 in pixels: x=613, y=718
# Landmark 12: x=0.155, y=0.985, visibility=0.87
# Landmark 12 in pixels: x=197, y=709
# Landmark 13: x=0.548, y=1.250, visibility=0.17
# Landmark 13 in pixels: x=701, y=900
# Landmark 14: x=0.064, y=1.270, visibility=0.48
# Landmark 14 in pixels: x=82, y=914
# Landmark 15: x=0.493, y=1.000, visibility=0.26
# Landmark 15 in pixels: x=631, y=720
# Landmark 16: x=0.152, y=0.995, visibility=0.34
# Landmark 16 in pixels: x=194, y=716
# Landmark 17: x=0.493, y=0.973, visibility=0.32
# Landmark 17 in pixels: x=630, y=700
# Landmark 18: x=0.170, y=0.919, visibility=0.34
# Landmark 18 in pixels: x=218, y=661
# Landmark 19: x=0.491, y=0.934, visibility=0.35
# Landmark 19 in pixels: x=627, y=672
# Landmark 20: x=0.173, y=0.882, visibility=0.36
# Landmark 20 in pixels: x=221, y=634
# Landmark 21: x=0.477, y=0.950, visibility=0.34
# Landmark 21 in pixels: x=610, y=684
# Landmark 22: x=0.185, y=0.915, visibility=0.31
# Landmark 22 in pixels: x=236, y=658
# Landmark 23: x=0.410, y=1.760, visibility=0.01
# Landmark 23 in pixels: x=525, y=1267
# Landmark 24: x=0.233, y=1.725, visibility=0.01
# Landmark 24 in pixels: x=298, y=1242
# Landmark 25: x=0.408, y=1.488, visibility=0.07
# Landmark 25 in pixels: x=521, y=1071
# Landmark 26: x=0.205, y=1.493, visibility=0.04
# Landmark 26 in pixels: x=262, y=1074
# Landmark 27: x=0.384, y=1.687, visibility=0.01
# Landmark 27 in pixels: x=491, y=1214
# Landmark 28: x=0.298, y=1.606, visibility=0.00
# Landmark 28 in pixels: x=381, y=1156
# Landmark 29: x=0.364, y=1.771, visibility=0.01
# Landmark 29 in pixels: x=466, y=1275
# Landmark 30: x=0.316, y=1.650, visibility=0.00
# Landmark 30 in pixels: x=404, y=1188
# Landmark 31: x=0.388, y=1.698, visibility=0.02
# Landmark 31 in pixels: x=496, y=1222
# Landmark 32: x=0.298, y=1.632, visibility=0.01
# Landmark 32 in pixels: x=381, y=1174
# Landmark 0: x=0.362, y=0.835, visibility=1.00
# Landmark 0 in pixels: x=463, y=600
# Landmark 1: x=0.398, y=0.749, visibility=1.00
# Landmark 1 in pixels: x=509, y=539
# Landmark 2: x=0.417, y=0.751, visibility=1.00
# Landmark 2 in pixels: x=533, y=540
# Landmark 3: x=0.435, y=0.753, visibility=1.00
# Landmark 3 in pixels: x=556, y=542
# Landmark 4: x=0.340, y=0.726, visibility=1.00
# Landmark 4 in pixels: x=434, y=522
# Landmark 5: x=0.318, y=0.714, visibility=1.00
# Landmark 5 in pixels: x=407, y=514
# Landmark 6: x=0.301, y=0.703, visibility=1.00
# Landmark 6 in pixels: x=385, y=506
# Landmark 7: x=0.455, y=0.757, visibility=1.00
# Landmark 7 in pixels: x=582, y=544
# Landmark 8: x=0.272, y=0.697, visibility=1.00
# Landmark 8 in pixels: x=348, y=502
# Landmark 9: x=0.387, y=0.922, visibility=0.99
# Landmark 9 in pixels: x=495, y=663
# Landmark 10: x=0.317, y=0.893, visibility=1.00
# Landmark 10 in pixels: x=405, y=642
# Landmark 11: x=0.480, y=1.002, visibility=0.84
# Landmark 11 in pixels: x=614, y=721
# Landmark 12: x=0.153, y=0.986, visibility=0.87
# Landmark 12 in pixels: x=195, y=709
# Landmark 13: x=0.547, y=1.262, visibility=0.19
# Landmark 13 in pixels: x=699, y=908
# Landmark 14: x=0.068, y=1.295, visibility=0.46
# Landmark 14 in pixels: x=86, y=932
# Landmark 15: x=0.496, y=0.997, visibility=0.28
# Landmark 15 in pixels: x=634, y=718
# Landmark 16: x=0.149, y=1.011, visibility=0.34
# Landmark 16 in pixels: x=190, y=727
# Landmark 17: x=0.507, y=0.967, visibility=0.35
# Landmark 17 in pixels: x=649, y=696
# Landmark 18: x=0.168, y=0.923, visibility=0.35
# Landmark 18 in pixels: x=215, y=664
# Landmark 19: x=0.502, y=0.923, visibility=0.38
# Landmark 19 in pixels: x=643, y=664
# Landmark 20: x=0.170, y=0.888, visibility=0.36
# Landmark 20 in pixels: x=217, y=639
# Landmark 21: x=0.486, y=0.933, visibility=0.36
# Landmark 21 in pixels: x=621, y=671
# Landmark 22: x=0.183, y=0.924, visibility=0.31
# Landmark 22 in pixels: x=233, y=665
# Landmark 23: x=0.411, y=1.758, visibility=0.01
# Landmark 23 in pixels: x=525, y=1265
# Landmark 24: x=0.232, y=1.729, visibility=0.01
# Landmark 24 in pixels: x=296, y=1245
# Landmark 25: x=0.417, y=1.466, visibility=0.06
# Landmark 25 in pixels: x=534, y=1055
# Landmark 26: x=0.200, y=1.490, visibility=0.03
# Landmark 26 in pixels: x=255, y=1072
# Landmark 27: x=0.391, y=1.649, visibility=0.01
# Landmark 27 in pixels: x=500, y=1187
# Landmark 28: x=0.294, y=1.579, visibility=0.00
# Landmark 28 in pixels: x=376, y=1136
# Landmark 29: x=0.372, y=1.728, visibility=0.01
# Landmark 29 in pixels: x=475, y=1244
# Landmark 30: x=0.312, y=1.623, visibility=0.00
# Landmark 30 in pixels: x=399, y=1168
# Landmark 31: x=0.402, y=1.666, visibility=0.02
# Landmark 31 in pixels: x=514, y=1199
# Landmark 32: x=0.301, y=1.593, visibility=0.01
# Landmark 32 in pixels: x=384, y=1146
# Landmark 0: x=0.363, y=0.836, visibility=1.00
# Landmark 0 in pixels: x=464, y=602
# Landmark 1: x=0.398, y=0.749, visibility=1.00
# Landmark 1 in pixels: x=509, y=539
# Landmark 2: x=0.418, y=0.752, visibility=1.00
# Landmark 2 in pixels: x=534, y=541
# Landmark 3: x=0.436, y=0.754, visibility=1.00
# Landmark 3 in pixels: x=557, y=543
# Landmark 4: x=0.340, y=0.726, visibility=1.00
# Landmark 4 in pixels: x=435, y=522
# Landmark 5: x=0.319, y=0.714, visibility=1.00
# Landmark 5 in pixels: x=407, y=514
# Landmark 6: x=0.301, y=0.703, visibility=1.00
# Landmark 6 in pixels: x=385, y=506
# Landmark 7: x=0.455, y=0.758, visibility=1.00
# Landmark 7 in pixels: x=582, y=545
# Landmark 8: x=0.272, y=0.698, visibility=1.00
# Landmark 8 in pixels: x=347, y=502
# Landmark 9: x=0.387, y=0.924, visibility=0.99
# Landmark 9 in pixels: x=495, y=665
# Landmark 10: x=0.317, y=0.895, visibility=1.00
# Landmark 10 in pixels: x=406, y=644
# Landmark 11: x=0.479, y=1.000, visibility=0.85
# Landmark 11 in pixels: x=613, y=720
# Landmark 12: x=0.152, y=0.986, visibility=0.88
# Landmark 12 in pixels: x=194, y=710
# Landmark 13: x=0.548, y=1.257, visibility=0.19
# Landmark 13 in pixels: x=700, y=905
# Landmark 14: x=0.092, y=1.314, visibility=0.46
# Landmark 14 in pixels: x=117, y=946
# Landmark 15: x=0.494, y=0.997, visibility=0.30
# Landmark 15 in pixels: x=632, y=718
# Landmark 16: x=0.178, y=1.004, visibility=0.35
# Landmark 16 in pixels: x=228, y=723
# Landmark 17: x=0.509, y=0.967, visibility=0.37
# Landmark 17 in pixels: x=652, y=696
# Landmark 18: x=0.201, y=0.921, visibility=0.37
# Landmark 18 in pixels: x=257, y=662
# Landmark 19: x=0.495, y=0.923, visibility=0.41
# Landmark 19 in pixels: x=633, y=664
# Landmark 20: x=0.199, y=0.884, visibility=0.38
# Landmark 20 in pixels: x=255, y=636
# Landmark 21: x=0.487, y=0.932, visibility=0.39
# Landmark 21 in pixels: x=623, y=670
# Landmark 22: x=0.207, y=0.924, visibility=0.33
# Landmark 22 in pixels: x=265, y=665
# Landmark 23: x=0.411, y=1.747, visibility=0.01
# Landmark 23 in pixels: x=526, y=1258
# Landmark 24: x=0.233, y=1.729, visibility=0.01
# Landmark 24 in pixels: x=298, y=1244
# Landmark 25: x=0.412, y=1.473, visibility=0.06
# Landmark 25 in pixels: x=526, y=1060
# Landmark 26: x=0.206, y=1.516, visibility=0.03
# Landmark 26 in pixels: x=263, y=1091
# Landmark 27: x=0.392, y=1.705, visibility=0.01
# Landmark 27 in pixels: x=501, y=1227
# Landmark 28: x=0.322, y=1.646, visibility=0.00
# Landmark 28 in pixels: x=412, y=1184
# Landmark 29: x=0.377, y=1.790, visibility=0.01
# Landmark 29 in pixels: x=482, y=1288
# Landmark 30: x=0.341, y=1.685, visibility=0.00
# Landmark 30 in pixels: x=436, y=1213
# Landmark 31: x=0.403, y=1.731, visibility=0.02
# Landmark 31 in pixels: x=515, y=1246
# Landmark 32: x=0.338, y=1.690, visibility=0.01
# Landmark 32 in pixels: x=432, y=1216
# Landmark 0: x=0.362, y=0.836, visibility=1.00
# Landmark 0 in pixels: x=463, y=602
# Landmark 1: x=0.398, y=0.749, visibility=1.00
# Landmark 1 in pixels: x=509, y=539
# Landmark 2: x=0.418, y=0.752, visibility=1.00
# Landmark 2 in pixels: x=534, y=541
# Landmark 3: x=0.436, y=0.754, visibility=1.00
# Landmark 3 in pixels: x=557, y=543
# Landmark 4: x=0.340, y=0.726, visibility=1.00
# Landmark 4 in pixels: x=434, y=522
# Landmark 5: x=0.318, y=0.714, visibility=1.00
# Landmark 5 in pixels: x=407, y=514
# Landmark 6: x=0.301, y=0.703, visibility=1.00
# Landmark 6 in pixels: x=385, y=506
# Landmark 7: x=0.456, y=0.758, visibility=1.00
# Landmark 7 in pixels: x=583, y=545
# Landmark 8: x=0.271, y=0.697, visibility=1.00
# Landmark 8 in pixels: x=346, y=502
# Landmark 9: x=0.386, y=0.924, visibility=0.99
# Landmark 9 in pixels: x=494, y=665
# Landmark 10: x=0.317, y=0.895, visibility=1.00
# Landmark 10 in pixels: x=405, y=644
# Landmark 11: x=0.480, y=1.001, visibility=0.85
# Landmark 11 in pixels: x=613, y=720
# Landmark 12: x=0.150, y=0.987, visibility=0.88
# Landmark 12 in pixels: x=191, y=710
# Landmark 13: x=0.552, y=1.271, visibility=0.20
# Landmark 13 in pixels: x=706, y=915
# Landmark 14: x=0.090, y=1.311, visibility=0.45
# Landmark 14 in pixels: x=115, y=943
# Landmark 15: x=0.493, y=0.997, visibility=0.33
# Landmark 15 in pixels: x=631, y=718
# Landmark 16: x=0.169, y=1.008, visibility=0.36
# Landmark 16 in pixels: x=215, y=726
# Landmark 17: x=0.511, y=0.967, visibility=0.40
# Landmark 17 in pixels: x=654, y=695
# Landmark 18: x=0.190, y=0.919, visibility=0.38
# Landmark 18 in pixels: x=243, y=661
# Landmark 19: x=0.501, y=0.924, visibility=0.43
# Landmark 19 in pixels: x=640, y=665
# Landmark 20: x=0.191, y=0.883, visibility=0.40
# Landmark 20 in pixels: x=244, y=635
# Landmark 21: x=0.485, y=0.933, visibility=0.41
# Landmark 21 in pixels: x=621, y=671
# Landmark 22: x=0.198, y=0.922, visibility=0.34
# Landmark 22 in pixels: x=253, y=664
# Landmark 23: x=0.411, y=1.761, visibility=0.01
# Landmark 23 in pixels: x=526, y=1267
# Landmark 24: x=0.232, y=1.741, visibility=0.01
# Landmark 24 in pixels: x=297, y=1253
# Landmark 25: x=0.414, y=1.567, visibility=0.06
# Landmark 25 in pixels: x=530, y=1128
# Landmark 26: x=0.208, y=1.601, visibility=0.03
# Landmark 26 in pixels: x=265, y=1152
# Landmark 27: x=0.404, y=1.842, visibility=0.01
# Landmark 27 in pixels: x=517, y=1326
# Landmark 28: x=0.331, y=1.778, visibility=0.00
# Landmark 28 in pixels: x=423, y=1280
# Landmark 29: x=0.396, y=1.931, visibility=0.01
# Landmark 29 in pixels: x=506, y=1390
# Landmark 30: x=0.354, y=1.823, visibility=0.00
# Landmark 30 in pixels: x=453, y=1312
# Landmark 31: x=0.411, y=1.880, visibility=0.01
# Landmark 31 in pixels: x=526, y=1353
# Landmark 32: x=0.339, y=1.833, visibility=0.01
# Landmark 32 in pixels: x=434, y=1319
# Landmark 0: x=0.362, y=0.836, visibility=1.00
# Landmark 0 in pixels: x=463, y=602
# Landmark 1: x=0.398, y=0.749, visibility=1.00
# Landmark 1 in pixels: x=509, y=539
# Landmark 2: x=0.418, y=0.752, visibility=1.00
# Landmark 2 in pixels: x=534, y=541
# Landmark 3: x=0.436, y=0.754, visibility=1.00
# Landmark 3 in pixels: x=557, y=543
# Landmark 4: x=0.341, y=0.726, visibility=1.00
# Landmark 4 in pixels: x=436, y=522
# Landmark 5: x=0.319, y=0.714, visibility=1.00
# Landmark 5 in pixels: x=408, y=514
# Landmark 6: x=0.301, y=0.703, visibility=1.00
# Landmark 6 in pixels: x=385, y=506
# Landmark 7: x=0.455, y=0.758, visibility=1.00
# Landmark 7 in pixels: x=582, y=545
# Landmark 8: x=0.270, y=0.697, visibility=1.00
# Landmark 8 in pixels: x=346, y=501
# Landmark 9: x=0.386, y=0.924, visibility=1.00
# Landmark 9 in pixels: x=494, y=665
# Landmark 10: x=0.317, y=0.895, visibility=1.00
# Landmark 10 in pixels: x=405, y=644
# Landmark 11: x=0.476, y=1.000, visibility=0.86
# Landmark 11 in pixels: x=609, y=720
# Landmark 12: x=0.146, y=0.988, visibility=0.89
# Landmark 12 in pixels: x=187, y=711
# Landmark 13: x=0.552, y=1.255, visibility=0.21
# Landmark 13 in pixels: x=706, y=903
# Landmark 14: x=0.088, y=1.303, visibility=0.44
# Landmark 14 in pixels: x=112, y=938
# Landmark 15: x=0.492, y=0.986, visibility=0.34
# Landmark 15 in pixels: x=629, y=709
# Landmark 16: x=0.163, y=1.005, visibility=0.36
# Landmark 16 in pixels: x=208, y=723
# Landmark 17: x=0.511, y=0.957, visibility=0.41
# Landmark 17 in pixels: x=653, y=688
# Landmark 18: x=0.183, y=0.917, visibility=0.39
# Landmark 18 in pixels: x=234, y=660
# Landmark 19: x=0.501, y=0.918, visibility=0.45
# Landmark 19 in pixels: x=641, y=661
# Landmark 20: x=0.186, y=0.881, visibility=0.40
# Landmark 20 in pixels: x=238, y=634
# Landmark 21: x=0.477, y=0.930, visibility=0.42
# Landmark 21 in pixels: x=609, y=669
# Landmark 22: x=0.193, y=0.920, visibility=0.35
# Landmark 22 in pixels: x=247, y=662
# Landmark 23: x=0.408, y=1.763, visibility=0.01
# Landmark 23 in pixels: x=522, y=1269
# Landmark 24: x=0.226, y=1.754, visibility=0.01
# Landmark 24 in pixels: x=289, y=1262
# Landmark 25: x=0.414, y=1.508, visibility=0.06
# Landmark 25 in pixels: x=530, y=1085
# Landmark 26: x=0.219, y=1.544, visibility=0.03
# Landmark 26 in pixels: x=279, y=1111
# Landmark 27: x=0.402, y=1.726, visibility=0.01
# Landmark 27 in pixels: x=513, y=1242
# Landmark 28: x=0.331, y=1.670, visibility=0.00
# Landmark 28 in pixels: x=423, y=1202
# Landmark 29: x=0.388, y=1.809, visibility=0.01
# Landmark 29 in pixels: x=496, y=1302
# Landmark 30: x=0.354, y=1.711, visibility=0.00
# Landmark 30 in pixels: x=452, y=1232
# Landmark 31: x=0.411, y=1.755, visibility=0.01
# Landmark 31 in pixels: x=526, y=1263
# Landmark 32: x=0.346, y=1.714, visibility=0.01
# Landmark 32 in pixels: x=442, y=1233
# Landmark 0: x=0.363, y=0.838, visibility=1.00
# Landmark 0 in pixels: x=464, y=603
# Landmark 1: x=0.399, y=0.751, visibility=1.00
# Landmark 1 in pixels: x=510, y=540
# Landmark 2: x=0.418, y=0.754, visibility=1.00
# Landmark 2 in pixels: x=535, y=543
# Landmark 3: x=0.436, y=0.757, visibility=1.00
# Landmark 3 in pixels: x=558, y=545
# Landmark 4: x=0.341, y=0.727, visibility=1.00
# Landmark 4 in pixels: x=436, y=523
# Landmark 5: x=0.319, y=0.714, visibility=1.00
# Landmark 5 in pixels: x=408, y=514
# Landmark 6: x=0.301, y=0.703, visibility=1.00
# Landmark 6 in pixels: x=385, y=506
# Landmark 7: x=0.455, y=0.762, visibility=1.00
# Landmark 7 in pixels: x=582, y=548
# Landmark 8: x=0.270, y=0.697, visibility=1.00
# Landmark 8 in pixels: x=345, y=501
# Landmark 9: x=0.386, y=0.926, visibility=1.00
# Landmark 9 in pixels: x=494, y=666
# Landmark 10: x=0.317, y=0.896, visibility=1.00
# Landmark 10 in pixels: x=405, y=645
# Landmark 11: x=0.467, y=1.000, visibility=0.86
# Landmark 11 in pixels: x=597, y=720
# Landmark 12: x=0.145, y=0.989, visibility=0.89
# Landmark 12 in pixels: x=185, y=712
# Landmark 13: x=0.548, y=1.247, visibility=0.22
# Landmark 13 in pixels: x=702, y=897
# Landmark 14: x=0.087, y=1.294, visibility=0.43
# Landmark 14 in pixels: x=110, y=931
# Landmark 15: x=0.495, y=0.986, visibility=0.35
# Landmark 15 in pixels: x=633, y=710
# Landmark 16: x=0.145, y=1.005, visibility=0.36
# Landmark 16 in pixels: x=185, y=723
# Landmark 17: x=0.518, y=0.956, visibility=0.43
# Landmark 17 in pixels: x=663, y=688
# Landmark 18: x=0.158, y=0.918, visibility=0.39
# Landmark 18 in pixels: x=202, y=660
# Landmark 19: x=0.510, y=0.918, visibility=0.47
# Landmark 19 in pixels: x=652, y=661
# Landmark 20: x=0.160, y=0.886, visibility=0.41
# Landmark 20 in pixels: x=204, y=638
# Landmark 21: x=0.488, y=0.931, visibility=0.44
# Landmark 21 in pixels: x=624, y=670
# Landmark 22: x=0.171, y=0.923, visibility=0.35
# Landmark 22 in pixels: x=218, y=664
# Landmark 23: x=0.400, y=1.773, visibility=0.01
# Landmark 23 in pixels: x=511, y=1276
# Landmark 24: x=0.218, y=1.765, visibility=0.01
# Landmark 24 in pixels: x=279, y=1270
# Landmark 25: x=0.407, y=1.478, visibility=0.06
# Landmark 25 in pixels: x=520, y=1064
# Landmark 26: x=0.225, y=1.520, visibility=0.03
# Landmark 26 in pixels: x=287, y=1094
# Landmark 27: x=0.392, y=1.697, visibility=0.01
# Landmark 27 in pixels: x=502, y=1221
# Landmark 28: x=0.326, y=1.649, visibility=0.00
# Landmark 28 in pixels: x=417, y=1187
# Landmark 29: x=0.374, y=1.781, visibility=0.01
# Landmark 29 in pixels: x=478, y=1282
# Landmark 30: x=0.340, y=1.689, visibility=0.00
# Landmark 30 in pixels: x=435, y=1215
# Landmark 31: x=0.410, y=1.720, visibility=0.01
# Landmark 31 in pixels: x=524, y=1238
# Landmark 32: x=0.345, y=1.691, visibility=0.01
# Landmark 32 in pixels: x=441, y=1217
# Landmark 0: x=0.364, y=0.838, visibility=1.00
# Landmark 0 in pixels: x=465, y=603
# Landmark 1: x=0.400, y=0.751, visibility=1.00
# Landmark 1 in pixels: x=511, y=540
# Landmark 2: x=0.420, y=0.754, visibility=1.00
# Landmark 2 in pixels: x=537, y=542
# Landmark 3: x=0.437, y=0.757, visibility=1.00
# Landmark 3 in pixels: x=559, y=544
# Landmark 4: x=0.343, y=0.727, visibility=1.00
# Landmark 4 in pixels: x=438, y=523
# Landmark 5: x=0.321, y=0.715, visibility=1.00
# Landmark 5 in pixels: x=410, y=514
# Landmark 6: x=0.302, y=0.703, visibility=1.00
# Landmark 6 in pixels: x=386, y=506
# Landmark 7: x=0.456, y=0.761, visibility=1.00
# Landmark 7 in pixels: x=583, y=548
# Landmark 8: x=0.269, y=0.697, visibility=1.00
# Landmark 8 in pixels: x=344, y=501
# Landmark 9: x=0.386, y=0.926, visibility=1.00
# Landmark 9 in pixels: x=494, y=666
# Landmark 10: x=0.318, y=0.896, visibility=1.00
# Landmark 10 in pixels: x=407, y=645
# Landmark 11: x=0.478, y=1.001, visibility=0.86
# Landmark 11 in pixels: x=612, y=720
# Landmark 12: x=0.146, y=0.990, visibility=0.89
# Landmark 12 in pixels: x=187, y=712
# Landmark 13: x=0.565, y=1.275, visibility=0.22
# Landmark 13 in pixels: x=723, y=917
# Landmark 14: x=0.072, y=1.321, visibility=0.42
# Landmark 14 in pixels: x=92, y=951
# Landmark 15: x=0.497, y=0.994, visibility=0.36
# Landmark 15 in pixels: x=636, y=715
# Landmark 16: x=0.131, y=1.009, visibility=0.35
# Landmark 16 in pixels: x=167, y=726
# Landmark 17: x=0.518, y=0.956, visibility=0.43
# Landmark 17 in pixels: x=662, y=688
# Landmark 18: x=0.143, y=0.917, visibility=0.39
# Landmark 18 in pixels: x=183, y=660
# Landmark 19: x=0.510, y=0.919, visibility=0.47
# Landmark 19 in pixels: x=652, y=661
# ...
# Landmark 24 in pixels: x=295, y=1432
# Landmark 25: x=0.498, y=2.729, visibility=0.01
# Landmark 25 in pixels: x=637, y=1964
# Landmark 26: x=0.255, y=2.729, visibility=0.00
# Landmark 26 in pixels: x=325, y=1964
# Landmark 27: x=0.538, y=3.578, visibility=0.00
# Landmark 27 in pixels: x=688, y=2575
# Landmark 28: x=0.308, y=3.534, visibility=0.00
# Landmark 28 in pixels: x=393, y=2544
# Landmark 29: x=0.556, y=3.722, visibility=0.00
# Landmark 29 in pixels: x=711, y=2679
# Landmark 30: x=0.319, y=3.657, visibility=0.00
# Landmark 30 in pixels: x=408, y=2633
# Landmark 31: x=0.492, y=3.791, visibility=0.00
# Landmark 31 in pixels: x=629, y=2729
# Landmark 32: x=0.313, y=3.776, visibility=0.00
# Landmark 32 in pixels: x=400, y=2718
# Landmark 0: x=0.325, y=0.666, visibility=1.00
# Landmark 0 in pixels: x=416, y=479
# Landmark 1: x=0.360, y=0.557, visibility=1.00
# Landmark 1 in pixels: x=461, y=401
# Landmark 2: x=0.383, y=0.552, visibility=1.00
# Landmark 2 in pixels: x=490, y=397
# Landmark 3: x=0.403, y=0.548, visibility=1.00
# Landmark 3 in pixels: x=515, y=394
# Landmark 4: x=0.301, y=0.560, visibility=1.00
# Landmark 4 in pixels: x=385, y=403
# Landmark 5: x=0.286, y=0.557, visibility=1.00
# Landmark 5 in pixels: x=365, y=400
# Landmark 6: x=0.273, y=0.554, visibility=1.00
# Landmark 6 in pixels: x=349, y=398
# Landmark 7: x=0.444, y=0.545, visibility=1.00
# Landmark 7 in pixels: x=567, y=392
# Landmark 8: x=0.274, y=0.542, visibility=1.00
# Landmark 8 in pixels: x=350, y=390
# Landmark 9: x=0.369, y=0.735, visibility=1.00
# Landmark 9 in pixels: x=472, y=528
# Landmark 10: x=0.304, y=0.733, visibility=1.00
# Landmark 10 in pixels: x=388, y=527
# Landmark 11: x=0.585, y=0.919, visibility=0.94
# Landmark 11 in pixels: x=749, y=661
# Landmark 12: x=0.129, y=0.912, visibility=0.95
# Landmark 12 in pixels: x=164, y=656
# Landmark 13: x=0.670, y=1.241, visibility=0.17
# Landmark 13 in pixels: x=857, y=893
# Landmark 14: x=0.022, y=1.356, visibility=0.17
# Landmark 14 in pixels: x=28, y=976
# Landmark 15: x=0.523, y=1.037, visibility=0.11
# Landmark 15 in pixels: x=669, y=746
# Landmark 16: x=0.111, y=1.044, visibility=0.15
# Landmark 16 in pixels: x=142, y=751
# Landmark 17: x=0.494, y=0.991, visibility=0.15
# Landmark 17 in pixels: x=632, y=713
# Landmark 18: x=0.172, y=1.095, visibility=0.18
# Landmark 18 in pixels: x=220, y=788
# Landmark 19: x=0.485, y=0.947, visibility=0.20
# Landmark 19 in pixels: x=620, y=681
# Landmark 20: x=0.180, y=1.040, visibility=0.25
# Landmark 20 in pixels: x=230, y=748
# Landmark 21: x=0.484, y=0.975, visibility=0.17
# Landmark 21 in pixels: x=619, y=701
# Landmark 22: x=0.180, y=1.068, visibility=0.20
# Landmark 22 in pixels: x=230, y=768
# Landmark 23: x=0.507, y=2.007, visibility=0.00
# Landmark 23 in pixels: x=648, y=1445
# Landmark 24: x=0.230, y=1.991, visibility=0.00
# Landmark 24 in pixels: x=294, y=1433
# Landmark 25: x=0.478, y=2.641, visibility=0.01
# Landmark 25 in pixels: x=612, y=1901
# Landmark 26: x=0.234, y=2.646, visibility=0.00
# Landmark 26 in pixels: x=299, y=1905
# Landmark 27: x=0.531, y=3.510, visibility=0.00
# Landmark 27 in pixels: x=679, y=2527
# Landmark 28: x=0.307, y=3.475, visibility=0.00
# Landmark 28 in pixels: x=393, y=2501
# Landmark 29: x=0.551, y=3.662, visibility=0.00
# Landmark 29 in pixels: x=705, y=2636
# Landmark 30: x=0.320, y=3.599, visibility=0.00
# Landmark 30 in pixels: x=409, y=2590
# Landmark 31: x=0.489, y=3.717, visibility=0.00
# Landmark 31 in pixels: x=626, y=2676
# Landmark 32: x=0.313, y=3.717, visibility=0.00
# Landmark 32 in pixels: x=400, y=2675
# Landmark 0: x=0.325, y=0.666, visibility=1.00
# Landmark 0 in pixels: x=416, y=479
# Landmark 1: x=0.360, y=0.557, visibility=1.00
# Landmark 1 in pixels: x=461, y=400
# Landmark 2: x=0.383, y=0.552, visibility=1.00
# Landmark 2 in pixels: x=490, y=397
# Landmark 3: x=0.403, y=0.547, visibility=1.00
# Landmark 3 in pixels: x=515, y=394
# Landmark 4: x=0.301, y=0.559, visibility=1.00
# Landmark 4 in pixels: x=385, y=402
# Landmark 5: x=0.286, y=0.556, visibility=1.00
# Landmark 5 in pixels: x=365, y=400
# Landmark 6: x=0.273, y=0.554, visibility=1.00
# Landmark 6 in pixels: x=348, y=398
# Landmark 7: x=0.444, y=0.545, visibility=1.00
# Landmark 7 in pixels: x=567, y=392
# Landmark 8: x=0.274, y=0.542, visibility=1.00
# Landmark 8 in pixels: x=350, y=390
# Landmark 9: x=0.369, y=0.735, visibility=1.00
# Landmark 9 in pixels: x=472, y=528
# Landmark 10: x=0.304, y=0.733, visibility=1.00
# Landmark 10 in pixels: x=388, y=527
# Landmark 11: x=0.585, y=0.919, visibility=0.94
# Landmark 11 in pixels: x=748, y=661
# Landmark 12: x=0.128, y=0.912, visibility=0.95
# Landmark 12 in pixels: x=163, y=656
# Landmark 13: x=0.670, y=1.245, visibility=0.17
# Landmark 13 in pixels: x=858, y=896
# Landmark 14: x=0.021, y=1.357, visibility=0.17
# Landmark 14 in pixels: x=26, y=977
# Landmark 15: x=0.527, y=1.064, visibility=0.11
# Landmark 15 in pixels: x=674, y=765
# Landmark 16: x=0.112, y=1.187, visibility=0.14
# Landmark 16 in pixels: x=143, y=854
# Landmark 17: x=0.500, y=1.026, visibility=0.15
# Landmark 17 in pixels: x=640, y=738
# Landmark 18: x=0.165, y=1.166, visibility=0.18
# Landmark 18 in pixels: x=211, y=839
# Landmark 19: x=0.490, y=0.978, visibility=0.20
# Landmark 19 in pixels: x=627, y=704
# Landmark 20: x=0.173, y=1.099, visibility=0.24
# Landmark 20 in pixels: x=220, y=790
# Landmark 21: x=0.489, y=1.003, visibility=0.17
# Landmark 21 in pixels: x=626, y=722
# Landmark 22: x=0.172, y=1.114, visibility=0.20
# Landmark 22 in pixels: x=220, y=801
# Landmark 23: x=0.507, y=2.009, visibility=0.00
# Landmark 23 in pixels: x=648, y=1446
# Landmark 24: x=0.230, y=1.993, visibility=0.00
# Landmark 24 in pixels: x=294, y=1434
# Landmark 25: x=0.484, y=2.659, visibility=0.01
# Landmark 25 in pixels: x=619, y=1914
# Landmark 26: x=0.237, y=2.653, visibility=0.00
# Landmark 26 in pixels: x=302, y=1909
# Landmark 27: x=0.535, y=3.520, visibility=0.00
# Landmark 27 in pixels: x=684, y=2534
# Landmark 28: x=0.308, y=3.485, visibility=0.00
# Landmark 28 in pixels: x=393, y=2508
# Landmark 29: x=0.554, y=3.670, visibility=0.00
# Landmark 29 in pixels: x=709, y=2642
# Landmark 30: x=0.320, y=3.607, visibility=0.00
# Landmark 30 in pixels: x=409, y=2597
# Landmark 31: x=0.494, y=3.731, visibility=0.00
# Landmark 31 in pixels: x=632, y=2686
# Landmark 32: x=0.314, y=3.728, visibility=0.00
# Landmark 32 in pixels: x=401, y=2683
# Landmark 0: x=0.325, y=0.666, visibility=1.00
# Landmark 0 in pixels: x=416, y=479
# Landmark 1: x=0.360, y=0.557, visibility=1.00
# Landmark 1 in pixels: x=461, y=401
# Landmark 2: x=0.383, y=0.552, visibility=1.00
# Landmark 2 in pixels: x=490, y=397
# Landmark 3: x=0.403, y=0.548, visibility=1.00
# Landmark 3 in pixels: x=515, y=394
# Landmark 4: x=0.301, y=0.560, visibility=1.00
# Landmark 4 in pixels: x=385, y=402
# Landmark 5: x=0.286, y=0.557, visibility=1.00
# Landmark 5 in pixels: x=365, y=400
# Landmark 6: x=0.272, y=0.554, visibility=1.00
# Landmark 6 in pixels: x=348, y=398
# Landmark 7: x=0.444, y=0.545, visibility=1.00
# Landmark 7 in pixels: x=567, y=392
# Landmark 8: x=0.274, y=0.542, visibility=1.00
# Landmark 8 in pixels: x=350, y=390
# Landmark 9: x=0.369, y=0.735, visibility=1.00
# Landmark 9 in pixels: x=471, y=529
# Landmark 10: x=0.304, y=0.733, visibility=1.00
# Landmark 10 in pixels: x=388, y=527
# Landmark 11: x=0.583, y=0.919, visibility=0.93
# Landmark 11 in pixels: x=745, y=661
# Landmark 12: x=0.128, y=0.913, visibility=0.95
# Landmark 12 in pixels: x=163, y=657
# Landmark 13: x=0.667, y=1.245, visibility=0.18
# Landmark 13 in pixels: x=853, y=896
# Landmark 14: x=0.025, y=1.359, visibility=0.17
# Landmark 14 in pixels: x=32, y=978
# Landmark 15: x=0.517, y=1.077, visibility=0.11
# Landmark 15 in pixels: x=662, y=775
# Landmark 16: x=0.137, y=1.220, visibility=0.14
# Landmark 16 in pixels: x=175, y=878
# Landmark 17: x=0.487, y=1.046, visibility=0.15
# Landmark 17 in pixels: x=623, y=753
# Landmark 18: x=0.178, y=1.183, visibility=0.18
# Landmark 18 in pixels: x=228, y=852
# Landmark 19: x=0.480, y=0.998, visibility=0.20
# Landmark 19 in pixels: x=614, y=718
# Landmark 20: x=0.184, y=1.116, visibility=0.24
# Landmark 20 in pixels: x=235, y=803
# Landmark 21: x=0.481, y=1.019, visibility=0.17
# Landmark 21 in pixels: x=615, y=733
# Landmark 22: x=0.182, y=1.129, visibility=0.20
# Landmark 22 in pixels: x=233, y=812
# Landmark 23: x=0.506, y=2.009, visibility=0.00
# Landmark 23 in pixels: x=647, y=1446
# Landmark 24: x=0.230, y=1.993, visibility=0.00
# Landmark 24 in pixels: x=294, y=1435
# Landmark 25: x=0.486, y=2.682, visibility=0.01
# Landmark 25 in pixels: x=621, y=1930
# Landmark 26: x=0.237, y=2.672, visibility=0.00
# Landmark 26 in pixels: x=303, y=1923
# Landmark 27: x=0.533, y=3.532, visibility=0.00
# Landmark 27 in pixels: x=682, y=2543
# Landmark 28: x=0.308, y=3.495, visibility=0.00
# Landmark 28 in pixels: x=393, y=2516
# Landmark 29: x=0.553, y=3.679, visibility=0.00
# Landmark 29 in pixels: x=707, y=2648
# Landmark 30: x=0.320, y=3.618, visibility=0.00
# Landmark 30 in pixels: x=409, y=2605
# Landmark 31: x=0.490, y=3.748, visibility=0.00
# Landmark 31 in pixels: x=627, y=2698
# Landmark 32: x=0.314, y=3.740, visibility=0.00
# Landmark 32 in pixels: x=401, y=2692
# Landmark 0: x=0.326, y=0.666, visibility=1.00
# Landmark 0 in pixels: x=416, y=479
# Landmark 1: x=0.361, y=0.557, visibility=1.00
# Landmark 1 in pixels: x=462, y=401
# Landmark 2: x=0.384, y=0.552, visibility=1.00
# Landmark 2 in pixels: x=491, y=397
# Landmark 3: x=0.404, y=0.548, visibility=1.00
# Landmark 3 in pixels: x=516, y=394
# Landmark 4: x=0.302, y=0.560, visibility=1.00
# Landmark 4 in pixels: x=385, y=403
# Landmark 5: x=0.286, y=0.557, visibility=1.00
# Landmark 5 in pixels: x=365, y=400
# Landmark 6: x=0.272, y=0.554, visibility=1.00
# Landmark 6 in pixels: x=348, y=398
# Landmark 7: x=0.444, y=0.545, visibility=1.00
# Landmark 7 in pixels: x=567, y=392
# Landmark 8: x=0.273, y=0.542, visibility=1.00
# Landmark 8 in pixels: x=349, y=390
# Landmark 9: x=0.369, y=0.735, visibility=1.00
# Landmark 9 in pixels: x=472, y=529
# Landmark 10: x=0.304, y=0.733, visibility=1.00
# Landmark 10 in pixels: x=388, y=527
# Landmark 11: x=0.581, y=0.920, visibility=0.94
# Landmark 11 in pixels: x=743, y=662
# Landmark 12: x=0.127, y=0.914, visibility=0.95
# Landmark 12 in pixels: x=162, y=657
# Landmark 13: x=0.666, y=1.247, visibility=0.18
# Landmark 13 in pixels: x=852, y=897
# Landmark 14: x=0.023, y=1.358, visibility=0.17
# Landmark 14 in pixels: x=28, y=978
# Landmark 15: x=0.523, y=1.050, visibility=0.12
# Landmark 15 in pixels: x=669, y=756
# Landmark 16: x=0.115, y=1.057, visibility=0.14
# Landmark 16 in pixels: x=147, y=760
# Landmark 17: x=0.495, y=1.004, visibility=0.16
# Landmark 17 in pixels: x=634, y=722
# Landmark 18: x=0.177, y=1.107, visibility=0.18
# Landmark 18 in pixels: x=227, y=797
# Landmark 19: x=0.486, y=0.957, visibility=0.21
# Landmark 19 in pixels: x=622, y=688
# Landmark 20: x=0.181, y=1.052, visibility=0.24
# Landmark 20 in pixels: x=232, y=757
# Landmark 21: x=0.486, y=0.985, visibility=0.17
# Landmark 21 in pixels: x=622, y=709
# Landmark 22: x=0.181, y=1.080, visibility=0.20
# Landmark 22 in pixels: x=231, y=777
# Landmark 23: x=0.504, y=2.014, visibility=0.00
# Landmark 23 in pixels: x=645, y=1450
# Landmark 24: x=0.228, y=1.999, visibility=0.00
# Landmark 24 in pixels: x=291, y=1439
# Landmark 25: x=0.488, y=2.683, visibility=0.01
# Landmark 25 in pixels: x=624, y=1931
# Landmark 26: x=0.238, y=2.690, visibility=0.00
# Landmark 26 in pixels: x=304, y=1936
# Landmark 27: x=0.533, y=3.544, visibility=0.00
# Landmark 27 in pixels: x=681, y=2551
# Landmark 28: x=0.307, y=3.511, visibility=0.00
# Landmark 28 in pixels: x=392, y=2528
# Landmark 29: x=0.552, y=3.692, visibility=0.00
# Landmark 29 in pixels: x=706, y=2658
# Landmark 30: x=0.319, y=3.635, visibility=0.00
# Landmark 30 in pixels: x=408, y=2617
# Landmark 31: x=0.490, y=3.759, visibility=0.00
# Landmark 31 in pixels: x=627, y=2706
# Landmark 32: x=0.313, y=3.747, visibility=0.00
# Landmark 32 in pixels: x=400, y=2698
# Landmark 0: x=0.326, y=0.666, visibility=1.00
# Landmark 0 in pixels: x=416, y=479
# Landmark 1: x=0.362, y=0.557, visibility=1.00
# Landmark 1 in pixels: x=462, y=400
# Landmark 2: x=0.384, y=0.551, visibility=1.00
# Landmark 2 in pixels: x=491, y=397
# Landmark 3: x=0.404, y=0.547, visibility=1.00
# Landmark 3 in pixels: x=516, y=393
# Landmark 4: x=0.302, y=0.559, visibility=1.00
# Landmark 4 in pixels: x=386, y=402
# Landmark 5: x=0.286, y=0.556, visibility=1.00
# Landmark 5 in pixels: x=365, y=400
# Landmark 6: x=0.273, y=0.553, visibility=1.00
# Landmark 6 in pixels: x=348, y=398
# Landmark 7: x=0.444, y=0.545, visibility=1.00
# Landmark 7 in pixels: x=567, y=392
# Landmark 8: x=0.273, y=0.542, visibility=1.00
# Landmark 8 in pixels: x=349, y=390
# Landmark 9: x=0.369, y=0.735, visibility=1.00
# Landmark 9 in pixels: x=472, y=529
# Landmark 10: x=0.304, y=0.733, visibility=1.00
# Landmark 10 in pixels: x=388, y=527
# Landmark 11: x=0.580, y=0.920, visibility=0.93
# Landmark 11 in pixels: x=741, y=662
# Landmark 12: x=0.127, y=0.913, visibility=0.95
# Landmark 12 in pixels: x=161, y=657
# Landmark 13: x=0.663, y=1.249, visibility=0.19
# Landmark 13 in pixels: x=849, y=899
# Landmark 14: x=0.023, y=1.362, visibility=0.16
# Landmark 14 in pixels: x=29, y=980
# Landmark 15: x=0.519, y=1.061, visibility=0.12
# Landmark 15 in pixels: x=664, y=764
# Landmark 16: x=0.116, y=1.245, visibility=0.14
# Landmark 16 in pixels: x=148, y=896
# Landmark 17: x=0.490, y=1.022, visibility=0.16
# Landmark 17 in pixels: x=626, y=735
# Landmark 18: x=0.166, y=1.252, visibility=0.18
# Landmark 18 in pixels: x=212, y=901
# Landmark 19: x=0.481, y=0.974, visibility=0.21
# Landmark 19 in pixels: x=615, y=701
# Landmark 20: x=0.171, y=1.191, visibility=0.23
# Landmark 20 in pixels: x=218, y=857
# Landmark 21: x=0.481, y=0.999, visibility=0.18
# Landmark 21 in pixels: x=615, y=719
# Landmark 22: x=0.171, y=1.199, visibility=0.19
# Landmark 22 in pixels: x=218, y=863
# Landmark 23: x=0.502, y=2.014, visibility=0.00
# Landmark 23 in pixels: x=641, y=1450
# Landmark 24: x=0.225, y=1.998, visibility=0.00
# Landmark 24 in pixels: x=287, y=1438
# Landmark 25: x=0.476, y=2.696, visibility=0.01
# Landmark 25 in pixels: x=608, y=1941
# Landmark 26: x=0.223, y=2.694, visibility=0.00
# Landmark 26 in pixels: x=285, y=1939
# Landmark 27: x=0.514, y=3.547, visibility=0.00
# Landmark 27 in pixels: x=658, y=2554
# Landmark 28: x=0.271, y=3.514, visibility=0.00
# Landmark 28 in pixels: x=346, y=2530
# Landmark 29: x=0.533, y=3.693, visibility=0.00
# Landmark 29 in pixels: x=681, y=2659
# Landmark 30: x=0.282, y=3.638, visibility=0.00
# Landmark 30 in pixels: x=360, y=2619
# Landmark 31: x=0.469, y=3.765, visibility=0.00
# Landmark 31 in pixels: x=600, y=2710
# Landmark 32: x=0.278, y=3.753, visibility=0.00
# Landmark 32 in pixels: x=356, y=2702
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 45
#      42 rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#      44 # Perform pose detection.
# ---> 45 results = pose_video.process(rgb_frame)
#      47 # If landmarks are detected, process them.
#      48 if results.pose_landmarks:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mediapipe\python\solutions\pose.py:185, in Pose.process(self, image)
#     164 def process(self, image: np.ndarray) -> NamedTuple:
#     165   """Processes an RGB image and returns the pose landmarks on the most prominent person detected.
#     166
#     167   Args:
#    (...)
#     182          "enable_segmentation" is set to true.
#     183   """
# --> 185   results = super().process(input_data={'image': image})
#     186   if results.pose_landmarks:  # pytype: disable=attribute-error
#     187     for landmark in results.pose_landmarks.landmark:  # pytype: disable=attribute-error
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mediapipe\python\solution_base.py:340, in SolutionBase.process(self, input_data)
#     334   else:
#     335     self._graph.add_packet_to_input_stream(
#     336         stream=stream_name,
#     337         packet=self._make_packet(input_stream_type,
#     338                                  data).at(self._simulated_timestamp))
# --> 340 self._graph.wait_until_idle()
#     341 # Create a NamedTuple object where the field names are mapping to the graph
#     342 # output stream names.
#     343 if self._output_stream_type_info is None:
#
# KeyboardInterrupt:

# %%
for lndmrk in mp_pose.PoseLandmark:
    print(f"{lndmrk.value}: {lndmrk.name}")
# Out:
# 0: NOSE
# 1: LEFT_EYE_INNER
# 2: LEFT_EYE
# 3: LEFT_EYE_OUTER
# 4: RIGHT_EYE_INNER
# 5: RIGHT_EYE
# 6: RIGHT_EYE_OUTER
# 7: LEFT_EAR
# 8: RIGHT_EAR
# 9: MOUTH_LEFT
# 10: MOUTH_RIGHT
# 11: LEFT_SHOULDER
# 12: RIGHT_SHOULDER
# 13: LEFT_ELBOW
# 14: RIGHT_ELBOW
# 15: LEFT_WRIST
# 16: RIGHT_WRIST
# 17: LEFT_PINKY
# 18: RIGHT_PINKY
# 19: LEFT_INDEX
# 20: RIGHT_INDEX
# 21: LEFT_THUMB
# 22: RIGHT_THUMB
# 23: LEFT_HIP
# 24: RIGHT_HIP
# 25: LEFT_KNEE
# 26: RIGHT_KNEE
# 27: LEFT_ANKLE
# 28: RIGHT_ANKLE
# 29: LEFT_HEEL
# 30: RIGHT_HEEL
# 31: LEFT_FOOT_INDEX
# 32: RIGHT_FOOT_INDEX

# %%
for i, landmark in enumerate(landmarks):
    print(f"Landmark {i}:")
    print(f"x: {landmark.x:.6f}")
    print(f"y: {landmark.y:.6f}")
    print(f"visibility: {landmark.visibility:.6f}")
    print("-" * 20)  # Separator for better readability
# Out:
# Landmark 0:
# x: 0.325759
# y: 0.666308
# visibility: 0.998667
# --------------------
# Landmark 1:
# x: 0.361673
# y: 0.556570
# visibility: 0.998598
# --------------------
# Landmark 2:
# x: 0.384117
# y: 0.551411
# visibility: 0.998475
# --------------------
# Landmark 3:
# x: 0.403786
# y: 0.546936
# visibility: 0.998167
# --------------------
# Landmark 4:
# x: 0.301831
# y: 0.559362
# visibility: 0.998675
# --------------------
# Landmark 5:
# x: 0.285694
# y: 0.556267
# visibility: 0.998542
# --------------------
# Landmark 6:
# x: 0.272503
# y: 0.553413
# visibility: 0.998510
# --------------------
# Landmark 7:
# x: 0.443622
# y: 0.545204
# visibility: 0.998768
# --------------------
# Landmark 8:
# x: 0.272940
# y: 0.542238
# visibility: 0.998840
# --------------------
# Landmark 9:
# x: 0.368878
# y: 0.735029
# visibility: 0.997545
# --------------------
# Landmark 10:
# x: 0.303778
# y: 0.733179
# visibility: 0.997920
# --------------------
# Landmark 11:
# x: 0.579650
# y: 0.920428
# visibility: 0.934232
# --------------------
# Landmark 12:
# x: 0.126530
# y: 0.913240
# visibility: 0.949151
# --------------------
# Landmark 13:
# x: 0.663460
# y: 1.249434
# visibility: 0.193134
# --------------------
# Landmark 14:
# x: 0.023408
# y: 1.361787
# visibility: 0.164378
# --------------------
# Landmark 15:
# x: 0.518923
# y: 1.061468
# visibility: 0.122986
# --------------------
# Landmark 16:
# x: 0.115785
# y: 1.244994
# visibility: 0.137989
# --------------------
# Landmark 17:
# x: 0.489705
# y: 1.021835
# visibility: 0.163075
# --------------------
# Landmark 18:
# x: 0.166246
# y: 1.251791
# visibility: 0.175836
# --------------------
# Landmark 19:
# x: 0.480788
# y: 0.973771
# visibility: 0.213473
# --------------------
# Landmark 20:
# x: 0.170609
# y: 1.191474
# visibility: 0.233940
# --------------------
# Landmark 21:
# x: 0.480837
# y: 0.998852
# visibility: 0.179282
# --------------------
# Landmark 22:
# x: 0.170780
# y: 1.199302
# visibility: 0.191963
# --------------------
# Landmark 23:
# x: 0.501536
# y: 2.014272
# visibility: 0.000678
# --------------------
# Landmark 24:
# x: 0.224663
# y: 1.998264
# visibility: 0.000568
# --------------------
# Landmark 25:
# x: 0.475616
# y: 2.696137
# visibility: 0.008831
# --------------------
# Landmark 26:
# x: 0.222830
# y: 2.694356
# visibility: 0.003910
# --------------------
# Landmark 27:
# x: 0.514446
# y: 3.547339
# visibility: 0.000266
# --------------------
# Landmark 28:
# x: 0.270975
# y: 3.514221
# visibility: 0.000203
# --------------------
# Landmark 29:
# x: 0.532512
# y: 3.693112
# visibility: 0.000126
# --------------------
# Landmark 30:
# x: 0.281549
# y: 3.638193
# visibility: 0.000261
# --------------------
# Landmark 31:
# x: 0.468779
# y: 3.765050
# visibility: 0.000492
# --------------------
# Landmark 32:
# x: 0.278453
# y: 3.752802
# visibility: 0.000952
# --------------------

# %%
# Initialize an empty list to store the landmarks
user_landmarks = []

# Extract x, y, and visibility for all 33 landmarks
for landmark in landmarks:
    user_landmarks.append([
        round(landmark.x, 6), 
        round(landmark.y, 6), 
        round(landmark.visibility, 6)
    ])

# Convert to a NumPy array (optional)
user_landmarks = np.array(user_landmarks)

# Print the result
print("user_landmarks =", user_landmarks.tolist())  # Convert to list for better readability
# Out:
# user_landmarks = [[0.325759, 0.666308, 0.998667], [0.361673, 0.55657, 0.998598], [0.384117, 0.551411, 0.998475], [0.403786, 0.546936, 0.998167], [0.301831, 0.559362, 0.998675], [0.285694, 0.556267, 0.998542], [0.272503, 0.553413, 0.99851], [0.443622, 0.545204, 0.998768], [0.27294, 0.542238, 0.99884], [0.368878, 0.735029, 0.997545], [0.303778, 0.733179, 0.99792], [0.57965, 0.920428, 0.934232], [0.12653, 0.91324, 0.949151], [0.66346, 1.249434, 0.193134], [0.023408, 1.361787, 0.164378], [0.518923, 1.061468, 0.122986], [0.115785, 1.244994, 0.137989], [0.489705, 1.021835, 0.163075], [0.166246, 1.251791, 0.175836], [0.480788, 0.973771, 0.213473], [0.170609, 1.191474, 0.23394], [0.480837, 0.998852, 0.179282], [0.17078, 1.199302, 0.191963], [0.501536, 2.014272, 0.000678], [0.224663, 1.998264, 0.000568], [0.475616, 2.696137, 0.008831], [0.22283, 2.694356, 0.00391], [0.514446, 3.547339, 0.000266], [0.270975, 3.514221, 0.000203], [0.532512, 3.693112, 0.000126], [0.281549, 3.638193, 0.000261], [0.468779, 3.76505, 0.000492], [0.278453, 3.752802, 0.000952]]

# %%
import json

# Initialize an empty list to store the landmarks
user_landmarks = []

# Extract x, y, and visibility for all 33 landmarks
for landmark in landmarks:
    user_landmarks.append([
        round(landmark.x, 6), 
        round(landmark.y, 6), 
        round(landmark.visibility, 6)
    ])

# Create a dictionary for JSON formatting
pose_data = {"user_landmarks": user_landmarks}

# Convert to JSON format (pretty-printed for readability)
pose_json = json.dumps(pose_data, indent=4)

# Print JSON output
print(pose_json)
# Out:
# {
#     "user_landmarks": [
#         [
#             0.325759,
#             0.666308,
#             0.998667
#         ],
#         [
#             0.361673,
#             0.55657,
#             0.998598
#         ],
#         [
#             0.384117,
#             0.551411,
#             0.998475
#         ],
#         [
#             0.403786,
#             0.546936,
#             0.998167
#         ],
#         [
#             0.301831,
#             0.559362,
#             0.998675
#         ],
#         [
#             0.285694,
#             0.556267,
#             0.998542
#         ],
#         [
#             0.272503,
#             0.553413,
#             0.99851
#         ],
#         [
#             0.443622,
#             0.545204,
#             0.998768
#         ],
#         [
#             0.27294,
#             0.542238,
#             0.99884
#         ],
#         [
#             0.368878,
#             0.735029,
#             0.997545
#         ],
#         [
#             0.303778,
#             0.733179,
#             0.99792
#         ],
#         [
#             0.57965,
#             0.920428,
#             0.934232
#         ],
#         [
#             0.12653,
#             0.91324,
#             0.949151
#         ],
#         [
#             0.66346,
#             1.249434,
#             0.193134
#         ],
#         [
#             0.023408,
#             1.361787,
#             0.164378
#         ],
#         [
#             0.518923,
#             1.061468,
#             0.122986
#         ],
#         [
#             0.115785,
#             1.244994,
#             0.137989
#         ],
#         [
#             0.489705,
#             1.021835,
#             0.163075
#         ],
#         [
#             0.166246,
#             1.251791,
#             0.175836
#         ],
#         [
#             0.480788,
#             0.973771,
#             0.213473
#         ],
#         [
#             0.170609,
#             1.191474,
#             0.23394
#         ],
#         [
#             0.480837,
#             0.998852,
#             0.179282
#         ],
#         [
#             0.17078,
#             1.199302,
#             0.191963
#         ],
#         [
#             0.501536,
#             2.014272,
#             0.000678
#         ],
#         [
#             0.224663,
#             1.998264,
#             0.000568
#         ],
#         [
#             0.475616,
#             2.696137,
#             0.008831
#         ],
#         [
#             0.22283,
#             2.694356,
#             0.00391
#         ],
#         [
#             0.514446,
#             3.547339,
#             0.000266
#         ],
#         [
#             0.270975,
#             3.514221,
#             0.000203
#         ],
#         [
#             0.532512,
#             3.693112,
#             0.000126
#         ],
#         [
#             0.281549,
#             3.638193,
#             0.000261
#         ],
#         [
#             0.468779,
#             3.76505,
#             0.000492
#         ],
#         [
#             0.278453,
#             3.752802,
#             0.000952
#         ]
#     ]
# }

# %%
def calculate_angle(a, b, c):
    """
    Calculate the angle between three points using the cosine rule.
    
    Args:
        a: First point (x, y).
        b: Second point (x, y) - the joint point.
        c: Third point (x, y).
    
    Returns:
        angle: Angle in degrees.
    """
    a = np.array(a)
    b = np.array(b)
    c = np.array(c)

    # Calculate vectors
    ba = a - b
    bc = c - b

    # Calculate cosine angle using dot product
    cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
    
    # Convert from radians to degrees
    angle = np.degrees(np.arccos(cosine_angle))
    
    return angle

# Extract landmark coordinates
left_shoulder = (landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x * frame_width, 
                 landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y * frame_height)

left_elbow = (landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x * frame_width, 
              landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y * frame_height)

left_wrist = (landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x * frame_width, 
              landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y * frame_height)

# Calculate the angle
elbow_angle = calculate_angle(left_shoulder, left_elbow, left_wrist)

print(f"Left Elbow Angle: {elbow_angle:.2f} degrees")
# Out:
# Left Elbow Angle: 143.61 degrees

# %%
print("hello world")
# Out:
# hello world
